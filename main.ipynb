# %% [markdown]
# # Advanced Querying Mongo

# %% [markdown]
# Importing libraries and setting up connection

# %%
# %pip install pymongo
from pymongo import MongoClient
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: pymongo in c:\users\usuario\anaconda3\lib\site-packages (4.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
cursor = MongoClient('mongodb://localhost:27017')
cursor
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
cursor.list_database_names()
# Out:
# ['admin', 'companies2', 'config', 'local']

# %%
db = cursor.companies2  # use companies;
colec = db.colec

# %%
colec
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies2'), 'colec')

# %% [markdown]
# ### 1. All the companies whose name match 'Babelgum'. Retrieve only their `name` field.

# %%
list(colec.find({'name': 'Babelgum'}, {'_id': False, 'name': True}))
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
list(colec.find({'number_of_employees':{'$gte': 5000}},
                {'name':1, 'number_of_employees':1, '_id':0}).sort('number_of_employees',1).limit(20))
# Out:
# [{'name': 'JDS Uniphase Corporation', 'number_of_employees': 5000},
#  {'name': 'PCH International', 'number_of_employees': 5000},
#  {'name': 'Vcare Call Center', 'number_of_employees': 5000},
#  {'name': 'United Internet', 'number_of_employees': 5000},
#  {'name': 'McAfee', 'number_of_employees': 5000},
#  {'name': 'Spotify', 'number_of_employees': 5000},
#  {'name': 'Air Astana Airlines', 'number_of_employees': 5000},
#  {'name': 'Nintendo', 'number_of_employees': 5080},
#  {'name': 'Hexaware Technologies', 'number_of_employees': 5200},
#  {'name': 'Facebook', 'number_of_employees': 5299},
#  {'name': 'OpenText', 'number_of_employees': 5300},
#  {'name': 'CPM Braxis', 'number_of_employees': 5400},
#  {'name': 'LSI', 'number_of_employees': 5400},
#  {'name': 'Microchip Technologies', 'number_of_employees': 5500},
#  {'name': 'Mediaset', 'number_of_employees': 5729},
#  {'name': 'Mindray Medical International', 'number_of_employees': 5763},
#  {'name': 'Atmel', 'number_of_employees': 6000},
#  {'name': 'Tata Communications', 'number_of_employees': 6000},
#  {'name': 'Dentsu', 'number_of_employees': 6000},
#  {'name': 'Baidu', 'number_of_employees': 6000}]

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fields.

# %%
list(colec.find({'founded_year':{'$gte':2000, '$lte':2005}},{'name':1,'founded_year':1,'_id':0}).sort('founded_year'))
# Out:
# [{'name': 'AllofMP3', 'founded_year': 2000},
#  {'name': 'Steorn', 'founded_year': 2000},
#  {'name': 'MeeVee', 'founded_year': 2000},
#  {'name': 'PhotoBox', 'founded_year': 2000},
#  {'name': 'Boonex', 'founded_year': 2000},
#  {'name': 'Sulake', 'founded_year': 2000},
#  {'name': 'SelectMinds', 'founded_year': 2000},
#  {'name': 'ContextWeb', 'founded_year': 2000},
#  {'name': 'ZoomInfo', 'founded_year': 2000},
#  {'name': 'eHarmony', 'founded_year': 2000},
#  {'name': 'Espotting', 'founded_year': 2000},
#  {'name': 'airG', 'founded_year': 2000},
#  {'name': 'Marchex', 'founded_year': 2000},
#  {'name': 'ContactOffice', 'founded_year': 2000},
#  {'name': 'WooMe', 'founded_year': 2000},
#  {'name': 'Boomi', 'founded_year': 2000},
#  {'name': 'zSlide', 'founded_year': 2000},
#  {'name': 'Phrasebase', 'founded_year': 2000},
#  {'name': 'Ubertor', 'founded_year': 2000},
#  {'name': 'JobDig', 'founded_year': 2000},
#  {'name': 'Quigo', 'founded_year': 2000},
#  {'name': 'Compete', 'founded_year': 2000},
#  {'name': 'LinkStorm', 'founded_year': 2000},
#  {'name': 'iStockphoto', 'founded_year': 2000},
#  {'name': 'beRecruited', 'founded_year': 2000},
#  {'name': 'FastBooking', 'founded_year': 2000},
#  {'name': 'Smilebox', 'founded_year': 2000},
#  {'name': 'Deem', 'founded_year': 2000},
#  {'name': 'CDNetworks', 'founded_year': 2000},
#  {'name': 'TripAdvisor', 'founded_year': 2000},
#  {'name': 'Oversee', 'founded_year': 2000},
#  {'name': 'iModules Software', 'founded_year': 2000},
#  {'name': 'eTeacher', 'founded_year': 2000},
#  {'name': 'uVuMobile', 'founded_year': 2000},
#  {'name': 'Escapia', 'founded_year': 2000},
#  {'name': 'Betfair', 'founded_year': 2000},
#  {'name': 'Maktoob', 'founded_year': 2000},
#  {'name': 'Ownersite Technologies', 'founded_year': 2000},
#  {'name': 'SnapNames', 'founded_year': 2000},
#  {'name': 'Online-Access', 'founded_year': 2000},
#  {'name': 'Exalead', 'founded_year': 2000},
#  {'name': 'Hotwire', 'founded_year': 2000},
#  {'name': 'StubHub', 'founded_year': 2000},
#  {'name': 'Project10X', 'founded_year': 2000},
#  {'name': 'Ephox', 'founded_year': 2000},
#  {'name': 'Fibre2fashion', 'founded_year': 2000},
#  {'name': 'LiveOps', 'founded_year': 2000},
#  {'name': 'PointRoll', 'founded_year': 2000},
#  {'name': 'Jelsoft', 'founded_year': 2000},
#  {'name': 'Cenzic', 'founded_year': 2000},
#  {'name': 'Ecommerce Solutions', 'founded_year': 2000},
#  {'name': 'Akampus', 'founded_year': 2000},
#  {'name': 'Glaxstar', 'founded_year': 2000},
#  {'name': 'Greater Than One', 'founded_year': 2000},
#  {'name': 'Wellwrittenwords', 'founded_year': 2000},
#  {'name': 'Parature', 'founded_year': 2000},
#  {'name': 'Higher One', 'founded_year': 2000},
#  {'name': 'Zong', 'founded_year': 2000},
#  {'name': 'Axosoft', 'founded_year': 2000},
#  {'name': 'Fourth Media Technologies', 'founded_year': 2000},
#  {'name': 'LocalWineEvents', 'founded_year': 2000},
#  {'name': 'Seattle Software', 'founded_year': 2000},
#  {'name': 'Fubra', 'founded_year': 2000},
#  {'name': 'eVIPlist', 'founded_year': 2000},
#  {'name': 'Visible World', 'founded_year': 2000},
#  {'name': 'ReefEdge', 'founded_year': 2000},
#  {'name': 'General Wireless', 'founded_year': 2000},
#  {'name': 'Rate Beer', 'founded_year': 2000},
#  {'name': 'Fog Creek Software', 'founded_year': 2000},
#  {'name': 'Scanbuy', 'founded_year': 2000},
#  {'name': 'Modera', 'founded_year': 2000},
#  {'name': 'Rising Sun Research', 'founded_year': 2000},
#  {'name': 'PIER Systems', 'founded_year': 2000},
#  {'name': 'Infinera Corporation', 'founded_year': 2000},
#  {'name': 'The Icon Factory', 'founded_year': 2000},
#  {'name': 'SilverStripe', 'founded_year': 2000},
#  {'name': 'AVIS eSolutions', 'founded_year': 2000},
#  {'name': 'FusionOps', 'founded_year': 2000},
#  {'name': 'YourTechOnline', 'founded_year': 2000},
#  {'name': 'Andera', 'founded_year': 2000},
#  {'name': 'Swamp Fox', 'founded_year': 2000},
#  {'name': 'Sawfish Software', 'founded_year': 2000},
#  {'name': 'deviantART', 'founded_year': 2000},
#  {'name': 'Geary Interactive', 'founded_year': 2000},
#  {'name': 'ITSportsNet', 'founded_year': 2000},
#  {'name': 'MediaRush', 'founded_year': 2000},
#  {'name': 'CompareNetworks', 'founded_year': 2000},
#  {'name': 'sph3re', 'founded_year': 2000},
#  {'name': 'Stockhouse', 'founded_year': 2000},
#  {'name': 'Vaultus Mobile', 'founded_year': 2000},
#  {'name': 'Handmark', 'founded_year': 2000},
#  {'name': 'Invensis Technologies', 'founded_year': 2000},
#  {'name': 'RMW Web Publishing', 'founded_year': 2000},
#  {'name': 'Versaly Entertainment', 'founded_year': 2000},
#  {'name': 'No Star Clothing', 'founded_year': 2000},
#  {'name': 'Navic Networks', 'founded_year': 2000},
#  {'name': 'Internet Mall', 'founded_year': 2000},
#  {'name': 'Avaya', 'founded_year': 2000},
#  {'name': 'ClickandBuy', 'founded_year': 2000},
#  {'name': 'zanox', 'founded_year': 2000},
#  {'name': 'Universal Clients', 'founded_year': 2000},
#  {'name': 'Bestofmedia Group', 'founded_year': 2000},
#  {'name': 'AnotherFriend', 'founded_year': 2000},
#  {'name': 'Gratis Internet', 'founded_year': 2000},
#  {'name': 'Astaro', 'founded_year': 2000},
#  {'name': 'ViewNow', 'founded_year': 2000},
#  {'name': 'LogicalApps', 'founded_year': 2000},
#  {'name': 'CPXi', 'founded_year': 2000},
#  {'name': 'Vodaco Web Strategies', 'founded_year': 2000},
#  {'name': 'Gammoth', 'founded_year': 2000},
#  {'name': 'Freeportway', 'founded_year': 2000},
#  {'name': 'JLOOP Rich Media', 'founded_year': 2000},
#  {'name': 'MobiComp', 'founded_year': 2000},
#  {'name': 'Clupedia', 'founded_year': 2000},
#  {'name': 'thePlatform', 'founded_year': 2000},
#  {'name': 'LifePics', 'founded_year': 2000},
#  {'name': 'Mediastay', 'founded_year': 2000},
#  {'name': 'Dot Com Infoway France', 'founded_year': 2000},
#  {'name': 'KnowNow', 'founded_year': 2000},
#  {'name': 'Synology', 'founded_year': 2000},
#  {'name': 'Unisfair', 'founded_year': 2000},
#  {'name': 'StoneFly', 'founded_year': 2000},
#  {'name': 'MixMeister', 'founded_year': 2000},
#  {'name': 'Zoomix', 'founded_year': 2000},
#  {'name': 'Caspio', 'founded_year': 2000},
#  {'name': 'Gigablast', 'founded_year': 2000},
#  {'name': 'Dexterra', 'founded_year': 2000},
#  {'name': 'Cultuzz', 'founded_year': 2000},
#  {'name': 'VISUALPLANT', 'founded_year': 2000},
#  {'name': 'Talance', 'founded_year': 2000},
#  {'name': 'Indextools', 'founded_year': 2000},
#  {'name': 'SparkPeople', 'founded_year': 2000},
#  {'name': 'Myibay', 'founded_year': 2000},
#  {'name': 'XFRIDAY', 'founded_year': 2000},
#  {'name': 'Systinet', 'founded_year': 2000},
#  {'name': 'akakce', 'founded_year': 2000},
#  {'name': 'Aurigma', 'founded_year': 2000},
#  {'name': 'Bioalma', 'founded_year': 2000},
#  {'name': 'iStreamPlanet', 'founded_year': 2000},
#  {'name': 'Carrot Communications', 'founded_year': 2000},
#  {'name': 'Telnic', 'founded_year': 2000},
#  {'name': 'NEXTA Media', 'founded_year': 2000},
#  {'name': 'Global Mind', 'founded_year': 2000},
#  {'name': 'e-Man', 'founded_year': 2000},
#  {'name': 'FinancialContent', 'founded_year': 2000},
#  {'name': 'Quova', 'founded_year': 2000},
#  {'name': 'Plastic Logic', 'founded_year': 2000},
#  {'name': 'DailyCandy', 'founded_year': 2000},
#  {'name': 'Casius', 'founded_year': 2000},
#  {'name': 'KDDI', 'founded_year': 2000},
#  {'name': 'Insyde', 'founded_year': 2000},
#  {'name': 'WorldMate', 'founded_year': 2000},
#  {'name': 'MobileAware', 'founded_year': 2000},
#  {'name': 'Recommind', 'founded_year': 2000},
#  {'name': 'Innotas', 'founded_year': 2000},
#  {'name': 'FreedomPay', 'founded_year': 2000},
#  {'name': 'Sequoia Communications', 'founded_year': 2000},
#  {'name': 'AxisMobile', 'founded_year': 2000},
#  {'name': 'Axis', 'founded_year': 2000},
#  {'name': 'Equipment Simulations', 'founded_year': 2000},
#  {'name': 'Hexacta', 'founded_year': 2000},
#  {'name': 'Adlib Software', 'founded_year': 2000},
#  {'name': 'AMAX Global Services', 'founded_year': 2000},
#  {'name': 'TimeTrade Systems', 'founded_year': 2000},
#  {'name': 'SG2', 'founded_year': 2000},
#  {'name': 'Neoris', 'founded_year': 2000},
#  {'name': 'Adaptive Technologies(ATi)', 'founded_year': 2000},
#  {'name': 'Billdesk', 'founded_year': 2000},
#  {'name': 'Spiral Shell Web LLC', 'founded_year': 2000},
#  {'name': 'KDDI', 'founded_year': 2000},
#  {'name': 'Insyde', 'founded_year': 2000},
#  {'name': 'WorldMate', 'founded_year': 2000},
#  {'name': 'MobileAware', 'founded_year': 2000},
#  {'name': 'Recommind', 'founded_year': 2000},
#  {'name': 'Innotas', 'founded_year': 2000},
#  {'name': 'FreedomPay', 'founded_year': 2000},
#  {'name': 'Sequoia Communications', 'founded_year': 2000},
#  {'name': 'AxisMobile', 'founded_year': 2000},
#  {'name': 'Axis', 'founded_year': 2000},
#  {'name': 'Equipment Simulations', 'founded_year': 2000},
#  {'name': 'Hexacta', 'founded_year': 2000},
#  {'name': 'Adlib Software', 'founded_year': 2000},
#  {'name': 'AMAX Global Services', 'founded_year': 2000},
#  {'name': 'TimeTrade Systems', 'founded_year': 2000},
#  {'name': 'SG2', 'founded_year': 2000},
#  {'name': 'Neoris', 'founded_year': 2000},
#  {'name': 'Adaptive Technologies(ATi)', 'founded_year': 2000},
#  {'name': 'Billdesk', 'founded_year': 2000},
#  {'name': 'Spiral Shell Web LLC', 'founded_year': 2000},
#  {'name': 'Zen Web Solutions', 'founded_year': 2000},
#  {'name': '3Sigma', 'founded_year': 2000},
#  {'name': 'Web CEO', 'founded_year': 2000},
#  {'name': 'nextep', 'founded_year': 2000},
#  {'name': 'Amethon Solutions', 'founded_year': 2000},
#  {'name': 'Intellectual Ventures', 'founded_year': 2000},
#  {'name': 'SEO Services Group', 'founded_year': 2000},
#  {'name': 'Jabber', 'founded_year': 2000},
#  {'name': 'Optiant', 'founded_year': 2000},
#  {'name': 'Elemica', 'founded_year': 2000},
#  {'name': 'Alpha SEP', 'founded_year': 2000},
#  {'name': 'PetitionSpot', 'founded_year': 2000},
#  {'name': 'ApartmentRatings', 'founded_year': 2000},
#  {'name': 'OQO', 'founded_year': 2000},
#  {'name': 'India Web Hosting', 'founded_year': 2000},
#  {'name': 'smashLAB', 'founded_year': 2000},
#  {'name': 'AOptix Technologies', 'founded_year': 2000},
#  {'name': 'iPhase Technologies', 'founded_year': 2000},
#  {'name': 'Precise', 'founded_year': 2000},
#  {'name': 'NativeX', 'founded_year': 2000},
#  {'name': 'Entellium', 'founded_year': 2000},
#  {'name': 'ExactTarget', 'founded_year': 2000},
#  {'name': 'Thinkingvoice', 'founded_year': 2000},
#  {'name': 'mBLAST', 'founded_year': 2000},
#  {'name': 'Agriya', 'founded_year': 2000},
#  {'name': 'MediaUnbound', 'founded_year': 2000},
#  {'name': 'Image Metrics', 'founded_year': 2000},
#  {'name': 'Quest Groups', 'founded_year': 2000},
#  {'name': 'AskMe Corp', 'founded_year': 2000},
#  {'name': 'Carat Interactive', 'founded_year': 2000},
#  {'name': 'McRaaN Systems', 'founded_year': 2000},
#  {'name': 'Bytemobile', 'founded_year': 2000},
#  {'name': 'Floor64', 'founded_year': 2000},
#  {'name': 'Motion Bridge', 'founded_year': 2000},
#  {'name': 'Alacris', 'founded_year': 2000},
#  {'name': 'Nexaweb Technologies', 'founded_year': 2000},
#  {'name': 'Indiagames', 'founded_year': 2000},
#  {'name': 'XE Corporation', 'founded_year': 2000},
#  {'name': 'Jataayu Software Ltd', 'founded_year': 2000},
#  {'name': 'Senario', 'founded_year': 2000},
#  {'name': 'Singing Fish', 'founded_year': 2000},
#  {'name': 'Red Ventures', 'founded_year': 2000},
#  {'name': 'Vividas', 'founded_year': 2000},
#  {'name': 'EdgeStream', 'founded_year': 2000},
#  {'name': 'HillCast Technologies', 'founded_year': 2000},
#  {'name': 'Arena Solutions', 'founded_year': 2000},
#  {'name': 'Booksfree', 'founded_year': 2000},
#  {'name': 'Celebros', 'founded_year': 2000},
#  {'name': 'LINKBYNET', 'founded_year': 2000},
#  {'name': 'NineSigma', 'founded_year': 2000},
#  {'name': 'Tenantplus', 'founded_year': 2000},
#  {'name': 'Machinima', 'founded_year': 2000},
#  {'name': 'Pilot Systems', 'founded_year': 2000},
#  {'name': 'Cymbet', 'founded_year': 2000},
#  {'name': 'Nantero', 'founded_year': 2000},
#  {'name': 'SkyPilot Networks', 'founded_year': 2000},
#  {'name': 'SiteBrand', 'founded_year': 2000},
#  {'name': 'Stamen Design', 'founded_year': 2000},
#  {'name': 'anaXis', 'founded_year': 2000},
#  {'name': 'Transitive', 'founded_year': 2000},
#  {'name': 'KB_Soft Group', 'founded_year': 2000},
#  {'name': 'Saurus', 'founded_year': 2000},
#  {'name': 'Attenex', 'founded_year': 2000},
#  {'name': 'Incredimail', 'founded_year': 2000},
#  {'name': 'HotLinuxJobs', 'founded_year': 2000},
#  {'name': 'Exanet', 'founded_year': 2000},
#  {'name': 'Nuxeo', 'founded_year': 2000},
#  {'name': 'SpeedyPin', 'founded_year': 2000},
#  {'name': 'Active Online', 'founded_year': 2000},
#  {'name': 'net-m', 'founded_year': 2000},
#  {'name': 'Xceligent', 'founded_year': 2000},
#  {'name': 'Vayan Marketing Group', 'founded_year': 2000},
#  {'name': 'Host Color', 'founded_year': 2000},
#  {'name': 'Hirebridge', 'founded_year': 2000},
#  {'name': 'zyntroPICS', 'founded_year': 2000},
#  {'name': 'Playtech', 'founded_year': 2000},
#  {'name': 'Liquid Fusion', 'founded_year': 2000},
#  {'name': 'Call Genie', 'founded_year': 2000},
#  {'name': 'iPixCel', 'founded_year': 2000},
#  {'name': 'SnapStream Media', 'founded_year': 2000},
#  {'name': 'MLB Advanced Media', 'founded_year': 2000},
#  {'name': 'Collective Wisdom', 'founded_year': 2000},
#  {'name': 'Ramp Technology Group', 'founded_year': 2000},
#  {'name': 'Career Crown International', 'founded_year': 2000},
#  {'name': 'Discogs', 'founded_year': 2000},
#  {'name': 'Nanomatic', 'founded_year': 2000},
#  {'name': 'US Chemist', 'founded_year': 2000},
#  {'name': 'Rainbow Partners', 'founded_year': 2000},
#  {'name': 'Amarok Multimedia', 'founded_year': 2000},
#  {'name': 'StillSecure', 'founded_year': 2000},
#  {'name': 'iPerceptions', 'founded_year': 2000},
#  {'name': 'Solavista', 'founded_year': 2000},
#  {'name': 'Dot Com Infoway', 'founded_year': 2000},
#  {'name': 'Ekahau', 'founded_year': 2000},
#  {'name': 'Masternaut UK', 'founded_year': 2000},
#  {'name': 'Forces Reunited', 'founded_year': 2000},
#  {'name': 'Bitam', 'founded_year': 2000},
#  {'name': 'E2open', 'founded_year': 2000},
#  {'name': 'Nstein Technologies', 'founded_year': 2000},
#  {'name': 'Asetek', 'founded_year': 2000},
#  {'name': 'StreamGuys', 'founded_year': 2000},
#  {'name': 'eSpace', 'founded_year': 2000},
#  {'name': 'e4e', 'founded_year': 2000},
#  {'name': 'Envivio', 'founded_year': 2000},
#  {'name': 'NTRglobal', 'founded_year': 2000},
#  {'name': 'Anystream', 'founded_year': 2000},
#  {'name': 'Aconex', 'founded_year': 2000},
#  {'name': 'BCG Attorney Search', 'founded_year': 2000},
#  {'name': 'MetaSpring', 'founded_year': 2000},
#  {'name': 'WageWorks', 'founded_year': 2000},
#  {'name': 'Advameg', 'founded_year': 2000},
#  {'name': 'Affinity Express', 'founded_year': 2000},
#  {'name': 'Adeptia', 'founded_year': 2000},
#  {'name': 'Crossbeam Systems', 'founded_year': 2000},
#  {'name': 'FierceMarkets', 'founded_year': 2000},
#  {'name': 'ONStor', 'founded_year': 2000},
#  {'name': 'Ravenflow', 'founded_year': 2000},
#  {'name': 'TriCipher', 'founded_year': 2000},
#  {'name': 'Aicent', 'founded_year': 2000},
#  {'name': 'Koves Technologies', 'founded_year': 2000},
#  {'name': 'Siperian', 'founded_year': 2000},
#  {'name': 'Daimon', 'founded_year': 2000},
#  {'name': 'PC Handyman', 'founded_year': 2000},
#  {'name': 'Open-Mind', 'founded_year': 2000},
#  {'name': 'Optimal Technologies', 'founded_year': 2000},
#  {'name': 'AscenVision Technology', 'founded_year': 2000},
#  {'name': 'Siimpel Corporation', 'founded_year': 2000},
#  {'name': 'Team Forrest', 'founded_year': 2000},
#  {'name': 'BroadLight', 'founded_year': 2000},
#  {'name': 'Wiretree', 'founded_year': 2000},
#  {'name': 'WhatCounts', 'founded_year': 2000},
#  {'name': 'Touchboards', 'founded_year': 2000},
#  {'name': 'CloudShield Technologies', 'founded_year': 2000},
#  {'name': 'GAMEVIL', 'founded_year': 2000},
#  {'name': 'YouGov', 'founded_year': 2000},
#  {'name': 'Eka Systems', 'founded_year': 2000},
#  {'name': 'Airband Communications Holdings', 'founded_year': 2000},
#  {'name': 'TechAspect Solutions', 'founded_year': 2000},
#  {'name': 'Signiant', 'founded_year': 2000},
#  {'name': 'PrimeSyn Lab', 'founded_year': 2000},
#  {'name': 'Aristos Logic', 'founded_year': 2000},
#  {'name': 'DuneNetworks', 'founded_year': 2000},
#  {'name': 'FirstRain', 'founded_year': 2000},
#  {'name': 'Slim Devices', 'founded_year': 2000},
#  {'name': 'TuVox', 'founded_year': 2000},
#  {'name': 'Backchannelmedia', 'founded_year': 2000},
#  {'name': 'Intelliden', 'founded_year': 2000},
#  {'name': 'Devicescape', 'founded_year': 2000},
#  {'name': 'Nexsan', 'founded_year': 2000},
#  {'name': 'hyperWALLET Systems', 'founded_year': 2000},
#  {'name': 'invu technology', 'founded_year': 2000},
#  {'name': 'Nilesh Roy Consultancy', 'founded_year': 2000},
#  {'name': 'Echopass Corporation', 'founded_year': 2000},
#  {'name': 'Bizclickusa', 'founded_year': 2000},
#  {'name': 'BT Fresca', 'founded_year': 2000},
#  {'name': 'Attensity', 'founded_year': 2000},
#  {'name': 'Serus', 'founded_year': 2000},
#  {'name': 'OpVista', 'founded_year': 2000},
#  {'name': 'Mazu Networks', 'founded_year': 2000},
#  {'name': 'Traiana', 'founded_year': 2000},
#  {'name': 'Bridgestream', 'founded_year': 2000},
#  {'name': 'Xelerated', 'founded_year': 2000},
#  {'name': 'Squeejee', 'founded_year': 2000},
#  {'name': 'NextHop Technologies', 'founded_year': 2000},
#  {'name': 'CipherMax', 'founded_year': 2000},
#  {'name': 'CipherTrust', 'founded_year': 2000},
#  {'name': 'TheMarkets', 'founded_year': 2000},
#  {'name': 'Skycross', 'founded_year': 2000},
#  {'name': 'FQcode True Traceability', 'founded_year': 2000},
#  {'name': 'Cambridge Broadband Networks', 'founded_year': 2000},
#  {'name': 'Axeda', 'founded_year': 2000},
#  {'name': 'GaimTheory', 'founded_year': 2000},
#  {'name': 'Adysoft', 'founded_year': 2000},
#  {'name': 'Silicon Stratgies Marketing', 'founded_year': 2000},
#  {'name': 'Icreon Communications', 'founded_year': 2000},
#  {'name': 'Shriv Commedia Solutions Pvt Ltd', 'founded_year': 2000},
#  {'name': 'Vorsite', 'founded_year': 2000},
#  {'name': 'A1-4 Electronics', 'founded_year': 2000},
#  {'name': 'Dot Com Infoway Australia', 'founded_year': 2000},
#  {'name': 'LLONA', 'founded_year': 2000},
#  {'name': 'Splash Media', 'founded_year': 2000},
#  {'name': 'Turtle Entertainment', 'founded_year': 2000},
#  {'name': 'HAPPYneuron', 'founded_year': 2000},
#  {'name': 'SEOValley', 'founded_year': 2000},
#  {'name': 'Netmaps', 'founded_year': 2000},
#  {'name': 'Netezza', 'founded_year': 2000},
#  {'name': 'IS Decisions', 'founded_year': 2000},
#  {'name': 'Geebo', 'founded_year': 2000},
#  {'name': 'NewVoiceMedia', 'founded_year': 2000},
#  {'name': 'Fabchannel', 'founded_year': 2000},
#  {'name': 'Real estate SKY', 'founded_year': 2000},
#  {'name': 'InPhase Technologies', 'founded_year': 2000},
#  {'name': 'Xact Check', 'founded_year': 2000},
#  {'name': 'ixi mobile', 'founded_year': 2000},
#  {'name': 'daysoft', 'founded_year': 2000},
#  {'name': 'Fotech', 'founded_year': 2000},
#  {'name': 'Heartscape', 'founded_year': 2000},
#  {'name': 'Kiala', 'founded_year': 2000},
#  {'name': 'picoChip', 'founded_year': 2000},
#  {'name': 'Networks in Motion', 'founded_year': 2000},
#  {'name': 'Axle IT', 'founded_year': 2000},
#  {'name': 'Lockstep Systems', 'founded_year': 2000},
#  {'name': 'AOI Marketing Group', 'founded_year': 2000},
#  {'name': 'Site Mafia Interactive', 'founded_year': 2000},
#  {'name': 'D2V', 'founded_year': 2000},
#  {'name': 'Tamarac', 'founded_year': 2000},
#  {'name': 'BusinessNameUSA', 'founded_year': 2000},
#  {'name': 'Paymate', 'founded_year': 2000},
#  {'name': 'Proper Hosting', 'founded_year': 2000},
#  {'name': 'Epsilon Concepts', 'founded_year': 2000},
#  {'name': 'SLK Software Services Pvt Ltd', 'founded_year': 2000},
#  {'name': 'StealthTech', 'founded_year': 2000},
#  {'name': 'igniteHealth', 'founded_year': 2000},
#  {'name': 'Catbird', 'founded_year': 2000},
#  {'name': 'WebFM', 'founded_year': 2000},
#  {'name': 'Red McCombs Media', 'founded_year': 2000},
#  {'name': 'Iksanika', 'founded_year': 2000},
#  {'name': 'SEOP', 'founded_year': 2000},
#  {'name': 'Azavea', 'founded_year': 2000},
#  {'name': 'Digitally Imported', 'founded_year': 2000},
#  {'name': 'Embitel', 'founded_year': 2000},
#  {'name': 'HT2', 'founded_year': 2000},
#  {'name': 'N-able Technologies', 'founded_year': 2000},
#  {'name': 'Kaseya', 'founded_year': 2000},
#  {'name': 'Symphogen', 'founded_year': 2000},
#  {'name': 'Melinta', 'founded_year': 2000},
#  {'name': 'Indienink', 'founded_year': 2000},
#  {'name': 'Dinahosting', 'founded_year': 2000},
#  {'name': 'Acotis Jewellery', 'founded_year': 2000},
#  {'name': 'Chasma', 'founded_year': 2000},
#  {'name': 'Bluewolf', 'founded_year': 2000},
#  {'name': 'MAQ Software', 'founded_year': 2000},
#  {'name': 'GMA Grading', 'founded_year': 2000},
#  {'name': 'CMS Enviro Systems', 'founded_year': 2000},
#  {'name': 'Netbiscuits', 'founded_year': 2000},
#  {'name': 'NetRetail Holding', 'founded_year': 2000},
#  {'name': 'Fulcrum Microsystems', 'founded_year': 2000},
#  {'name': 'Panasas', 'founded_year': 2000},
#  {'name': 'FocusFrame', 'founded_year': 2000},
#  {'name': 'bwired', 'founded_year': 2000},
#  {'name': 'GRNLive', 'founded_year': 2000},
#  {'name': 'Infostroy', 'founded_year': 2000},
#  {'name': 'VFM Leonardo', 'founded_year': 2000},
#  {'name': 'Corvil', 'founded_year': 2000},
#  {'name': 'MergeOptics', 'founded_year': 2000},
#  {'name': 'Qosmos', 'founded_year': 2000},
#  {'name': 'InSite Wireless', 'founded_year': 2000},
#  {'name': 'Rhapso', 'founded_year': 2000},
#  {'name': 'Ondax', 'founded_year': 2000},
#  {'name': 'SEOeconomist', 'founded_year': 2000},
#  {'name': 'Distinctive Media', 'founded_year': 2000},
#  {'name': 'Evolutionary Genomics', 'founded_year': 2000},
#  {'name': '2 Minutes', 'founded_year': 2000},
#  {'name': 'Netsonda Research', 'founded_year': 2000},
#  {'name': 'Zipcar', 'founded_year': 2000},
#  {'name': 'Sirius Forex Trading Group', 'founded_year': 2000},
#  {'name': 'uttarbharat Inc', 'founded_year': 2000},
#  {'name': 'Infosearch Media', 'founded_year': 2000},
#  {'name': 'TRIRIGA', 'founded_year': 2000},
#  {'name': 'Ambow Education', 'founded_year': 2000},
#  {'name': 'Telisma', 'founded_year': 2000},
#  {'name': 'OnMobile', 'founded_year': 2000},
#  {'name': 'Ovation Pharmaceuticals', 'founded_year': 2000},
#  {'name': 'Biofisica', 'founded_year': 2000},
#  {'name': 'Tangoe', 'founded_year': 2000},
#  {'name': 'Chiral Quest', 'founded_year': 2000},
#  {'name': 'MD-IT', 'founded_year': 2000},
#  {'name': 'S*Bio', 'founded_year': 2000},
#  {'name': 'Cornerstone Pharmaceuticals', 'founded_year': 2000},
#  {'name': 'Telenity', 'founded_year': 2000},
#  {'name': 'Polatis', 'founded_year': 2000},
#  {'name': 'Avantium Technologies', 'founded_year': 2000},
#  {'name': 'MacroGenics', 'founded_year': 2000},
#  {'name': 'Anacor Pharmaceutical', 'founded_year': 2000},
#  {'name': 'MusicIP', 'founded_year': 2000},
#  {'name': 'Baobaz', 'founded_year': 2000},
#  {'name': 'BioMed Central', 'founded_year': 2000},
#  {'name': 'THiNKmedia', 'founded_year': 2000},
#  {'name': 'm-Wise', 'founded_year': 2000},
#  {'name': 'FuckedCompany', 'founded_year': 2000},
#  {'name': 'Connectiva Systems', 'founded_year': 2000},
#  {'name': 'Seahorse Bioscience', 'founded_year': 2000},
#  {'name': 'Threadless', 'founded_year': 2000},
#  {'name': 'Silex Microsystems', 'founded_year': 2000},
#  {'name': 'Brainsgate', 'founded_year': 2000},
#  {'name': 'Audience', 'founded_year': 2000},
#  {'name': 'Intradigm Corporation', 'founded_year': 2000},
#  {'name': 'Global Data Solutions', 'founded_year': 2000},
#  {'name': 'Hythiam', 'founded_year': 2000},
#  {'name': 'mediaburst', 'founded_year': 2000},
#  {'name': 'Oesia', 'founded_year': 2000},
#  {'name': 'Schoolwires', 'founded_year': 2000},
#  {'name': 'HxTechnologies', 'founded_year': 2000},
#  {'name': 'AbCRO', 'founded_year': 2000},
#  {'name': 'Fisher Vista', 'founded_year': 2000},
#  {'name': 'XDx', 'founded_year': 2000},
#  {'name': 'Woodland Biofuels', 'founded_year': 2000},
#  {'name': 'Colibria', 'founded_year': 2000},
#  {'name': 'Kurani Interactive', 'founded_year': 2000},
#  {'name': 'Compliance 360', 'founded_year': 2000},
#  {'name': 'Nexant', 'founded_year': 2000},
#  {'name': 'Sana Security', 'founded_year': 2000},
#  {'name': 'Mind Drivers', 'founded_year': 2000},
#  {'name': 'PopCap Games', 'founded_year': 2000},
#  {'name': 'Picsearch', 'founded_year': 2000},
#  {'name': 'One97 Communications', 'founded_year': 2000},
#  {'name': 'C7 Data Centers', 'founded_year': 2000},
#  {'name': 'Recycleinme', 'founded_year': 2000},
#  {'name': 'Moonfruit', 'founded_year': 2000},
#  {'name': 'Goodman Networks', 'founded_year': 2000},
#  {'name': 'Telx', 'founded_year': 2000},
#  {'name': 'CPower', 'founded_year': 2000},
#  {'name': 'Radio Systemes Ingenierie', 'founded_year': 2000},
#  {'name': 'Prepared Response', 'founded_year': 2000},
#  {'name': 'Optium', 'founded_year': 2000},
#  {'name': 'OSA Technologies', 'founded_year': 2000},
#  {'name': 'Sanera', 'founded_year': 2000},
#  {'name': 'eXMeritus', 'founded_year': 2000},
#  {'name': 'Canevaflor', 'founded_year': 2000},
#  {'name': 'iomart Group', 'founded_year': 2000},
#  {'name': 'Everyday Solutions', 'founded_year': 2000},
#  {'name': 'NanoBio', 'founded_year': 2000},
#  {'name': 'PaymentOne', 'founded_year': 2000},
#  {'name': 'optionsXpress', 'founded_year': 2000},
#  {'name': 'Skywire Software', 'founded_year': 2000},
#  {'name': 'Sirific Wireless', 'founded_year': 2000},
#  {'name': 'LogicLibrary', 'founded_year': 2000},
#  {'name': 'Vigilos', 'founded_year': 2000},
#  {'name': 'Block Shield', 'founded_year': 2000},
#  {'name': 'Netrake', 'founded_year': 2000},
#  {'name': 'EnterSys Group', 'founded_year': 2000},
#  {'name': 'EnteGreat', 'founded_year': 2000},
#  {'name': 'TechnologyGuide', 'founded_year': 2001},
#  {'name': 'Vast', 'founded_year': 2001},
#  {'name': 'Userplane', 'founded_year': 2001},
#  {'name': 'Six Apart', 'founded_year': 2001},
#  {'name': 'SuicideGirls', 'founded_year': 2001},
#  {'name': 'Friendster', 'founded_year': 2001},
#  {'name': 'ChannelAdvisor', 'founded_year': 2001},
#  {'name': 'Jive Software', 'founded_year': 2001},
#  {'name': 'PrepMe', 'founded_year': 2001},
#  {'name': 'Shopatron', 'founded_year': 2001},
#  {'name': 'Optimost', 'founded_year': 2001},
#  {'name': 'Localeze', 'founded_year': 2001},
#  {'name': 'Skyscanner', 'founded_year': 2001},
#  {'name': 'HelioVolt', 'founded_year': 2001},
#  {'name': 'Shozu', 'founded_year': 2001},
#  {'name': 'SuccessFactors', 'founded_year': 2001},
#  {'name': 'Jellyvision', 'founded_year': 2001},
#  {'name': 'skinnyCorp', 'founded_year': 2001},
#  {'name': 'Booyah Networks', 'founded_year': 2001},
#  {'name': 'Neotonic Software', 'founded_year': 2001},
#  {'name': 'Three Rings', 'founded_year': 2001},
#  {'name': 'ChoiceStream', 'founded_year': 2001},
#  {'name': 'Gorilla Nation Media', 'founded_year': 2001},
#  {'name': 'Motionplan', 'founded_year': 2001},
#  {'name': 'Swarmcast', 'founded_year': 2001},
#  {'name': 'Animax Entertainment', 'founded_year': 2001},
#  {'name': 'Mochila', 'founded_year': 2001},
#  {'name': 'The Media Kitchen', 'founded_year': 2001},
#  {'name': 'Tectura', 'founded_year': 2001},
#  {'name': 'FatPort', 'founded_year': 2001},
#  {'name': 'Boonty', 'founded_year': 2001},
#  {'name': 'Digital-Telepathy', 'founded_year': 2001},
#  {'name': 'PacketFront', 'founded_year': 2001},
#  {'name': 'KeyEye Communications', 'founded_year': 2001},
#  {'name': 'Voxiva', 'founded_year': 2001},
#  {'name': 'Sedo', 'founded_year': 2001},
#  {'name': 'InMage Systems', 'founded_year': 2001},
#  {'name': 'WebVisible', 'founded_year': 2001},
#  {'name': 'Xtenza Solutions', 'founded_year': 2001},
#  {'name': 'Gecad Technologies', 'founded_year': 2001},
#  {'name': 'BlueCat Networks', 'founded_year': 2001},
#  {'name': 'Berkeley Design Automation', 'founded_year': 2001},
#  {'name': 'Designing Interactive', 'founded_year': 2001},
#  {'name': 'Avisena', 'founded_year': 2001},
#  {'name': 'Pure Digital Technologies', 'founded_year': 2001},
#  {'name': 'Sogeti USA', 'founded_year': 2001},
#  {'name': 'Alex Gorney Web Development', 'founded_year': 2001},
#  {'name': 'MediaWhiz', 'founded_year': 2001},
#  {'name': 'Creative Commons', 'founded_year': 2001},
#  {'name': 'UnitedLayer', 'founded_year': 2001},
#  {'name': 'ServePath', 'founded_year': 2001},
#  {'name': 'MailChimp', 'founded_year': 2001},
#  {'name': 'Red Oxygen', 'founded_year': 2001},
#  {'name': 'Yendo', 'founded_year': 2001},
#  {'name': 'Foldera', 'founded_year': 2001},
#  {'name': 'hosting365', 'founded_year': 2001},
#  {'name': 'Dilithium Networks', 'founded_year': 2001},
#  {'name': 'Esendex', 'founded_year': 2001},
#  {'name': 'TrafficZ', 'founded_year': 2001},
#  {'name': 'Hypertag', 'founded_year': 2001},
#  {'name': 'Dezide', 'founded_year': 2001},
#  {'name': 'Drawloop Technologies', 'founded_year': 2001},
#  {'name': 'OpenCircle', 'founded_year': 2001},
#  {'name': 'Atmail', 'founded_year': 2001},
#  {'name': 'Loyalty Matrix', 'founded_year': 2001},
#  {'name': 'Accenture', 'founded_year': 2001},
#  {'name': 'iBiz Software', 'founded_year': 2001},
#  {'name': 'Vocio', 'founded_year': 2001},
#  {'name': 'iWin', 'founded_year': 2001},
#  {'name': 'Acquity Group', 'founded_year': 2001},
#  {'name': 'Rove', 'founded_year': 2001},
#  {'name': 'Sputnik', 'founded_year': 2001},
#  {'name': 'Cloudmark', 'founded_year': 2001},
#  {'name': 'Fabric Interactive', 'founded_year': 2001},
#  {'name': 'Xtract', 'founded_year': 2001},
#  {'name': 'YTB', 'founded_year': 2001},
#  {'name': 'Macronimous Web Solutions', 'founded_year': 2001},
#  {'name': 'AtTask', 'founded_year': 2001},
#  {'name': 'Rally Software', 'founded_year': 2001},
#  {'name': 'Phonerental', 'founded_year': 2001},
#  {'name': 'Groove Networks', 'founded_year': 2001},
#  {'name': 'Infusionsoft', 'founded_year': 2001},
#  {'name': 'Birthday Alarm', 'founded_year': 2001},
#  {'name': 'Storagepipe', 'founded_year': 2001},
#  {'name': 'Meetic', 'founded_year': 2001},
#  {'name': 'Flex2go', 'founded_year': 2001},
#  {'name': 'Xcerion', 'founded_year': 2001},
#  {'name': 'Forcestream', 'founded_year': 2001},
#  {'name': 'FlipDog', 'founded_year': 2001},
#  {'name': 'Easyflirt', 'founded_year': 2001},
#  {'name': 'Manticore Technology', 'founded_year': 2001},
#  {'name': 'Troux Technologies', 'founded_year': 2001},
#  {'name': 'Mobile Data Now', 'founded_year': 2001},
#  {'name': 'SightSpeed', 'founded_year': 2001},
#  {'name': 'Easypano', 'founded_year': 2001},
#  {'name': 'Rhapsody', 'founded_year': 2001},
#  {'name': 'ZipcodeZ', 'founded_year': 2001},
#  {'name': 'Vonage', 'founded_year': 2001},
#  {'name': 'Copper Project', 'founded_year': 2001},
#  {'name': 'MetaCarta', 'founded_year': 2001},
#  {'name': 'Linspire', 'founded_year': 2001},
#  {'name': 'Xandros', 'founded_year': 2001},
#  {'name': 'Surgenia Productions', 'founded_year': 2001},
#  {'name': 'GoGrid', 'founded_year': 2001},
#  {'name': 'ProjectSpaces', 'founded_year': 2001},
#  {'name': 'Segway', 'founded_year': 2001},
#  {'name': 'Trinex Commercial Finance', 'founded_year': 2001},
#  {'name': 'MainNerve', 'founded_year': 2001},
#  {'name': 'Data Domain', 'founded_year': 2001},
#  {'name': 'Vimukti Tehnologies', 'founded_year': 2001},
#  {'name': 'Four Corners Development Group', 'founded_year': 2001},
#  {'name': 'Converseon', 'founded_year': 2001},
#  {'name': 'Diquest', 'founded_year': 2001},
#  {'name': 'Nexdot', 'founded_year': 2001},
#  {'name': 'Hands-On Mobile', 'founded_year': 2001},
#  {'name': 'Cynapse', 'founded_year': 2001},
#  {'name': 'BUKA', 'founded_year': 2001},
#  {'name': 'Lead411', 'founded_year': 2001},
#  {'name': 'Castle Ink Cartridges', 'founded_year': 2001},
#  {'name': 'DutchSoftware', 'founded_year': 2001},
#  {'name': 'FUNKY BUSINESS', 'founded_year': 2001},
#  {'name': 'ProForma Document Management Services', 'founded_year': 2001},
#  {'name': 'The Tin', 'founded_year': 2001},
#  {'name': 'Halogen Software', 'founded_year': 2001},
#  {'name': 'CompuBase Internet Solutions', 'founded_year': 2001},
#  {'name': 'Covarity', 'founded_year': 2001},
#  {'name': 'BuildIQ', 'founded_year': 2001},
#  {'name': 'Qualiteam Software', 'founded_year': 2001},
#  {'name': 'Kirtas Technologies', 'founded_year': 2001},
#  {'name': 'Propertyware', 'founded_year': 2001},
#  {'name': 'Ambient Devices', 'founded_year': 2001},
#  {'name': 'Kilopass', 'founded_year': 2001},
#  {'name': 'Frontier Silicon', 'founded_year': 2001},
#  {'name': 'Imprev', 'founded_year': 2001},
#  {'name': 'EnOcean', 'founded_year': 2001},
#  {'name': 'Parama Networks', 'founded_year': 2001},
#  {'name': 'Procera Networks', 'founded_year': 2001},
#  {'name': 'OMS SafeHarbor', 'founded_year': 2001},
#  {'name': 'GeoTrust', 'founded_year': 2001},
#  {'name': 'Google Japan', 'founded_year': 2001},
#  {'name': 'frankst0ned', 'founded_year': 2001},
#  {'name': 'Utagoe', 'founded_year': 2001},
#  {'name': 'Carribean International trading', 'founded_year': 2001},
#  {'name': 'Imixs', 'founded_year': 2001},
#  {'name': 'HexaCorp', 'founded_year': 2001},
#  {'name': 'Flashants', 'founded_year': 2001},
#  {'name': 'IT Matters', 'founded_year': 2001},
#  {'name': 'GolterGraphix', 'founded_year': 2001},
#  {'name': 'IdeaBlade', 'founded_year': 2001},
#  {'name': 'Vichara Technologies', 'founded_year': 2001},
#  {'name': 'Ambient Devices', 'founded_year': 2001},
#  {'name': 'Kilopass', 'founded_year': 2001},
#  {'name': 'Frontier Silicon', 'founded_year': 2001},
#  {'name': 'Imprev', 'founded_year': 2001},
#  {'name': 'EnOcean', 'founded_year': 2001},
#  {'name': 'Parama Networks', 'founded_year': 2001},
#  {'name': 'Procera Networks', 'founded_year': 2001},
#  {'name': 'OMS SafeHarbor', 'founded_year': 2001},
#  {'name': 'GeoTrust', 'founded_year': 2001},
#  {'name': 'Google Japan', 'founded_year': 2001},
#  {'name': 'frankst0ned', 'founded_year': 2001},
#  {'name': 'Utagoe', 'founded_year': 2001},
#  {'name': 'Carribean International trading', 'founded_year': 2001},
#  {'name': 'Imixs', 'founded_year': 2001},
#  {'name': 'HexaCorp', 'founded_year': 2001},
#  {'name': 'Flashants', 'founded_year': 2001},
#  {'name': 'IT Matters', 'founded_year': 2001},
#  {'name': 'GolterGraphix', 'founded_year': 2001},
#  {'name': 'IdeaBlade', 'founded_year': 2001},
#  {'name': 'Vichara Technologies', 'founded_year': 2001},
#  {'name': 'Open Lab', 'founded_year': 2001},
#  {'name': 'Frontline Selling', 'founded_year': 2001},
#  {'name': 'SK Net Service Company Ltd', 'founded_year': 2001},
#  {'name': 'Infinity Pharmaceuticals', 'founded_year': 2001},
#  {'name': 'Apogee Search', 'founded_year': 2001},
#  {'name': 'Enspire Learning', 'founded_year': 2001},
#  {'name': 'Smiley Media', 'founded_year': 2001},
#  {'name': 'Servoy', 'founded_year': 2001},
#  {'name': 'eWrite', 'founded_year': 2001},
#  {'name': 'Architel LP', 'founded_year': 2001},
#  {'name': 'DataCrunch', 'founded_year': 2001},
#  {'name': 'Big Nerd Ranch Consulting', 'founded_year': 2001},
#  {'name': 'Verdisoft', 'founded_year': 2001},
#  {'name': 'Kodiak Networks', 'founded_year': 2001},
#  {'name': 'PlumChoice', 'founded_year': 2001},
#  {'name': 'Papercheck', 'founded_year': 2001},
#  {'name': 'Sitecore', 'founded_year': 2001},
#  {'name': 'Naughty America', 'founded_year': 2001},
#  {'name': 'Apaja', 'founded_year': 2001},
#  {'name': 'AMF Ventures', 'founded_year': 2001},
#  {'name': 'Edoceo', 'founded_year': 2001},
#  {'name': 'Xceed', 'founded_year': 2001},
#  {'name': 'The Hyperfactory', 'founded_year': 2001},
#  {'name': 'Large Animal Games', 'founded_year': 2001},
#  {'name': 'Microsupply', 'founded_year': 2001},
#  {'name': 'FatTail', 'founded_year': 2001},
#  {'name': 'Webgineers', 'founded_year': 2001},
#  {'name': 'Ukash', 'founded_year': 2001},
#  {'name': 'SharperAgent', 'founded_year': 2001},
#  {'name': 'RigNet', 'founded_year': 2001},
#  {'name': 'Screen Tonic', 'founded_year': 2001},
#  {'name': 'Mobile Factory', 'founded_year': 2001},
#  {'name': 'Kirusa', 'founded_year': 2001},
#  {'name': 'Pharmacy OneSource', 'founded_year': 2001},
#  {'name': 'Mezimedia', 'founded_year': 2001},
#  {'name': 'Scate Technologies', 'founded_year': 2001},
#  {'name': 'OpenEdit', 'founded_year': 2001},
#  {'name': 'Netviewer', 'founded_year': 2001},
#  {'name': 'Big Nerd Ranch', 'founded_year': 2001},
#  {'name': 'Ponton Consulting', 'founded_year': 2001},
#  {'name': 'Centro', 'founded_year': 2001},
#  {'name': 'CTL Europe', 'founded_year': 2001},
#  {'name': 'iKobo', 'founded_year': 2001},
#  {'name': 'Privaris', 'founded_year': 2001},
#  {'name': 'Media River', 'founded_year': 2001},
#  {'name': 'Metropolitan Regional Information Systems', 'founded_year': 2001},
#  {'name': 'SLI Systems', 'founded_year': 2001},
#  {'name': 'The Jonah Group', 'founded_year': 2001},
#  {'name': 'InnoCentive', 'founded_year': 2001},
#  {'name': 'Autotask', 'founded_year': 2001},
#  {'name': 'Finacity', 'founded_year': 2001},
#  {'name': 'AmeriGlide', 'founded_year': 2001},
#  {'name': '32bytes', 'founded_year': 2001},
#  {'name': 'SEOMatrix', 'founded_year': 2001},
#  {'name': 'Apptera', 'founded_year': 2001},
#  {'name': 'Carnegie Speech', 'founded_year': 2001},
#  {'name': 'Miniclip', 'founded_year': 2001},
#  {'name': 'VicMan Software', 'founded_year': 2001},
#  {'name': 'Mindreef', 'founded_year': 2001},
#  {'name': 'Xendex Holding', 'founded_year': 2001},
#  {'name': 'Epok', 'founded_year': 2001},
#  {'name': 'Hosted Solutions', 'founded_year': 2001},
#  {'name': 'FirstDIBZ', 'founded_year': 2001},
#  {'name': 'Navio Systems', 'founded_year': 2001},
#  {'name': 'ForeSoft', 'founded_year': 2001},
#  {'name': 'ClearSight Networks', 'founded_year': 2001},
#  {'name': 'Clew', 'founded_year': 2001},
#  {'name': 'Campusbooks4less', 'founded_year': 2001},
#  {'name': 'Cubic Compass', 'founded_year': 2001},
#  {'name': 'Unicorn Solutions', 'founded_year': 2001},
#  {'name': 'SMA Informatics', 'founded_year': 2001},
#  {'name': 'Masstech Group', 'founded_year': 2001},
#  {'name': 'CrownPeak', 'founded_year': 2001},
#  {'name': 'Decru', 'founded_year': 2001},
#  {'name': 'SmartEquip', 'founded_year': 2001},
#  {'name': 'Brightegg', 'founded_year': 2001},
#  {'name': 'AppLabs', 'founded_year': 2001},
#  {'name': 'MarketForward', 'founded_year': 2001},
#  {'name': 'Ad Giants', 'founded_year': 2001},
#  {'name': 'Vontu', 'founded_year': 2001},
#  {'name': 'Proxibid', 'founded_year': 2001},
#  {'name': 'Consileon Business Consultancy GmbH', 'founded_year': 2001},
#  {'name': 'Sencia', 'founded_year': 2001},
#  {'name': 'The WebMan Network', 'founded_year': 2001},
#  {'name': 'IP2Location', 'founded_year': 2001},
#  {'name': 'CoKinetic Systems Corp', 'founded_year': 2001},
#  {'name': 'SMAF associates Law Firm', 'founded_year': 2001},
#  {'name': 'Peperoni', 'founded_year': 2001},
#  {'name': 'Clear2Pay', 'founded_year': 2001},
#  {'name': 'Jaspersoft', 'founded_year': 2001},
#  {'name': 'FileVision', 'founded_year': 2001},
#  {'name': 'FlightStats', 'founded_year': 2001},
#  {'name': 'WhiteHat Security', 'founded_year': 2001},
#  {'name': 'EoPlex Technologies', 'founded_year': 2001},
#  {'name': 'Stratavia', 'founded_year': 2001},
#  {'name': 'Frumster', 'founded_year': 2001},
#  {'name': 'Safari Books Online', 'founded_year': 2001},
#  {'name': 'Liquid Engines', 'founded_year': 2001},
#  {'name': 'Traverse Networks', 'founded_year': 2001},
#  {'name': 'Hannon Hill', 'founded_year': 2001},
#  {'name': 'InfoEther', 'founded_year': 2001},
#  {'name': 'Five9', 'founded_year': 2001},
#  {'name': 'Clarus Systems', 'founded_year': 2001},
#  {'name': 'Spring Mobile Solutions', 'founded_year': 2001},
#  {'name': 'Rage Frameworks', 'founded_year': 2001},
#  {'name': 'Dropfire', 'founded_year': 2001},
#  {'name': 'Cortina Systems', 'founded_year': 2001},
#  {'name': 'MyRealPage', 'founded_year': 2001},
#  {'name': 'NorthStar Systems International', 'founded_year': 2001},
#  {'name': 'Rapport', 'founded_year': 2001},
#  {'name': 'Webrageous Studios', 'founded_year': 2001},
#  {'name': 'Infrant Technologies', 'founded_year': 2001},
#  {'name': 'PhoneFactor', 'founded_year': 2001},
#  {'name': 'Asoka', 'founded_year': 2001},
#  {'name': 'Artifact Software', 'founded_year': 2001},
#  {'name': 'Voxify', 'founded_year': 2001},
#  {'name': 'NetAsturias Internet', 'founded_year': 2001},
#  {'name': 'TransGaming', 'founded_year': 2001},
#  {'name': 'Flarium', 'founded_year': 2001},
#  {'name': 'ITM Software', 'founded_year': 2001},
#  {'name': 'Yolk', 'founded_year': 2001},
#  {'name': 'Symwave', 'founded_year': 2001},
#  {'name': 'Saffron Brand Consultants', 'founded_year': 2001},
#  {'name': 'HYFN', 'founded_year': 2001},
#  {'name': 'Spreadtrum Communications', 'founded_year': 2001},
#  {'name': 'Glu Mobile', 'founded_year': 2001},
#  {'name': 'Firethorn', 'founded_year': 2001},
#  {'name': 'Websiteprojects', 'founded_year': 2001},
#  {'name': 'Neocase Software', 'founded_year': 2001},
#  {'name': 'Atrenta', 'founded_year': 2001},
#  {'name': 'Team Rubber', 'founded_year': 2001},
#  {'name': 'Tobii Technology', 'founded_year': 2001},
#  {'name': 'Visage Mobile', 'founded_year': 2001},
#  {'name': 'Vista Research', 'founded_year': 2001},
#  {'name': 'Code Authority Custom Software', 'founded_year': 2001},
#  {'name': 'Litepoint', 'founded_year': 2001},
#  {'name': 'Sittercity', 'founded_year': 2001},
#  {'name': 'Manifest Digital', 'founded_year': 2001},
#  {'name': 'Masabi', 'founded_year': 2001},
#  {'name': 'ELP', 'founded_year': 2001},
#  {'name': 'Metricus', 'founded_year': 2001},
#  {'name': 'TopCoder', 'founded_year': 2001},
#  {'name': 'ABCO TECHNOLOGY', 'founded_year': 2001},
#  {'name': 'Designing Digitally', 'founded_year': 2001},
#  {'name': 'WIT Software', 'founded_year': 2001},
#  {'name': 'Artionet', 'founded_year': 2001},
#  {'name': 'BPower House', 'founded_year': 2001},
#  {'name': 'TimeLog', 'founded_year': 2001},
#  {'name': 'Pivotal Concept', 'founded_year': 2001},
#  {'name': 'TicketBiscuit', 'founded_year': 2001},
#  {'name': 'Sourcefire', 'founded_year': 2001},
#  {'name': 'Apalon', 'founded_year': 2001},
#  {'name': 'Umbraco', 'founded_year': 2001},
#  {'name': 'Ekartha', 'founded_year': 2001},
#  {'name': 'Tech Support 4 NYC', 'founded_year': 2001},
#  {'name': 'Preface Media', 'founded_year': 2001},
#  {'name': 'Dyn', 'founded_year': 2001},
#  {'name': 'Binserver', 'founded_year': 2001},
#  {'name': 'SchemaLogic', 'founded_year': 2001},
#  {'name': 'Verdiem', 'founded_year': 2001},
#  {'name': 'Dmailer', 'founded_year': 2001},
#  {'name': 'Liberty League International', 'founded_year': 2001},
#  {'name': 'Chronicle Solutions', 'founded_year': 2001},
#  {'name': 'RedVision System', 'founded_year': 2001},
#  {'name': 'Touchpaper', 'founded_year': 2001},
#  {'name': 'Javaground', 'founded_year': 2001},
#  {'name': 'StudioEmotion', 'founded_year': 2001},
#  {'name': 'Adityaa Call Centre', 'founded_year': 2001},
#  {'name': 'Production Media Network', 'founded_year': 2001},
#  {'name': 'NetMotion Wireless', 'founded_year': 2001},
#  {'name': 'ToonUps', 'founded_year': 2001},
#  {'name': 'Verisim', 'founded_year': 2001},
#  {'name': '25 Pixels Media', 'founded_year': 2001},
#  {'name': 'SmartReply', 'founded_year': 2001},
#  {'name': 'ContractPal', 'founded_year': 2001},
#  {'name': 'Greetz', 'founded_year': 2001},
#  {'name': 'Synacor', 'founded_year': 2001},
#  {'name': 'TIS India', 'founded_year': 2001},
#  {'name': 'Lingo24', 'founded_year': 2001},
#  {'name': 'Net Aspects', 'founded_year': 2001},
#  {'name': 'ControlCircle', 'founded_year': 2001},
#  {'name': 'Talent Alliance', 'founded_year': 2001},
#  {'name': 'GlassHouse Technologies', 'founded_year': 2001},
#  {'name': 'Groxis', 'founded_year': 2001},
#  {'name': 'Foviance', 'founded_year': 2001},
#  {'name': 'AbodesIndia', 'founded_year': 2001},
#  {'name': 'Mindgruve', 'founded_year': 2001},
#  {'name': 'Smart AdServer', 'founded_year': 2001},
#  {'name': 'Sierra Logic', 'founded_year': 2001},
#  {'name': 'Two Animators! LLP', 'founded_year': 2001},
#  {'name': 'StoredIQ', 'founded_year': 2001},
#  {'name': 'Cat on the Couch Productions', 'founded_year': 2001},
#  {'name': 'ServiceRelated', 'founded_year': 2001},
#  {'name': 'Pelikan Technologies', 'founded_year': 2001},
#  {'name': 'Nirix', 'founded_year': 2001},
#  {'name': 'Cinetic Media', 'founded_year': 2001},
#  {'name': 'eG Innovations', 'founded_year': 2001},
#  {'name': 'Websystems, inc', 'founded_year': 2001},
#  {'name': 'Centralis', 'founded_year': 2001},
#  {'name': 'Minecode', 'founded_year': 2001},
#  {'name': 'Phonevalley', 'founded_year': 2001},
#  {'name': 'Metreos Corporation', 'founded_year': 2001},
#  {'name': 'NaturalMotion', 'founded_year': 2001},
#  {'name': 'Control Group', 'founded_year': 2001},
#  {'name': 'Tomoye Community Software', 'founded_year': 2001},
#  {'name': 'Invenergy', 'founded_year': 2001},
#  {'name': 'Taigen', 'founded_year': 2001},
#  {'name': 'Bullhorn', 'founded_year': 2001},
#  {'name': 'CoreOptics', 'founded_year': 2001},
#  {'name': 'NetroStar', 'founded_year': 2001},
#  {'name': 'Antepo', 'founded_year': 2001},
#  {'name': 'Brandspace', 'founded_year': 2001},
#  {'name': 'Baytech Webs', 'founded_year': 2001},
#  {'name': 'Celtro', 'founded_year': 2001},
#  {'name': 'X3 Studios', 'founded_year': 2001},
#  {'name': 'Eglue Business Technologies', 'founded_year': 2001},
#  {'name': 'Host Analytics', 'founded_year': 2001},
#  {'name': 'Velti', 'founded_year': 2001},
#  {'name': 'Razorsight', 'founded_year': 2001},
#  {'name': 'Emmaus Designs', 'founded_year': 2001},
#  {'name': 'Minyanville', 'founded_year': 2001},
#  {'name': 'BetterTrades', 'founded_year': 2001},
#  {'name': 'Shqiperia Com', 'founded_year': 2001},
#  {'name': 'Pro-Technologies', 'founded_year': 2001},
#  {'name': 'Internet Marketing Consultant', 'founded_year': 2001},
#  {'name': 'Domainex', 'founded_year': 2001},
#  {'name': 'WysDM Software', 'founded_year': 2001},
#  {'name': 'Oxatis', 'founded_year': 2001},
#  {'name': 'Partners Marketing Group', 'founded_year': 2001},
#  {'name': 'AppIQ', 'founded_year': 2001},
#  {'name': 'BuildForge', 'founded_year': 2001},
#  {'name': 'Qingdao Land of State Power Environment Engineering',
#   'founded_year': 2001},
#  {'name': 'Apieron', 'founded_year': 2001},
#  {'name': 'Solace Systems', 'founded_year': 2001},
#  {'name': 'ObjectSharp', 'founded_year': 2001},
#  {'name': 'eIQnetworks', 'founded_year': 2001},
#  {'name': 'Red Javelin Communications', 'founded_year': 2001},
#  {'name': 'Hydra Biosciences', 'founded_year': 2001},
#  {'name': 'Motion Computing', 'founded_year': 2001},
#  {'name': 'KaloBios Pharmaceuticals', 'founded_year': 2001},
#  {'name': 'TextMagic', 'founded_year': 2001},
#  {'name': 'CareGain', 'founded_year': 2001},
#  {'name': 'Brogent Technologies', 'founded_year': 2001},
#  {'name': 'ReportLinker', 'founded_year': 2001},
#  {'name': 'Pegasys', 'founded_year': 2001},
#  {'name': 'Costume Craze', 'founded_year': 2001},
#  {'name': 'Infinite Power Solutions', 'founded_year': 2001},
#  {'name': 'Lime Kiln Camera', 'founded_year': 2001},
#  {'name': 'Proteon Therapeutics', 'founded_year': 2001},
#  {'name': 'Ntech Industries', 'founded_year': 2001},
#  {'name': 'Fresh Echo Interactive', 'founded_year': 2001},
#  {'name': 'Generous Gems Jewelry', 'founded_year': 2001},
#  {'name': 'Idealo', 'founded_year': 2001},
#  {'name': 'Mailout Interactive', 'founded_year': 2001},
#  {'name': 'PIERIS Proteolab', 'founded_year': 2001},
#  {'name': 'Agrisoma Biosciences', 'founded_year': 2001},
#  {'name': 'Mediamobile', 'founded_year': 2001},
#  {'name': 'Luca Technologies', 'founded_year': 2001},
#  {'name': 'Glaukos', 'founded_year': 2001},
#  {'name': 'Accera', 'founded_year': 2001},
#  {'name': 'Zugara', 'founded_year': 2001},
#  {'name': 'Enpirion', 'founded_year': 2001},
#  {'name': 'Visiogen', 'founded_year': 2001},
#  {'name': 'Premier Power', 'founded_year': 2001},
#  {'name': 'Altivation Software', 'founded_year': 2001},
#  {'name': 'Aspen Aerogels', 'founded_year': 2001},
#  {'name': 'Neosens', 'founded_year': 2001},
#  {'name': 'AlterPoint', 'founded_year': 2001},
#  {'name': 'Darby Corporate Solutions', 'founded_year': 2001},
#  {'name': 'Telogis', 'founded_year': 2001},
#  {'name': 'Jalios', 'founded_year': 2001},
#  {'name': 'Purple Labs', 'founded_year': 2001},
#  {'name': 'Infrasolve', 'founded_year': 2001},
#  {'name': 'Bamboo Media Casting', 'founded_year': 2001},
#  {'name': 'StreamUK', 'founded_year': 2001},
#  {'name': 'MentorMate', 'founded_year': 2001},
#  {'name': 'Vativ Technologies', 'founded_year': 2001},
#  {'name': 'BzzAgent', 'founded_year': 2001},
#  {'name': 'Axway', 'founded_year': 2001},
#  {'name': 'CognitiveDATA', 'founded_year': 2001},
#  {'name': 'Media Whiz', 'founded_year': 2001},
#  {'name': 'Anchor Bay Technologies', 'founded_year': 2001},
#  {'name': 'Kineto Wireless', 'founded_year': 2001},
#  {'name': 'Airespace', 'founded_year': 2001},
#  {'name': 'ColdSpark', 'founded_year': 2001},
#  {'name': 'm35 Limited', 'founded_year': 2001},
#  {'name': 'Translucent', 'founded_year': 2001},
#  {'name': 'InfoLogix', 'founded_year': 2001},
#  {'name': 'Ponte Solutions', 'founded_year': 2001},
#  {'name': 'Abraxas', 'founded_year': 2001},
#  {'name': 'SOA Software', 'founded_year': 2001},
#  {'name': 'Edgeos', 'founded_year': 2001},
#  {'name': 'CScout Japan', 'founded_year': 2001},
#  {'name': 'Cameron Health', 'founded_year': 2001},
#  {'name': 'StumbleUpon', 'founded_year': 2002},
#  {'name': 'Plaxo', 'founded_year': 2002},
#  {'name': 'Technorati', 'founded_year': 2002},
#  {'name': 'Meetup', 'founded_year': 2002},
#  {'name': 'SmugMug', 'founded_year': 2002},
#  {'name': 'Topix', 'founded_year': 2002},
#  {'name': 'CornerWorld', 'founded_year': 2002},
#  {'name': 'iLike', 'founded_year': 2002},
#  {'name': 'Spreadshirt', 'founded_year': 2002},
#  {'name': 'Socialtext', 'founded_year': 2002},
#  {'name': 'Cerado', 'founded_year': 2002},
#  {'name': 'Fathom Online', 'founded_year': 2002},
#  {'name': 'BitPass', 'founded_year': 2002},
#  {'name': 'Netblue', 'founded_year': 2002},
#  {'name': 'Fotolog', 'founded_year': 2002},
#  ...]

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
list(colec.find({'$and':[{'ipo.valuation_amount':{'$gte':1e8}}, 
                         {'founded_year':{'$lt':2010}}
                          ]},
                
                {'name':1,'ipo.valuation_amount':1,'_id':0}))
# Out:
# [{'name': 'Facebook', 'ipo': {'valuation_amount': 104000000000}},
#  {'name': 'Twitter', 'ipo': {'valuation_amount': 18100000000}},
#  {'name': 'Yelp', 'ipo': {'valuation_amount': 1300000000}},
#  {'name': 'LinkedIn', 'ipo': {'valuation_amount': 9310000000}},
#  {'name': 'Amazon', 'ipo': {'valuation_amount': 100000000000}},
#  {'name': 'Brightcove', 'ipo': {'valuation_amount': 290000000}},
#  {'name': 'KIT digital', 'ipo': {'valuation_amount': 235000000}},
#  {'name': 'Nielsen', 'ipo': {'valuation_amount': 1600000000}},
#  {'name': 'OpenTable', 'ipo': {'valuation_amount': 1050000000}},
#  {'name': 'ChannelAdvisor', 'ipo': {'valuation_amount': 287000000}},
#  {'name': 'Jive Software', 'ipo': {'valuation_amount': 1000000000}},
#  {'name': 'Zillow', 'ipo': {'valuation_amount': 2550000000}},
#  {'name': 'Wix', 'ipo': {'valuation_amount': 750000000}},
#  {'name': 'Shutterfly', 'ipo': {'valuation_amount': 350000000}},
#  {'name': 'TripAdvisor', 'ipo': {'valuation_amount': 3273770000}},
#  {'name': 'Salesforce', 'ipo': {'valuation_amount': 110000000}},
#  {'name': 'HomeAway', 'ipo': {'valuation_amount': 3000000000}},
#  {'name': 'QuinStreet', 'ipo': {'valuation_amount': 140000000}},
#  {'name': 'Rackspace', 'ipo': {'valuation_amount': 5440000000}},
#  {'name': 'BMC Software', 'ipo': {'valuation_amount': 6000000000}},
#  {'name': 'Higher One', 'ipo': {'valuation_amount': 1060000000}},
#  {'name': 'Infoblox', 'ipo': {'valuation_amount': 824000000}},
#  {'name': 'Tencent', 'ipo': {'valuation_amount': 11000000000}},
#  {'name': 'Marketo', 'ipo': {'valuation_amount': 465000000}},
#  {'name': 'Baidu', 'ipo': {'valuation_amount': 4000000000}},
#  {'name': 'Geeknet', 'ipo': {'valuation_amount': 134000000}},
#  {'name': 'Opsware', 'ipo': {'valuation_amount': 450000000}},
#  {'name': 'Telenav', 'ipo': {'valuation_amount': 337000000}},
#  {'name': 'Rally Software', 'ipo': {'valuation_amount': 315000000}},
#  {'name': 'BrightSource Energy', 'ipo': {'valuation_amount': 1000000000}},
#  {'name': 'Mixi', 'ipo': {'valuation_amount': 970000000}},
#  {'name': 'QlikTech', 'ipo': {'valuation_amount': 1000000000}},
#  {'name': 'Chegg', 'ipo': {'valuation_amount': 1100000000}},
#  {'name': 'Chegg', 'ipo': {'valuation_amount': 1100000000}},
#  {'name': 'Groupon', 'ipo': {'valuation_amount': 12800000000}},
#  {'name': 'SolarWinds', 'ipo': {'valuation_amount': 803000000}},
#  {'name': 'GREE', 'ipo': {'valuation_amount': 108960000000}},
#  {'name': 'Tudou', 'ipo': {'valuation_amount': 174000000}},
#  {'name': 'DemandTec', 'ipo': {'valuation_amount': 245000000}},
#  {'name': 'Cornerstone OnDemand', 'ipo': {'valuation_amount': 900000000}},
#  {'name': 'Western Digital', 'ipo': {'valuation_amount': 9430000000}},
#  {'name': 'Millennial Media', 'ipo': {'valuation_amount': 973500000}}]

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
list(colec.find({'$and':[{'number_of_employees':{'$lt':1e3}},
                        {'founded_year':{'$lt':2005}}]},

                {'name':1, '_id':0, 'number_of_employees':1, 'founded_year':1}).sort('number_of_employees',-1).limit(10))
# Out:
# [{'name': 'Infinera Corporation',
#   'number_of_employees': 974,
#   'founded_year': 2000},
#  {'name': 'NorthPoint Communications Group',
#   'number_of_employees': 948,
#   'founded_year': 1997},
#  {'name': '888 Holdings', 'number_of_employees': 931, 'founded_year': 1997},
#  {'name': 'Forrester Research',
#   'number_of_employees': 903,
#   'founded_year': 1983},
#  {'name': 'SonicWALL', 'number_of_employees': 900, 'founded_year': 1991},
#  {'name': 'Webmetrics', 'number_of_employees': 900, 'founded_year': 1999},
#  {'name': 'Cornerstone OnDemand',
#   'number_of_employees': 881,
#   'founded_year': 1999},
#  {'name': 'Mozilla', 'number_of_employees': 800, 'founded_year': 1998},
#  {'name': 'Buongiorno', 'number_of_employees': 800, 'founded_year': 1999},
#  {'name': 'Yelp', 'number_of_employees': 800, 'founded_year': 2004}]

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
list(colec.find({'partners':{'$exists':False}},{'name':1, '_id':0, 'partners':1}))
# Out:
# []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
list(colec.find({'category_code':None},{'name':1, '_id':0, 'category_code':1}))
# Out:
# [{'name': 'Collective', 'category_code': None},
#  {'name': 'Snimmer', 'category_code': None},
#  {'name': 'KoolIM', 'category_code': None},
#  {'name': 'Level9 Media', 'category_code': None},
#  {'name': 'VidKing', 'category_code': None},
#  {'name': 'Drigg', 'category_code': None},
#  {'name': 'SpaceTime', 'category_code': None},
#  {'name': 'Touch Clarity', 'category_code': None},
#  {'name': 'MMDAYS', 'category_code': None},
#  {'name': 'Inside Group', 'category_code': None},
#  {'name': 'Repeater Store', 'category_code': None},
#  {'name': 'Tapesh', 'category_code': None},
#  {'name': 'iPersians', 'category_code': None},
#  {'name': 'NewPersia', 'category_code': None},
#  {'name': 'Pyra Labs', 'category_code': None},
#  {'name': 'Feedmap', 'category_code': None},
#  {'name': 'NuvoMedia', 'category_code': None},
#  {'name': 'Intwine', 'category_code': None},
#  {'name': 'The Weinstein Company', 'category_code': None},
#  {'name': 'ExecuNet', 'category_code': None},
#  {'name': 'A1Vacations', 'category_code': None},
#  {'name': 'TripHomes', 'category_code': None},
#  {'name': 'Picturehouse', 'category_code': None},
#  {'name': 'Covalent Technologies', 'category_code': None},
#  {'name': 'Epic Trip', 'category_code': None},
#  {'name': 'Telepost', 'category_code': None},
#  {'name': 'Fidelity', 'category_code': None},
#  {'name': 'Quirk', 'category_code': None},
#  {'name': 'Skyrove', 'category_code': None},
#  {'name': 'Leechblock', 'category_code': None},
#  {'name': 'My Success Gateway', 'category_code': None},
#  {'name': 'RealNames', 'category_code': None},
#  {'name': 'The Easynet Group', 'category_code': None},
#  {'name': 'NetNames', 'category_code': None},
#  {'name': 'Sniperoo', 'category_code': None},
#  {'name': 'JD Project', 'category_code': None},
#  {'name': 'ABC News', 'category_code': None},
#  {'name': 'Teoma Technologies', 'category_code': None},
#  {'name': 'cometro', 'category_code': None},
#  {'name': 'U-Cast', 'category_code': None},
#  {'name': 'TechJuicer', 'category_code': None},
#  {'name': 'Fnatic', 'category_code': None},
#  {'name': 'Sports Gamer', 'category_code': None},
#  {'name': 'Infraworks', 'category_code': None},
#  {'name': 'MessageOne', 'category_code': None},
#  {'name': 'Idealab', 'category_code': None},
#  {'name': 'Invitastic', 'category_code': None},
#  {'name': 'Windows Live Events', 'category_code': None},
#  {'name': 'News Futures', 'category_code': None},
#  {'name': 'Foresight Exchange', 'category_code': None},
#  {'name': 'Greenspun', 'category_code': None},
#  {'name': 'American Solutions', 'category_code': None},
#  {'name': 'Media Run', 'category_code': None},
#  {'name': 'Tonic Studios', 'category_code': None},
#  {'name': 'USLegalForms', 'category_code': None},
#  {'name': 'Livevault', 'category_code': None},
#  {'name': 'Vector Capital', 'category_code': None},
#  {'name': 'Neudesic', 'category_code': None},
#  {'name': 'TuneCircle', 'category_code': None},
#  {'name': 'Hotbar', 'category_code': None},
#  {'name': 'eWeb Productions', 'category_code': None},
#  {'name': 'FatPort', 'category_code': None},
#  {'name': 'Excilan SA', 'category_code': None},
#  {'name': 'SEO Toolset', 'category_code': None},
#  {'name': 'ClarityBlue', 'category_code': None},
#  {'name': 'Reuters', 'category_code': None},
#  {'name': 'Guru', 'category_code': None},
#  {'name': 'Paxfire', 'category_code': None},
#  {'name': 'Digital-Telepathy', 'category_code': None},
#  {'name': 'Pidgin Technologies', 'category_code': None},
#  {'name': 'Time Lending California', 'category_code': None},
#  {'name': 'Gazprom-Media', 'category_code': None},
#  {'name': 'reQall', 'category_code': None},
#  {'name': 'Fon11', 'category_code': None},
#  {'name': 'Quicken Online', 'category_code': None},
#  {'name': 'Pooxi', 'category_code': None},
#  {'name': 'Mfuse', 'category_code': None},
#  {'name': 'Moconso', 'category_code': None},
#  {'name': 'Everysport', 'category_code': None},
#  {'name': 'Menmo', 'category_code': None},
#  {'name': 'IntelliPath', 'category_code': None},
#  {'name': 'ATR International', 'category_code': None},
#  {'name': 'Personiva', 'category_code': None},
#  {'name': 'IPE', 'category_code': None},
#  {'name': 'FloVox', 'category_code': None},
#  {'name': 'Jasper Design', 'category_code': None},
#  {'name': 'NVCA', 'category_code': None},
#  {'name': 'The Privacy Council', 'category_code': None},
#  {'name': 'Saban Media Group', 'category_code': None},
#  {'name': 'Norg Media', 'category_code': None},
#  {'name': 'mojungle', 'category_code': None},
#  {'name': 'Social Actions', 'category_code': None},
#  {'name': 'Podbop', 'category_code': None},
#  {'name': 'The Planet', 'category_code': None},
#  {'name': '500 Hats', 'category_code': None},
#  {'name': 'GoDaddy', 'category_code': None},
#  {'name': 'iModo', 'category_code': None},
#  {'name': 'iCat', 'category_code': None},
#  {'name': 'ontheFRONTIER', 'category_code': None},
#  {'name': 'Prologue', 'category_code': None},
#  {'name': 'Vipahealth', 'category_code': None},
#  {'name': 'eLabor', 'category_code': None},
#  {'name': 'Groundwork Equicy', 'category_code': None},
#  {'name': 'SynerDyne', 'category_code': None},
#  {'name': 'NEC', 'category_code': None},
#  {'name': 'Masai', 'category_code': None},
#  {'name': 'My Wedding', 'category_code': None},
#  {'name': 'Wedding Channel', 'category_code': None},
#  {'name': 'Wedding Jack', 'category_code': None},
#  {'name': 'On Demand Books', 'category_code': None},
#  {'name': 'GoToMeeting', 'category_code': None},
#  {'name': 'NetCreations', 'category_code': None},
#  {'name': 'PrimeTimeRewind', 'category_code': None},
#  {'name': 'efanguide', 'category_code': None},
#  {'name': 'Greater Than One', 'category_code': None},
#  {'name': 'Slice The Pie', 'category_code': None},
#  {'name': 'GreenLight Media', 'category_code': None},
#  {'name': 'The Orchard', 'category_code': None},
#  {'name': 'TangledMesh', 'category_code': None},
#  {'name': 'FolioLink', 'category_code': None},
#  {'name': 'ferium', 'category_code': None},
#  {'name': 'Epoq US', 'category_code': None},
#  {'name': 'ThinkFreeDocs', 'category_code': None},
#  {'name': 'Carsonified', 'category_code': None},
#  {'name': 'Runwild', 'category_code': None},
#  {'name': 'Green River', 'category_code': None},
#  {'name': 'Proflowers', 'category_code': None},
#  {'name': 'ShareYourLook', 'category_code': None},
#  {'name': 'Smart Charter', 'category_code': None},
#  {'name': 'Wiredset', 'category_code': None},
#  {'name': 'Postlets', 'category_code': None},
#  {'name': 'Voxtel', 'category_code': None},
#  {'name': 'Dimestore Media', 'category_code': None},
#  {'name': 'Mindbox', 'category_code': None},
#  {'name': 'Princeton Softech', 'category_code': None},
#  {'name': 'HouseSpin', 'category_code': None},
#  {'name': 'EMI Group', 'category_code': None},
#  {'name': 'PocketMail', 'category_code': None},
#  {'name': 'KnowledgeBase', 'category_code': None},
#  {'name': 'Virtualis', 'category_code': None},
#  {'name': 'Tailsma', 'category_code': None},
#  {'name': 'Santa Cruz Networks', 'category_code': None},
#  {'name': 'Plural', 'category_code': None},
#  {'name': 'Tapped', 'category_code': None},
#  {'name': 'PaintPoker', 'category_code': None},
#  {'name': 'Ultris', 'category_code': None},
#  {'name': 'MusicZone', 'category_code': None},
#  {'name': 'EPO', 'category_code': None},
#  {'name': 'JPO', 'category_code': None},
#  {'name': "What's Open", 'category_code': None},
#  {'name': 'Tanga', 'category_code': None},
#  {'name': 'Thing Fling', 'category_code': None},
#  {'name': 'T Traditions', 'category_code': None},
#  {'name': 'Excite', 'category_code': None},
#  {'name': 'FriendVox', 'category_code': None},
#  {'name': 'DoppelMe', 'category_code': None},
#  {'name': 'izzyme', 'category_code': None},
#  {'name': 'Hachette Book Group', 'category_code': None},
#  {'name': 'i4giveu', 'category_code': None},
#  {'name': 'Pheedo', 'category_code': None},
#  {'name': 'Lockergnome', 'category_code': None},
#  {'name': 'MyCyberTwin', 'category_code': None},
#  {'name': 'The Secret Agency', 'category_code': None},
#  {'name': 'MediaWave', 'category_code': None},
#  {'name': 'Middio', 'category_code': None},
#  {'name': '1938 Media', 'category_code': None},
#  {'name': 'GarageBand', 'category_code': None},
#  {'name': 'Oddpost', 'category_code': None},
#  {'name': 'Starbucks', 'category_code': None},
#  {'name': 'TeleWare', 'category_code': None},
#  {'name': 'Swyx', 'category_code': None},
#  {'name': 'Housenetwork', 'category_code': None},
#  {'name': 'New Media Age', 'category_code': None},
#  {'name': 'British Telecom', 'category_code': None},
#  {'name': 'Nichenet Pty', 'category_code': None},
#  {'name': 'MyDataIsMyData', 'category_code': None},
#  {'name': 'geoURL', 'category_code': None},
#  {'name': 'ASPextra', 'category_code': None},
#  {'name': '365 Main', 'category_code': None},
#  {'name': 'ThePlanet', 'category_code': None},
#  {'name': 'Visioneer', 'category_code': None},
#  {'name': 'livesteez', 'category_code': None},
#  {'name': 'E-mail Vision', 'category_code': None},
#  {'name': 'GF-X', 'category_code': None},
#  {'name': 'Netconversions', 'category_code': None},
#  {'name': 'BMAT', 'category_code': None},
#  {'name': 'Froogle', 'category_code': None},
#  {'name': 'mIRC', 'category_code': None},
#  {'name': 'IceChat', 'category_code': None},
#  {'name': 'Vendare Media', 'category_code': None},
#  {'name': 'Pulse Mobile', 'category_code': None},
#  {'name': 'Logix', 'category_code': None},
#  {'name': 'Radioactive', 'category_code': None},
#  {'name': 'RoRCraft', 'category_code': None},
#  {'name': 'AllYouCanUpload', 'category_code': None},
#  {'name': 'Message Media', 'category_code': None},
#  {'name': 'Sxipper', 'category_code': None},
#  {'name': 'Quote Desk Software', 'category_code': None},
#  {'name': 'Upgradebase', 'category_code': None},
#  {'name': 'Peachtree', 'category_code': None},
#  {'name': 'Quickbooks', 'category_code': None},
#  {'name': 'LessAccounting', 'category_code': None},
#  {'name': 'Waggener Edstrom', 'category_code': None},
#  {'name': 'The Pudding', 'category_code': None},
#  {'name': 'Rojo', 'category_code': None},
#  {'name': 'Tvrss', 'category_code': None},
#  {'name': 'DrKW', 'category_code': None},
#  {'name': 'ValleySoft', 'category_code': None},
#  {'name': 'Jumpcut', 'category_code': None},
#  {'name': 'Giga Group', 'category_code': None},
#  {'name': 'WebTV', 'category_code': None},
#  {'name': 'ObjectSpeed', 'category_code': None},
#  {'name': 'Enclude', 'category_code': None},
#  {'name': 'EarthWeb', 'category_code': None},
#  {'name': 'Kurzweil Computer Products', 'category_code': None},
#  {'name': 'Aegis USA', 'category_code': None},
#  {'name': 'Avexus', 'category_code': None},
#  {'name': 'WideRay', 'category_code': None},
#  {'name': 'Pixelpanic', 'category_code': None},
#  {'name': 'Schematic', 'category_code': None},
#  {'name': 'mango', 'category_code': None},
#  {'name': 'TrafficSynergy', 'category_code': None},
#  {'name': 'Cox Enterprises', 'category_code': None},
#  {'name': 'Universal Music Group', 'category_code': None},
#  {'name': 'Hoovers', 'category_code': None},
#  {'name': 'Grey Global Group', 'category_code': None},
#  {'name': 'IP NetVertising', 'category_code': None},
#  {'name': 'Entergy Operations', 'category_code': None},
#  {'name': 'AllMyData', 'category_code': None},
#  {'name': 'Addictomatic', 'category_code': None},
#  {'name': 'eFORCE Global', 'category_code': None},
#  {'name': 'Welovelocal', 'category_code': None},
#  {'name': 'Red Swoosh', 'category_code': None},
#  {'name': 'Halobrite', 'category_code': None},
#  {'name': 'Poker Stars', 'category_code': None},
#  {'name': 'Personic', 'category_code': None},
#  {'name': 'Norm Miller of Interstate Batteries', 'category_code': None},
#  {'name': 'Documents To Go', 'category_code': None},
#  {'name': 'Pepsmedia', 'category_code': None},
#  {'name': 'Inquisitr', 'category_code': None},
#  {'name': 'Ludington Media West', 'category_code': None},
#  {'name': 'Grupo Televisa', 'category_code': None},
#  {'name': 'Medbroadcast Corporation', 'category_code': None},
#  {'name': 'Tradesports', 'category_code': None},
#  {'name': 'elogocontest', 'category_code': None},
#  {'name': 'Vox Telecom', 'category_code': None},
#  {'name': 'GTN Telecom', 'category_code': None},
#  {'name': 'MyVirtualDrive', 'category_code': None},
#  {'name': 'Solutionstap', 'category_code': None},
#  {'name': 'Epsodic', 'category_code': None},
#  {'name': 'Wubud', 'category_code': None},
#  {'name': 'Jaipur Restaurants', 'category_code': None},
#  {'name': 'Mento', 'category_code': None},
#  {'name': 'Doko', 'category_code': None},
#  {'name': 'dotMobi', 'category_code': None},
#  {'name': 'SmartRay Network', 'category_code': None},
#  {'name': 'Medium Design Group', 'category_code': None},
#  {'name': 'Rightcart', 'category_code': None},
#  {'name': 'Silent City Productions', 'category_code': None},
#  {'name': 'PictureRx', 'category_code': None},
#  {'name': 'TripKick', 'category_code': None},
#  {'name': 'InternetStart', 'category_code': None},
#  {'name': 'Holtzbrinck eLAB', 'category_code': None},
#  {'name': 'Software Arts', 'category_code': None},
#  {'name': 'eShop', 'category_code': None},
#  {'name': 'PaperStyle', 'category_code': None},
#  {'name': 'Torin', 'category_code': None},
#  {'name': 'Clear Applications', 'category_code': None},
#  {'name': 'Eloquent', 'category_code': None},
#  {'name': 'Graco Oilfield Services', 'category_code': None},
#  {'name': 'matchflick', 'category_code': None},
#  {'name': 'financial crossing', 'category_code': None},
#  {'name': 'DSLExtreme', 'category_code': None},
#  {'name': 'StoreHours', 'category_code': None},
#  {'name': 'tagstoc', 'category_code': None},
#  {'name': 'Newsworld International', 'category_code': None},
#  {'name': 'Eurostar Industries', 'category_code': None},
#  {'name': 'RVS Ventures', 'category_code': None},
#  {'name': 'eWare', 'category_code': None},
#  {'name': 'Paragon Five', 'category_code': None},
#  {'name': 'Reachd', 'category_code': None},
#  {'name': 'Thinkable', 'category_code': None},
#  {'name': 'Rambler', 'category_code': None},
#  {'name': 'Market Probability', 'category_code': None},
#  {'name': 'snurl', 'category_code': None},
#  {'name': 'Documentum', 'category_code': None},
#  {'name': 'Cyber Communications', 'category_code': None},
#  {'name': 'Honda Motor Company', 'category_code': None},
#  {'name': 'Torstar', 'category_code': None},
#  {'name': 'J2Play', 'category_code': None},
#  {'name': 'OrderLunch', 'category_code': None},
#  {'name': 'LinkExperts', 'category_code': None},
#  {'name': 'SocialAdmit', 'category_code': None},
#  {'name': 'The Portables', 'category_code': None},
#  {'name': 'Imajet', 'category_code': None},
#  {'name': 'Kent Ridge Digital Labs', 'category_code': None},
#  {'name': 'ePrecision', 'category_code': None},
#  {'name': 'Joard', 'category_code': None},
#  {'name': 'PlaySite', 'category_code': None},
#  {'name': 'Symbol Technologies', 'category_code': None},
#  {'name': 'RicardoArce', 'category_code': None},
#  {'name': 'Tyroo', 'category_code': None},
#  {'name': 'Linuxcare', 'category_code': None},
#  {'name': 'NationalShowTickets', 'category_code': None},
#  {'name': 'SpellBoy', 'category_code': None},
#  {'name': 'Plugg', 'category_code': None},
#  {'name': 'sticko', 'category_code': None},
#  {'name': 'Latina', 'category_code': None},
#  {'name': 'LeaseThis', 'category_code': None},
#  {'name': 'MyRichUncle', 'category_code': None},
#  {'name': 'Cittadino', 'category_code': None},
#  {'name': 'Mobaganda', 'category_code': None},
#  {'name': 'Epicentric', 'category_code': None},
#  {'name': 'QAS', 'category_code': None},
#  {'name': 'Europeatweb', 'category_code': None},
#  {'name': 'FiveSeven Studios', 'category_code': None},
#  {'name': 'Tufans Technology', 'category_code': None},
#  {'name': 'Intelect Communications', 'category_code': None},
#  {'name': 'Mosaic Information Technologies', 'category_code': None},
#  {'name': 'iBlast', 'category_code': None},
#  {'name': 'Qwil Company', 'category_code': None},
#  {'name': 'Musicbank', 'category_code': None},
#  {'name': 'Addwater', 'category_code': None},
#  {'name': 'The Brian Madden Company', 'category_code': None},
#  {'name': 'ViewScore', 'category_code': None},
#  {'name': 'PRWeb', 'category_code': None},
#  {'name': 'Katoupi', 'category_code': None},
#  {'name': 'Young Jobs', 'category_code': None},
#  {'name': 'GoodContacts', 'category_code': None},
#  {'name': 'RealtyTracker', 'category_code': None},
#  {'name': '2channel', 'category_code': None},
#  {'name': 'Interpolls', 'category_code': None},
#  {'name': 'Talent Edge', 'category_code': None},
#  {'name': 'LOPSA', 'category_code': None},
#  {'name': 'TIML Golden Square', 'category_code': None},
#  {'name': 'Jobby', 'category_code': None},
#  {'name': 'LandAirSea', 'category_code': None},
#  {'name': 'Pianofever', 'category_code': None},
#  {'name': 'LiveWire Networks', 'category_code': None},
#  {'name': 'Interfold', 'category_code': None},
#  {'name': 'Dynasty Online', 'category_code': None},
#  {'name': 'Epic Advertising', 'category_code': None},
#  {'name': 'Bluemobile', 'category_code': None},
#  {'name': 'Startaholics', 'category_code': None},
#  {'name': 'Partnership for Strong Families', 'category_code': None},
#  {'name': 'Lifesouth Community Blood Centers', 'category_code': None},
#  {'name': 'UNext', 'category_code': None},
#  {'name': 'WidgetWorld', 'category_code': None},
#  {'name': 'Eyeonix', 'category_code': None},
#  {'name': 'Pepsi', 'category_code': None},
#  {'name': 'Federal Aviation Administration', 'category_code': None},
#  {'name': 'United States Air Force', 'category_code': None},
#  {'name': 'Advantiv', 'category_code': None},
#  {'name': 'L-Ipse Services-Conseil', 'category_code': None},
#  {'name': 'Groupe AGI', 'category_code': None},
#  {'name': 'Marketing33', 'category_code': None},
#  {'name': 'Ghost', 'category_code': None},
#  {'name': 'SixSigma', 'category_code': None},
#  {'name': 'Groove Networks', 'category_code': None},
#  {'name': 'Lobe Multimedia', 'category_code': None},
#  {'name': 'IconMedialab', 'category_code': None},
#  {'name': 'SawLogs', 'category_code': None},
#  {'name': 'OurPlanet', 'category_code': None},
#  {'name': 'SproutCore', 'category_code': None},
#  {'name': 'Dogpile', 'category_code': None},
#  {'name': 'kimeta', 'category_code': None},
#  {'name': 'Availl', 'category_code': None},
#  {'name': 'WhaleMail', 'category_code': None},
#  {'name': 'Seapower', 'category_code': None},
#  {'name': 'Access', 'category_code': None},
#  {'name': 'Emergis (Bell Canada)', 'category_code': None},
#  {'name': 'Emergis', 'category_code': None},
#  {'name': 'Dynamite Partners', 'category_code': None},
#  {'name': 'USA Exports', 'category_code': None},
#  {'name': 'Sims Carnival', 'category_code': None},
#  {'name': 'iGoogle', 'category_code': None},
#  {'name': 'MxPlay', 'category_code': None},
#  {'name': 'Sonific', 'category_code': None},
#  {'name': 'Kinzin', 'category_code': None},
#  {'name': 'McCaw Cellular', 'category_code': None},
#  {'name': 'ShoeMoney Media Group', 'category_code': None},
#  {'name': 'The Open Group', 'category_code': None},
#  {'name': 'MagnusManis', 'category_code': None},
#  {'name': 'Bazaar Advertising Solutions', 'category_code': None},
#  {'name': 'Informative', 'category_code': None},
#  {'name': 'Flashbase', 'category_code': None},
#  {'name': 'Watch for Change Media', 'category_code': None},
#  {'name': 'Spinway', 'category_code': None},
#  {'name': 'FlipDog', 'category_code': None},
#  {'name': 'iTourSavannah', 'category_code': None},
#  {'name': 'Eftia OSS Solutions', 'category_code': None},
#  {'name': 'MTV Ukraine', 'category_code': None},
#  {'name': 'le ker', 'category_code': None},
#  {'name': 'prolitec', 'category_code': None},
#  {'name': 'nfactory', 'category_code': None},
#  {'name': 'full resource', 'category_code': None},
#  {'name': 'SYIF', 'category_code': None},
#  {'name': 'Sage Clearing', 'category_code': None},
#  {'name': 'Telinco', 'category_code': None},
#  {'name': 'Liberty Corporation', 'category_code': None},
#  {'name': 'm|a agile consulting', 'category_code': None},
#  {'name': '111pix', 'category_code': None},
#  {'name': 'Centrif', 'category_code': None},
#  {'name': 'Myspace Karaoke', 'category_code': None},
#  {'name': 'Sims On Stage', 'category_code': None},
#  {'name': 'SingSnap', 'category_code': None},
#  {'name': 'Euclid Infotech', 'category_code': None},
#  {'name': 'Queer Entertainment', 'category_code': None},
#  {'name': 'Dodgeball', 'category_code': None},
#  {'name': 'iPlayMusic', 'category_code': None},
#  {'name': 'Fashion Networks', 'category_code': None},
#  {'name': 'Micropole-Univers', 'category_code': None},
#  {'name': 'MythTV', 'category_code': None},
#  {'name': 'JustConfirmed', 'category_code': None},
#  {'name': 'Organic', 'category_code': None},
#  {'name': 'Adecco', 'category_code': None},
#  {'name': 'Ratemyemployer', 'category_code': None},
#  {'name': 'UUNET Technologies', 'category_code': None},
#  {'name': 'Tribbit', 'category_code': None},
#  {'name': 'Go Farm', 'category_code': None},
#  {'name': 'Greenit!', 'category_code': None},
#  {'name': 'Pier 39 San Francisco', 'category_code': None},
#  {'name': 'santa mistura', 'category_code': None},
#  {'name': 'The Source', 'category_code': None},
#  {'name': 'GKN Automotive', 'category_code': None},
#  {'name': 'PB', 'category_code': None},
#  {'name': 'InfoTone', 'category_code': None},
#  {'name': 'Progeny Linux Systems', 'category_code': None},
#  {'name': 'Deja', 'category_code': None},
#  {'name': 'Outride', 'category_code': None},
#  {'name': 'Kaltix', 'category_code': None},
#  {'name': 'Sprinks', 'category_code': None},
#  {'name': 'Genius Labs', 'category_code': None},
#  {'name': 'Ignite Logic', 'category_code': None},
#  {'name': 'Picasa', 'category_code': None},
#  {'name': 'ZipDash', 'category_code': None},
#  {'name': 'Reqwireless', 'category_code': None},
#  {'name': 'Skia', 'category_code': None},
#  {'name': 'Phatbits', 'category_code': None},
#  {'name': 'allPAY', 'category_code': None},
#  {'name': 'bruNET', 'category_code': None},
#  {'name': 'Upstartle', 'category_code': None},
#  {'name': '@Last Software', 'category_code': None},
#  {'name': 'Orion', 'category_code': None},
#  {'name': '2Web Technologies', 'category_code': None},
#  {'name': 'Endoxon', 'category_code': None},
#  {'name': 'Trendalyzer', 'category_code': None},
#  {'name': 'Tonic Systems', 'category_code': None},
#  {'name': 'Zingku', 'category_code': None},
#  {'name': 'Ripe Digital Media', 'category_code': None},
#  {'name': 'Mobile365 (fka InphoMatch)', 'category_code': None},
#  {'name': 'Joya Technologies', 'category_code': None},
#  {'name': 'Freever', 'category_code': None},
#  {'name': 'Tutch Media Mobile', 'category_code': None},
#  {'name': 'Gsmbox', 'category_code': None},
#  {'name': 'Vitaminic', 'category_code': None},
#  {'name': 'MicroAId', 'category_code': None},
#  {'name': 'MicroAid Projects', 'category_code': None},
#  {'name': 'Group Software', 'category_code': None},
#  {'name': 'Kinnetic', 'category_code': None},
#  {'name': 'KLM Airlines', 'category_code': None},
#  {'name': 'eMedicine', 'category_code': None},
#  {'name': 'Enbou', 'category_code': None},
#  {'name': 'MECLABS', 'category_code': None},
#  {'name': 'Junction Networks', 'category_code': None},
#  {'name': 'Trendum', 'category_code': None},
#  {'name': 'Open University, Israel', 'category_code': None},
#  {'name': 'Monolithic Memories', 'category_code': None},
#  {'name': 'livevideo', 'category_code': None},
#  {'name': 'OREA', 'category_code': None},
#  {'name': 'NeXT', 'category_code': None},
#  {'name': 'Lightstage', 'category_code': None},
#  {'name': 'GoodShop', 'category_code': None},
#  {'name': 'WickedLocal', 'category_code': None},
#  {'name': 'Primix', 'category_code': None},
#  {'name': 'EMI Music', 'category_code': None},
#  {'name': 'Electrolux', 'category_code': None},
#  {'name': 'Filmnight Group', 'category_code': None},
#  {'name': 'StandAlone Consulting', 'category_code': None},
#  {'name': 'NuParadigm', 'category_code': None},
#  {'name': 'EasyBib', 'category_code': None},
#  {'name': 'Hilton', 'category_code': None},
#  {'name': 'MTV Europe', 'category_code': None},
#  {'name': 'iChat', 'category_code': None},
#  {'name': 'Poker Timer', 'category_code': None},
#  {'name': 'ShapeWriter', 'category_code': None},
#  {'name': 'Tomatoes', 'category_code': None},
#  {'name': 'iMaze', 'category_code': None},
#  {'name': "What's Open iPhone App", 'category_code': None},
#  {'name': 'FlexoExchange', 'category_code': None},
#  {'name': 'tradebit', 'category_code': None},
#  {'name': 'Mastodonte Communication', 'category_code': None},
#  {'name': 'MicroSon', 'category_code': None},
#  {'name': 'MyEmma', 'category_code': None},
#  {'name': 'SonicMountain', 'category_code': None},
#  {'name': 'Pal Info Com Technologies', 'category_code': None},
#  {'name': 'Nvish Solutions', 'category_code': None},
#  {'name': 'ISKO Engineers AG', 'category_code': None},
#  {'name': 'Internet Interventions Incorporated', 'category_code': None},
#  {'name': 'Virtusa', 'category_code': None},
#  {'name': 'REBO Research', 'category_code': None},
#  {'name': 'pureorigin', 'category_code': None},
#  {'name': 'Heck, LLC', 'category_code': None},
#  {'name': 'Palmpixels', 'category_code': None},
#  {'name': 'Stopped Clocks Foundation', 'category_code': None},
#  {'name': 'mo blog', 'category_code': None},
#  {'name': 'Homepage Baukasten GmbH', 'category_code': None},
#  {'name': 'SmarTeam', 'category_code': None},
#  {'name': 'Publicitas LATAM', 'category_code': None},
#  {'name': 'EQMentor', 'category_code': None},
#  {'name': 'Psystar', 'category_code': None},
#  {'name': 'London2012', 'category_code': None},
#  {'name': 'KPMG Peat Marwick', 'category_code': None},
#  {'name': 'United States Marine Corps', 'category_code': None},
#  {'name': 'AdCamo', 'category_code': None},
#  {'name': 'Saber Corporation', 'category_code': None},
#  {'name': 'Skyhawks', 'category_code': None},
#  {'name': 'Gerdow', 'category_code': None},
#  {'name': 'Sundera', 'category_code': None},
#  {'name': 'Epsylon Video', 'category_code': None},
#  {'name': 'Epsylon Technologies', 'category_code': None},
#  {'name': 'TV4B', 'category_code': None},
#  {'name': 'MobiMate', 'category_code': None},
#  {'name': 'Rockstar Games', 'category_code': None},
#  {'name': 'KRAS ASIA Semiconductor', 'category_code': None},
#  {'name': 'PKC Corporation', 'category_code': None},
#  {'name': 'StumbleAudio', 'category_code': None},
#  {'name': 'Robertson Douglas Group', 'category_code': None},
#  {'name': 'SparkPeople', 'category_code': None},
#  {'name': 'EveryDNS', 'category_code': None},
#  {'name': 'GECAD NET', 'category_code': None},
#  {'name': 'RAV', 'category_code': None},
#  {'name': 'OMC Design Studios', 'category_code': None},
#  {'name': "Stella d'Oriente", 'category_code': None},
#  {'name': 'HyperCommune', 'category_code': None},
#  {'name': 'FocusAbacus', 'category_code': None},
#  {'name': 'PiFlow', 'category_code': None},
#  {'name': 'BUKA', 'category_code': None},
#  {'name': 'GiantBomb', 'category_code': None},
#  {'name': 'CasualCafe', 'category_code': None},
#  {'name': 'Online Publisher', 'category_code': None},
#  {'name': 'Hairy Ape', 'category_code': None},
#  {'name': 'Ai2', 'category_code': None},
#  {'name': 'MBA', 'category_code': None},
#  {'name': 'Philip Thompson', 'category_code': None},
#  {'name': 'Mixergy', 'category_code': None},
#  {'name': 'InTouch Kiosk', 'category_code': None},
#  {'name': 'MyHDTV Plus', 'category_code': None},
#  {'name': 'PRSA', 'category_code': None},
#  {'name': 'Kubl', 'category_code': None},
#  {'name': 'France Telecom', 'category_code': None},
#  {'name': 'Softlink', 'category_code': None},
#  {'name': 'ISF', 'category_code': None},
#  {'name': 'Pipegrep Consulting PTY LTD', 'category_code': None},
#  {'name': 'RadioShack', 'category_code': None},
#  {'name': 'Bubble Labs', 'category_code': None},
#  {'name': 'infoseek', 'category_code': None},
#  {'name': 'Tideway Systems ltd', 'category_code': None},
#  {'name': 'eSector Solutions', 'category_code': None},
#  {'name': 'Mollie', 'category_code': None},
#  {'name': 'Gradient Labs', 'category_code': None},
#  {'name': 'PlasTie', 'category_code': None},
#  {'name': 'SimonShows', 'category_code': None},
#  {'name': 'Tipic', 'category_code': None},
#  {'name': 'Ardesic', 'category_code': None},
#  {'name': 'Communitech', 'category_code': None},
#  {'name': 'ImThere', 'category_code': None},
#  {'name': 'Don Russell Family Investments', 'category_code': None},
#  {'name': 'Lovdal Media Norway', 'category_code': None},
#  {'name': 'Techvibes Media', 'category_code': None},
#  {'name': 'Biblio', 'category_code': None},
#  {'name': 'FillZ', 'category_code': None},
#  {'name': 'eMind', 'category_code': None},
#  {'name': 'affinitos', 'category_code': None},
#  {'name': 'InZearch', 'category_code': None},
#  {'name': 'Global Mind', 'category_code': None},
#  {'name': 'NetKiosk', 'category_code': None},
#  {'name': 'Greenling', 'category_code': None},
#  {'name': 'ColorSelector', 'category_code': None},
#  {'name': 'Icebox', 'category_code': None},
#  {'name': 'Confidential', 'category_code': None},
#  {'name': 'Lucky Upstairs', 'category_code': None},
#  {'name': 'cozi nozi', 'category_code': None},
#  {'name': 'notblue', 'category_code': None},
#  {'name': 'Socialogue', 'category_code': None},
#  {'name': 'Build-to-Order', 'category_code': None},
#  {'name': 'eMoney Advisor', 'category_code': None},
#  {'name': 'Reality Online(Reuters)', 'category_code': None},
#  {'name': 'Secure A Quote', 'category_code': None},
#  {'name': 'Code to Customer', 'category_code': None},
#  {'name': 'Smith Barney', 'category_code': None},
#  {'name': 'Pacific Crest Inspections', 'category_code': None},
#  {'name': 'Linqua', 'category_code': None},
#  {'name': 'CanalGOLF', 'category_code': None},
#  {'name': 'Loaded Media', 'category_code': None},
#  {'name': 'Piclinq', 'category_code': None},
#  {'name': 'Consist', 'category_code': None},
#  {'name': 'eFriendsNet', 'category_code': None},
#  {'name': 'Mobera Systems', 'category_code': None},
#  {'name': 'Epitaph Records', 'category_code': None},
#  {'name': 'Scape Velocity', 'category_code': None},
#  {'name': 'ACS', 'category_code': None},
#  {'name': 'Plainpeak Inc', 'category_code': None},
#  {'name': 'ScottTV', 'category_code': None},
#  {'name': 'Room FT', 'category_code': None},
#  {'name': 'Real Media', 'category_code': None},
#  {'name': 'IMATRIX', 'category_code': None},
#  {'name': 'Social Sample Inc', 'category_code': None},
#  {'name': 'NookNetwork LLC', 'category_code': None},
#  {'name': 'Neil Kaplan', 'category_code': None},
#  {'name': 'Charles Schwab', 'category_code': None},
#  {'name': 'AtomFilms', 'category_code': None},
#  {'name': 'Sedna Communications', 'category_code': None},
#  {'name': 'Director', 'category_code': None},
#  {'name': 'PSIMED Corporation', 'category_code': None},
#  {'name': 'Clinical Micro Sensors', 'category_code': None},
#  {'name': 'Insight Medical Healthcare Information Systems',
#   'category_code': None},
#  {'name': 'Huntington Memorial Research Institute', 'category_code': None},
#  {'name': 'MediaVast', 'category_code': None},
#  {'name': 'Captainad', 'category_code': None},
#  {'name': 'Jazztel', 'category_code': None},
#  {'name': 'Sandburg Village', 'category_code': None},
#  {'name': 'East Bank Club', 'category_code': None},
#  {'name': 'Mixi Mobile', 'category_code': None},
#  {'name': 'FreedomPay', 'category_code': None},
#  {'name': 'Corea Titanium', 'category_code': None},
#  {'name': 'HI-DIS', 'category_code': None},
#  {'name': 'Agape Package Manufacturing', 'category_code': None},
#  {'name': 'HK-HiTech', 'category_code': None},
#  {'name': 'Team Atlantis', 'category_code': None},
#  {'name': 'TENSV', 'category_code': None},
#  {'name': 'Seisint', 'category_code': None},
#  {'name': 'Cupr Hill', 'category_code': None},
#  {'name': 'Ex Machina', 'category_code': None},
#  {'name': 'The Computer Classroom', 'category_code': None},
#  {'name': 'Joltage', 'category_code': None},
#  {'name': 'Red Tie Media', 'category_code': None},
#  {'name': 'Petry Interactive', 'category_code': None},
#  {'name': 'FreeTicketExchange', 'category_code': None},
#  {'name': 'Vanilla Elephant', 'category_code': None},
#  {'name': 'Kontrol Media', 'category_code': None},
#  {'name': 'SilverFlash', 'category_code': None},
#  {'name': 'CleanCode Limited', 'category_code': None},
#  {'name': 'Netmar Solutions', 'category_code': None},
#  {'name': 'StarMarks', 'category_code': None},
#  {'name': 'Epoch Networks', 'category_code': None},
#  {'name': 'Commercial Internet eXchange', 'category_code': None},
#  {'name': 'Vantage Holdings', 'category_code': None},
#  {'name': 'Inker', 'category_code': None},
#  {'name': 'MMIM Technologies (PICA)', 'category_code': None},
#  {'name': '43Folders', 'category_code': None},
#  {'name': 'PingMyCompany', 'category_code': None},
#  {'name': 'Orange Dogs', 'category_code': None},
#  {'name': 'Threebrix E-services Pvt Ltd', 'category_code': None},
#  {'name': 'PDG+creative', 'category_code': None},
#  {'name': 'Du Nguyen', 'category_code': None},
#  {'name': 'Asera', 'category_code': None},
#  {'name': 'TPS Labs', 'category_code': None},
#  {'name': 'NomadIQ', 'category_code': None},
#  {'name': 'GTE Interactive Media', 'category_code': None},
#  {'name': 'Kamikaze', 'category_code': None},
#  {'name': 'Postcode Anywhere', 'category_code': None},
#  {'name': 'GeoTrust', 'category_code': None},
#  {'name': 'Equifax Secure', 'category_code': None},
#  {'name': 'hinttech', 'category_code': None},
#  {'name': 'Istanta Group', 'category_code': None},
#  {'name': 'Melon Media', 'category_code': None},
#  {'name': 'CBC', 'category_code': None},
#  {'name': 'Molson', 'category_code': None},
#  {'name': 'CTV', 'category_code': None},
#  {'name': 'Vision Media', 'category_code': None},
#  {'name': 'Exodus', 'category_code': None},
#  {'name': 'SiteMighty, Inc', 'category_code': None},
#  {'name': 'Destination VIP', 'category_code': None},
#  {'name': 'Goo', 'category_code': None},
#  {'name': 'Infoseek Rakuten', 'category_code': None},
#  {'name': 'BIGGLOBE', 'category_code': None},
#  {'name': 'Worldres', 'category_code': None},
#  {'name': 'IP Advisers', 'category_code': None},
#  {'name': 'Andersen Consulting', 'category_code': None},
#  {'name': 'FlatSoft', 'category_code': None},
#  {'name': 'Kazan Portal', 'category_code': None},
#  {'name': 'IFT Tomatoes', 'category_code': None},
#  {'name': 'Trapeze', 'category_code': None},
#  {'name': 'Twitly', 'category_code': None},
#  {'name': 'Lime Design', 'category_code': None},
#  {'name': 'RISC Partners', 'category_code': None},
#  {'name': 'Commerce360', 'category_code': None},
#  {'name': 'TurnTide', 'category_code': None},
#  {'name': 'ePrivacy Group', 'category_code': None},
#  {'name': 'Green-line', 'category_code': None},
#  {'name': 'Feedoor', 'category_code': None},
#  {'name': 'CellularVision', 'category_code': None},
#  {'name': 'Lavipharm Labs', 'category_code': None},
#  {'name': 'Scotia Pharma', 'category_code': None},
#  {'name': 'Holtzbrinck', 'category_code': None},
#  {'name': 'Neighborrow', 'category_code': None},
#  {'name': 'Loanables', 'category_code': None},
#  {'name': 'VoodooPC', 'category_code': None},
#  {'name': 'Reality Wireless', 'category_code': None},
#  {'name': 'M6 Communication Applications Server', 'category_code': None},
#  {'name': 'Massive Solutions Limited', 'category_code': None},
#  {'name': 'Imbolc Consulting Limited', 'category_code': None},
#  {'name': 'CleverTec Limited', 'category_code': None},
#  {'name': 'LuckyEye', 'category_code': None},
#  {'name': 'SideTaker', 'category_code': None},
#  {'name': 'Influencing', 'category_code': None},
#  {'name': 'Spoink', 'category_code': None},
#  {'name': 'InciteBot', 'category_code': None},
#  {'name': 'Positive Networks', 'category_code': None},
#  {'name': 'Legalicious', 'category_code': None},
#  {'name': 'Vedio', 'category_code': None},
#  {'name': 'iWoogs', 'category_code': None},
#  {'name': 'M31 Enterprises', 'category_code': None},
#  {'name': 'IAMNEWS', 'category_code': None},
#  {'name': 'AZRI', 'category_code': None},
#  {'name': 'Amplafi', 'category_code': None},
#  {'name': 'Planet Alumni User Data', 'category_code': None},
#  {'name': 'SEO Hyd', 'category_code': None},
#  {'name': 'Kronomy', 'category_code': None},
#  {'name': 'Glenwood Group', 'category_code': None},
#  {'name': 'TechTV', 'category_code': None},
#  {'name': 'Collective Technologies', 'category_code': None},
#  {'name': 'itList', 'category_code': None},
#  {'name': 'NTT East Corporation', 'category_code': None},
#  {'name': 'Gourmet Navigator', 'category_code': None},
#  {'name': "Stay N' Alive Productions, LLC", 'category_code': None},
#  {'name': 'AdForce', 'category_code': None},
#  {'name': 'Signio', 'category_code': None},
#  {'name': 'eVoice', 'category_code': None},
#  {'name': 'Intelmatec', 'category_code': None},
#  {'name': 'Invincibelle', 'category_code': None},
#  {'name': 'Career Liaison, LLC', 'category_code': None},
#  {'name': 'Epylon', 'category_code': None},
#  {'name': 'Steel Wars', 'category_code': None},
#  {'name': 'AnalyticBridge', 'category_code': None},
#  {'name': 'intrust Technologies', 'category_code': None},
#  {'name': 'Plainpeak Inc', 'category_code': None},
#  {'name': 'ScottTV', 'category_code': None},
#  {'name': 'Room FT', 'category_code': None},
#  {'name': 'Real Media', 'category_code': None},
#  {'name': 'IMATRIX', 'category_code': None},
#  {'name': 'Social Sample Inc', 'category_code': None},
#  {'name': 'NookNetwork LLC', 'category_code': None},
#  {'name': 'Neil Kaplan', 'category_code': None},
#  {'name': 'Charles Schwab', 'category_code': None},
#  {'name': 'AtomFilms', 'category_code': None},
#  {'name': 'Sedna Communications', 'category_code': None},
#  {'name': 'Director', 'category_code': None},
#  {'name': 'PSIMED Corporation', 'category_code': None},
#  {'name': 'Clinical Micro Sensors', 'category_code': None},
#  {'name': 'Insight Medical Healthcare Information Systems',
#   'category_code': None},
#  {'name': 'Huntington Memorial Research Institute', 'category_code': None},
#  {'name': 'MediaVast', 'category_code': None},
#  {'name': 'Captainad', 'category_code': None},
#  {'name': 'Jazztel', 'category_code': None},
#  {'name': 'Sandburg Village', 'category_code': None},
#  {'name': 'East Bank Club', 'category_code': None},
#  {'name': 'Mixi Mobile', 'category_code': None},
#  {'name': 'FreedomPay', 'category_code': None},
#  {'name': 'Corea Titanium', 'category_code': None},
#  {'name': 'HI-DIS', 'category_code': None},
#  {'name': 'Agape Package Manufacturing', 'category_code': None},
#  {'name': 'HK-HiTech', 'category_code': None},
#  {'name': 'Team Atlantis', 'category_code': None},
#  {'name': 'TENSV', 'category_code': None},
#  {'name': 'Seisint', 'category_code': None},
#  {'name': 'Cupr Hill', 'category_code': None},
#  {'name': 'Ex Machina', 'category_code': None},
#  {'name': 'The Computer Classroom', 'category_code': None},
#  {'name': 'Joltage', 'category_code': None},
#  {'name': 'Red Tie Media', 'category_code': None},
#  {'name': 'Petry Interactive', 'category_code': None},
#  {'name': 'FreeTicketExchange', 'category_code': None},
#  {'name': 'Vanilla Elephant', 'category_code': None},
#  {'name': 'Kontrol Media', 'category_code': None},
#  {'name': 'SilverFlash', 'category_code': None},
#  {'name': 'CleanCode Limited', 'category_code': None},
#  {'name': 'Netmar Solutions', 'category_code': None},
#  {'name': 'StarMarks', 'category_code': None},
#  {'name': 'Epoch Networks', 'category_code': None},
#  {'name': 'Commercial Internet eXchange', 'category_code': None},
#  {'name': 'Vantage Holdings', 'category_code': None},
#  {'name': 'Inker', 'category_code': None},
#  {'name': 'MMIM Technologies (PICA)', 'category_code': None},
#  {'name': '43Folders', 'category_code': None},
#  {'name': 'PingMyCompany', 'category_code': None},
#  {'name': 'Orange Dogs', 'category_code': None},
#  {'name': 'Threebrix E-services Pvt Ltd', 'category_code': None},
#  {'name': 'PDG+creative', 'category_code': None},
#  {'name': 'Du Nguyen', 'category_code': None},
#  {'name': 'Asera', 'category_code': None},
#  {'name': 'TPS Labs', 'category_code': None},
#  {'name': 'NomadIQ', 'category_code': None},
#  {'name': 'GTE Interactive Media', 'category_code': None},
#  {'name': 'Kamikaze', 'category_code': None},
#  {'name': 'Postcode Anywhere', 'category_code': None},
#  {'name': 'GeoTrust', 'category_code': None},
#  {'name': 'Equifax Secure', 'category_code': None},
#  {'name': 'hinttech', 'category_code': None},
#  {'name': 'Istanta Group', 'category_code': None},
#  {'name': 'Melon Media', 'category_code': None},
#  {'name': 'CBC', 'category_code': None},
#  {'name': 'Molson', 'category_code': None},
#  {'name': 'CTV', 'category_code': None},
#  {'name': 'Vision Media', 'category_code': None},
#  {'name': 'Exodus', 'category_code': None},
#  {'name': 'SiteMighty, Inc', 'category_code': None},
#  {'name': 'Destination VIP', 'category_code': None},
#  {'name': 'Goo', 'category_code': None},
#  {'name': 'Infoseek Rakuten', 'category_code': None},
#  {'name': 'BIGGLOBE', 'category_code': None},
#  {'name': 'Worldres', 'category_code': None},
#  {'name': 'IP Advisers', 'category_code': None},
#  {'name': 'Andersen Consulting', 'category_code': None},
#  {'name': 'FlatSoft', 'category_code': None},
#  {'name': 'Kazan Portal', 'category_code': None},
#  {'name': 'IFT Tomatoes', 'category_code': None},
#  {'name': 'Trapeze', 'category_code': None},
#  {'name': 'Twitly', 'category_code': None},
#  {'name': 'Lime Design', 'category_code': None},
#  {'name': 'RISC Partners', 'category_code': None},
#  {'name': 'Commerce360', 'category_code': None},
#  {'name': 'TurnTide', 'category_code': None},
#  {'name': 'ePrivacy Group', 'category_code': None},
#  {'name': 'Green-line', 'category_code': None},
#  {'name': 'Feedoor', 'category_code': None},
#  {'name': 'CellularVision', 'category_code': None},
#  {'name': 'Lavipharm Labs', 'category_code': None},
#  {'name': 'Scotia Pharma', 'category_code': None},
#  {'name': 'Holtzbrinck', 'category_code': None},
#  {'name': 'Neighborrow', 'category_code': None},
#  {'name': 'Loanables', 'category_code': None},
#  {'name': 'VoodooPC', 'category_code': None},
#  {'name': 'Reality Wireless', 'category_code': None},
#  {'name': 'M6 Communication Applications Server', 'category_code': None},
#  {'name': 'Massive Solutions Limited', 'category_code': None},
#  {'name': 'Imbolc Consulting Limited', 'category_code': None},
#  {'name': 'CleverTec Limited', 'category_code': None},
#  {'name': 'LuckyEye', 'category_code': None},
#  {'name': 'SideTaker', 'category_code': None},
#  {'name': 'Influencing', 'category_code': None},
#  {'name': 'Spoink', 'category_code': None},
#  {'name': 'InciteBot', 'category_code': None},
#  {'name': 'Positive Networks', 'category_code': None},
#  {'name': 'Legalicious', 'category_code': None},
#  {'name': 'Vedio', 'category_code': None},
#  {'name': 'iWoogs', 'category_code': None},
#  {'name': 'M31 Enterprises', 'category_code': None},
#  {'name': 'IAMNEWS', 'category_code': None},
#  {'name': 'AZRI', 'category_code': None},
#  {'name': 'Amplafi', 'category_code': None},
#  {'name': 'Planet Alumni User Data', 'category_code': None},
#  {'name': 'SEO Hyd', 'category_code': None},
#  {'name': 'Kronomy', 'category_code': None},
#  {'name': 'Glenwood Group', 'category_code': None},
#  {'name': 'TechTV', 'category_code': None},
#  {'name': 'Collective Technologies', 'category_code': None},
#  {'name': 'itList', 'category_code': None},
#  {'name': 'NTT East Corporation', 'category_code': None},
#  {'name': 'Gourmet Navigator', 'category_code': None},
#  {'name': "Stay N' Alive Productions, LLC", 'category_code': None},
#  {'name': 'AdForce', 'category_code': None},
#  {'name': 'Signio', 'category_code': None},
#  {'name': 'eVoice', 'category_code': None},
#  {'name': 'Intelmatec', 'category_code': None},
#  {'name': 'Invincibelle', 'category_code': None},
#  {'name': 'Career Liaison, LLC', 'category_code': None},
#  {'name': 'Epylon', 'category_code': None},
#  {'name': 'Steel Wars', 'category_code': None},
#  {'name': 'AnalyticBridge', 'category_code': None},
#  {'name': 'intrust Technologies', 'category_code': None},
#  {'name': 'OnMyList', 'category_code': None},
#  {'name': 'Niimozga', 'category_code': None},
#  {'name': 'Blogbaza', 'category_code': None},
#  {'name': 'Hotel Ambasador', 'category_code': None},
#  {'name': 'Digital Support Technology', 'category_code': None},
#  {'name': 'Tula Technology', 'category_code': None},
#  {'name': 'Data Connection', 'category_code': None},
#  {'name': 'Aruba Networks', 'category_code': None},
#  {'name': 'SourgeForce', 'category_code': None},
#  {'name': 'Factor Three Software', 'category_code': None},
#  {'name': 'Soligence', 'category_code': None},
#  {'name': 'Proficient', 'category_code': None},
#  {'name': 'iSyndicate', 'category_code': None},
#  {'name': 'iVendor', 'category_code': None},
#  {'name': 'card USA', 'category_code': None},
#  {'name': 'ComputerOil AG', 'category_code': None},
#  {'name': 'Clotho Business Solutions', 'category_code': None},
#  {'name': 'Mobio Networks', 'category_code': None},
#  {'name': 'Icardio', 'category_code': None},
#  {'name': 'TechTalk Media', 'category_code': None},
#  {'name': 'RiverVillage', 'category_code': None},
#  {'name': 'isBIZZ', 'category_code': None},
#  {'name': 'emilio', 'category_code': None},
#  {'name': 'IT Revolution', 'category_code': None},
#  {'name': 'NE Services', 'category_code': None},
#  {'name': 'Hinchliffe Solicitors', 'category_code': None},
#  {'name': 'BuyDomains', 'category_code': None},
#  {'name': 'AfterNic', 'category_code': None},
#  {'name': 'Middleshift Consulting', 'category_code': None},
#  {'name': 'Advanta Bank', 'category_code': None},
#  {'name': 'Better', 'category_code': None},
#  {'name': '(fluff)Friends', 'category_code': None},
#  {'name': 'Elemica', 'category_code': None},
#  {'name': 'Travent UK', 'category_code': None},
#  {'name': 'MyPlay', 'category_code': None},
#  {'name': 'Empire Media', 'category_code': None},
#  {'name': 'Lypp', 'category_code': None},
#  {'name': 'enterprise wireless alliance', 'category_code': None},
#  {'name': 'Allant', 'category_code': None},
#  {'name': 'Claritas', 'category_code': None},
#  {'name': 'Nitro Marketing', 'category_code': None},
#  {'name': 'Sapotek', 'category_code': None},
#  {'name': 'Iceberg Cafe', 'category_code': None},
#  {'name': 'Uptown Scoop', 'category_code': None},
#  {'name': 'Aurora Electric', 'category_code': None},
#  {'name': 'Axxess Business Consulting', 'category_code': None},
#  {'name': 'YourLocal', 'category_code': None},
#  {'name': 'Vendio', 'category_code': None},
#  {'name': 'The Pioneer', 'category_code': None},
#  {'name': 'RTT News', 'category_code': None},
#  {'name': 'BigVine', 'category_code': None},
#  {'name': 'Concellera Software', 'category_code': None},
#  {'name': 'BrainQUICKEN', 'category_code': None},
#  {'name': 'Polygon Group', 'category_code': None},
#  {'name': 'CollectZing', 'category_code': None},
#  {'name': 'Classgrabber', 'category_code': None},
#  {'name': 'IBM Japan', 'category_code': None},
#  {'name': 'TBWA Paris', 'category_code': None},
#  {'name': 'Kistefos VC', 'category_code': None},
#  {'name': 'MailFoundry', 'category_code': None},
#  {'name': 'dmInteractive', 'category_code': None},
#  {'name': 'DCT Technologies', 'category_code': None},
#  {'name': 'EpicSessions', 'category_code': None},
#  {'name': 'Netintact', 'category_code': None},
#  {'name': 'WinkSite', 'category_code': None},
#  {'name': 'Marmot iGloves', 'category_code': None},
#  {'name': 'Pionetics', 'category_code': None},
#  {'name': 'The Island Packet', 'category_code': None},
#  {'name': 'The Beaufort Gazette', 'category_code': None},
#  {'name': 'The Times Herald-Record', 'category_code': None},
#  {'name': 'Edwardsville Intelligencer', 'category_code': None},
#  {'name': 'Journal Newspapers of Southern Illinois', 'category_code': None},
#  {'name': 'The Alton Telegraph', 'category_code': None},
#  {'name': 'Spotlight Effect', 'category_code': None},
#  {'name': 'Revmap', 'category_code': None},
#  {'name': 'These Lovely Days', 'category_code': None},
#  {'name': 'Paradigm Staffing', 'category_code': None},
#  {'name': 'Yoyodyne Entertainment', 'category_code': None},
#  {'name': 'AdInterax', 'category_code': None},
#  {'name': 'Konfabulator', 'category_code': None},
#  {'name': 'Dialpad', 'category_code': None},
#  {'name': 'TeRespondo', 'category_code': None},
#  {'name': 'Stadeon', 'category_code': None},
#  {'name': 'Stata Labs', 'category_code': None},
#  {'name': 'The All-Seeing Eye', 'category_code': None},
#  {'name': '3721 Internet Assistant', 'category_code': None},
#  {'name': 'Inktomi', 'category_code': None},
#  {'name': 'AlltheWeb', 'category_code': None},
#  {'name': 'Hotjobs', 'category_code': None},
#  {'name': 'Launch Media', 'category_code': None},
#  {'name': 'Kimo', 'category_code': None},
#  {'name': 'Arthas', 'category_code': None},
#  {'name': 'MyQuest', 'category_code': None},
#  {'name': 'Online Anywhere', 'category_code': None},
#  {'name': 'Encompass', 'category_code': None},
#  {'name': 'HyperParallel', 'category_code': None},
#  {'name': 'Webcal', 'category_code': None},
#  {'name': 'Viaweb', 'category_code': None},
#  {'name': 'Net Controls', 'category_code': None},
#  {'name': 'e-Value (Germany)', 'category_code': None},
#  {'name': 'MivzaMedia', 'category_code': None},
#  {'name': 'Creopolis', 'category_code': None},
#  {'name': 'QuieroMirar!', 'category_code': None},
#  {'name': 'Oh!NEWSLETTER', 'category_code': None},
#  {'name': 'BeDesk', 'category_code': None},
#  {'name': 'Indomite', 'category_code': None},
#  {'name': 'PubSub', 'category_code': None},
#  {'name': 'hi-tech e internet', 'category_code': None},
#  {'name': 'Tampa Bay Recycling', 'category_code': None},
#  {'name': 'Monetaire', 'category_code': None},
#  {'name': 'Canopus BioPharma', 'category_code': None},
#  {'name': 'Startup District', 'category_code': None},
#  {'name': 'Sports Fan Live', 'category_code': None},
#  {'name': 'AthensRoom', 'category_code': None},
#  {'name': '6s Marketing', 'category_code': None},
#  {'name': 'Audizen', 'category_code': None},
#  {'name': 'Glue London', 'category_code': None},
#  {'name': 'Airside', 'category_code': None},
#  {'name': 'Mother', 'category_code': None},
#  {'name': 'Acknowledgement', 'category_code': None},
#  {'name': 'MyAgency', 'category_code': None},
#  {'name': 'Docuware', 'category_code': None},
#  {'name': 'imitrieve', 'category_code': None},
#  {'name': 'Baazee', 'category_code': None},
#  {'name': 'Iceflow Studios', 'category_code': None},
#  {'name': 'Unitrove', 'category_code': None},
#  {'name': 'Scala', 'category_code': None},
#  {'name': 'Blush Media', 'category_code': None},
#  ...]

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
list(colec.find({'number_of_employees':{'$gte':100, '$lt':1000}}, 
                {'name':1,'number_of_employees':1, '_id':0}).sort('number_of_employees',-1))
# Out:
# [{'name': 'Datamonitor', 'number_of_employees': 984},
#  {'name': 'Infinera Corporation', 'number_of_employees': 974},
#  {'name': 'Box', 'number_of_employees': 950},
#  {'name': 'NorthPoint Communications Group', 'number_of_employees': 948},
#  {'name': '888 Holdings', 'number_of_employees': 931},
#  {'name': 'Forrester Research', 'number_of_employees': 903},
#  {'name': 'Workday', 'number_of_employees': 900},
#  {'name': 'InMobi', 'number_of_employees': 900},
#  {'name': 'Relax Solutions Pvt Ltd', 'number_of_employees': 900},
#  {'name': 'SonicWALL', 'number_of_employees': 900},
#  {'name': 'Webmetrics', 'number_of_employees': 900},
#  {'name': 'Cornerstone OnDemand', 'number_of_employees': 881},
#  {'name': 'Yelp', 'number_of_employees': 800},
#  {'name': 'MySpace', 'number_of_employees': 800},
#  {'name': 'ZoomInfo', 'number_of_employees': 800},
#  {'name': 'Mozilla', 'number_of_employees': 800},
#  {'name': 'Buongiorno', 'number_of_employees': 800},
#  {'name': 'Cvent', 'number_of_employees': 800},
#  {'name': 'Wayfair', 'number_of_employees': 800},
#  {'name': 'BitDefender', 'number_of_employees': 800},
#  {'name': 'Gateway TechnoLabs Pvt Ltd', 'number_of_employees': 800},
#  {'name': 'LivingLink', 'number_of_employees': 800},
#  {'name': 'LivingLink', 'number_of_employees': 800},
#  {'name': 'Good Technology', 'number_of_employees': 800},
#  {'name': 'RightNow Technologies', 'number_of_employees': 800},
#  {'name': 'SourceMedia', 'number_of_employees': 800},
#  {'name': 'Pegasystems', 'number_of_employees': 750},
#  {'name': 'Landor Associates', 'number_of_employees': 750},
#  {'name': 'Intelligent Software Solutions', 'number_of_employees': 730},
#  {'name': 'Sonosite', 'number_of_employees': 715},
#  {'name': 'Criteo', 'number_of_employees': 700},
#  {'name': 'Citrix Online', 'number_of_employees': 700},
#  {'name': 'Toluna', 'number_of_employees': 700},
#  {'name': 'Barracuda Networks', 'number_of_employees': 700},
#  {'name': 'Creative Kingdom Animation Studios Film',
#   'number_of_employees': 700},
#  {'name': 'GREE', 'number_of_employees': 700},
#  {'name': 'TGS Geophysicl', 'number_of_employees': 696},
#  {'name': '4shared', 'number_of_employees': 666},
#  {'name': 'HubSpot', 'number_of_employees': 650},
#  {'name': 'Kabam', 'number_of_employees': 650},
#  {'name': 'Scope e Knowledge Center Pvt Ltd', 'number_of_employees': 650},
#  {'name': 'Silver Spring Networks', 'number_of_employees': 650},
#  {'name': 'SLR Consulting', 'number_of_employees': 650},
#  {'name': 'LifeLock', 'number_of_employees': 644},
#  {'name': 'Shutterfly', 'number_of_employees': 611},
#  {'name': 'AdventNet', 'number_of_employees': 600},
#  {'name': 'PhotoBox', 'number_of_employees': 600},
#  {'name': 'Bazaarvoice', 'number_of_employees': 600},
#  {'name': 'TechTarget', 'number_of_employees': 600},
#  {'name': 'Zillow', 'number_of_employees': 600},
#  {'name': 'NaviSite', 'number_of_employees': 600},
#  {'name': 'Saba', 'number_of_employees': 600},
#  {'name': 'zanox', 'number_of_employees': 600},
#  {'name': 'Vertex', 'number_of_employees': 600},
#  {'name': 'QlikTech', 'number_of_employees': 600},
#  {'name': 'Sitecore', 'number_of_employees': 600},
#  {'name': 'MLB Advanced Media', 'number_of_employees': 600},
#  {'name': 'Itransition', 'number_of_employees': 600},
#  {'name': 'Consumers Union', 'number_of_employees': 600},
#  {'name': 'Huge', 'number_of_employees': 600},
#  {'name': 'Linekong', 'number_of_employees': 600},
#  {'name': 'Square', 'number_of_employees': 600},
#  {'name': 'GRNLive', 'number_of_employees': 600},
#  {'name': 'Anacomp', 'number_of_employees': 600},
#  {'name': 'Micro Focus', 'number_of_employees': 591},
#  {'name': 'Micro Focus', 'number_of_employees': 591},
#  {'name': 'Unwired Planet', 'number_of_employees': 590},
#  {'name': 'TESCRA', 'number_of_employees': 580},
#  {'name': 'OpenTable', 'number_of_employees': 550},
#  {'name': 'iCrossing', 'number_of_employees': 550},
#  {'name': 'Vostu', 'number_of_employees': 550},
#  {'name': 'AKQA', 'number_of_employees': 550},
#  {'name': 'AKQA', 'number_of_employees': 550},
#  {'name': 'i365, A Seagate Company', 'number_of_employees': 550},
#  {'name': 'smartFOCUS', 'number_of_employees': 550},
#  {'name': 'Leapfrog Enterprises', 'number_of_employees': 541},
#  {'name': 'TaskUs', 'number_of_employees': 540},
#  {'name': 'Markafoni', 'number_of_employees': 520},
#  {'name': 'Central Reservations', 'number_of_employees': 510},
#  {'name': 'Veeva', 'number_of_employees': 510},
#  {'name': 'Xero', 'number_of_employees': 507},
#  {'name': 'Trulia', 'number_of_employees': 500},
#  {'name': 'Alipay', 'number_of_employees': 500},
#  {'name': 'Splunk', 'number_of_employees': 500},
#  {'name': 'Tesla Motors', 'number_of_employees': 500},
#  {'name': 'XING', 'number_of_employees': 500},
#  {'name': 'Endeca', 'number_of_employees': 500},
#  {'name': 'QuinStreet', 'number_of_employees': 500},
#  {'name': 'Adconion Media Group', 'number_of_employees': 500},
#  {'name': 'Infoblox', 'number_of_employees': 500},
#  {'name': 'SilkRoad Technology', 'number_of_employees': 500},
#  {'name': 'Acquity Group', 'number_of_employees': 500},
#  {'name': 'Talent Gurus', 'number_of_employees': 500},
#  {'name': 'Cleartrip', 'number_of_employees': 500},
#  {'name': 'IDEO', 'number_of_employees': 500},
#  {'name': 'Zhaopin', 'number_of_employees': 500},
#  {'name': 'Appirio', 'number_of_employees': 500},
#  {'name': 'Xiamen Everbeen Magnet Electron', 'number_of_employees': 500},
#  {'name': 'A10 Networks', 'number_of_employees': 500},
#  {'name': 'Macbellads Network', 'number_of_employees': 500},
#  {'name': 'Red Ventures', 'number_of_employees': 500},
#  {'name': 'Marine Harvest Canada', 'number_of_employees': 500},
#  {'name': 'Hi-media', 'number_of_employees': 500},
#  {'name': 'Activeweb', 'number_of_employees': 500},
#  {'name': 'Commission Junction', 'number_of_employees': 500},
#  {'name': 'Dot Com Infoway', 'number_of_employees': 500},
#  {'name': 'CAP Digisoft Solutions', 'number_of_employees': 500},
#  {'name': 'Three Stars', 'number_of_employees': 500},
#  {'name': 'TMP Directional Marketing', 'number_of_employees': 500},
#  {'name': 'NewAuto Video Technology', 'number_of_employees': 500},
#  {'name': 'Daimer Industries', 'number_of_employees': 500},
#  {'name': 'Water Health International', 'number_of_employees': 500},
#  {'name': 'Timetric', 'number_of_employees': 500},
#  {'name': 'COA Solutions', 'number_of_employees': 500},
#  {'name': 'Imagination Technologies', 'number_of_employees': 500},
#  {'name': 'Bigpoint', 'number_of_employees': 500},
#  {'name': 'FleetMatics', 'number_of_employees': 500},
#  {'name': 'Avira', 'number_of_employees': 500},
#  {'name': 'UOL (Universo Online)', 'number_of_employees': 500},
#  {'name': 'Netcentives', 'number_of_employees': 496},
#  {'name': 'Tangoe', 'number_of_employees': 485},
#  {'name': 'GARA Web Hosting', 'number_of_employees': 480},
#  {'name': 'TOA Technologies', 'number_of_employees': 460},
#  {'name': '9You', 'number_of_employees': 460},
#  {'name': 'Intellisync', 'number_of_employees': 456},
#  {'name': 'Truphone', 'number_of_employees': 450},
#  {'name': 'ZocDoc', 'number_of_employees': 450},
#  {'name': 'Clear2Pay', 'number_of_employees': 450},
#  {'name': 'Express KCS', 'number_of_employees': 450},
#  {'name': 'Marketwired', 'number_of_employees': 450},
#  {'name': 'Embarcadero Technologies', 'number_of_employees': 450},
#  {'name': 'ITP Publishing Group', 'number_of_employees': 437},
#  {'name': 'INX', 'number_of_employees': 433},
#  {'name': 'Rally Software', 'number_of_employees': 430},
#  {'name': 'Onsite3', 'number_of_employees': 422},
#  {'name': 'Tier Technologies', 'number_of_employees': 412},
#  {'name': 'RigNet', 'number_of_employees': 410},
#  {'name': 'Wix', 'number_of_employees': 400},
#  {'name': 'Viadeo', 'number_of_employees': 400},
#  {'name': 'Deem', 'number_of_employees': 400},
#  {'name': 'Acquia', 'number_of_employees': 400},
#  {'name': 'TiVo', 'number_of_employees': 400},
#  {'name': 'Outblaze', 'number_of_employees': 400},
#  {'name': 'InvenSense', 'number_of_employees': 400},
#  {'name': 'Talend', 'number_of_employees': 400},
#  {'name': 'VECTOR', 'number_of_employees': 400},
#  {'name': 'Zendesk', 'number_of_employees': 400},
#  {'name': 'Big Property Ladder', 'number_of_employees': 400},
#  {'name': 'Atari', 'number_of_employees': 400},
#  {'name': 'Webroot', 'number_of_employees': 400},
#  {'name': 'Yammer', 'number_of_employees': 400},
#  {'name': 'Webroot', 'number_of_employees': 400},
#  {'name': 'Yammer', 'number_of_employees': 400},
#  {'name': 'Canpages', 'number_of_employees': 400},
#  {'name': 'Onebox', 'number_of_employees': 400},
#  {'name': 'Internap', 'number_of_employees': 400},
#  {'name': 'TradeKey', 'number_of_employees': 400},
#  {'name': 'Kaseya', 'number_of_employees': 400},
#  {'name': 'Sonos', 'number_of_employees': 400},
#  {'name': 'SpringSoft', 'number_of_employees': 400},
#  {'name': 'Telogis', 'number_of_employees': 400},
#  {'name': 'Calypso Technology', 'number_of_employees': 386},
#  {'name': 'Willdan Group', 'number_of_employees': 385},
#  {'name': 'PubMatic', 'number_of_employees': 380},
#  {'name': 'Higher One', 'number_of_employees': 380},
#  {'name': 'mindSHIFT Technologies', 'number_of_employees': 380},
#  {'name': 'Silverpop', 'number_of_employees': 380},
#  {'name': 'HootSuite', 'number_of_employees': 370},
#  {'name': 'CCP Games', 'number_of_employees': 360},
#  {'name': 'Softonic', 'number_of_employees': 360},
#  {'name': 'Softonic', 'number_of_employees': 360},
#  {'name': 'SolarWinds', 'number_of_employees': 354},
#  {'name': 'HighJump Software', 'number_of_employees': 352},
#  {'name': 'Dropbox', 'number_of_employees': 350},
#  {'name': 'Match', 'number_of_employees': 350},
#  {'name': 'CDNetworks', 'number_of_employees': 350},
#  {'name': 'eTeacher', 'number_of_employees': 350},
#  {'name': 'FriendFinder Networks', 'number_of_employees': 350},
#  {'name': 'ScanCafe', 'number_of_employees': 350},
#  {'name': 'Webtrends', 'number_of_employees': 350},
#  {'name': 'AtTask', 'number_of_employees': 350},
#  {'name': 'Infusionsoft', 'number_of_employees': 350},
#  {'name': 'WideOrbit', 'number_of_employees': 350},
#  {'name': 'FileMaker', 'number_of_employees': 350},
#  {'name': 'PurpleTalk', 'number_of_employees': 350},
#  {'name': 'iTouchPoint', 'number_of_employees': 350},
#  {'name': 'DigitalGlobe', 'number_of_employees': 350},
#  {'name': '2AdPro', 'number_of_employees': 350},
#  {'name': 'DemandTec', 'number_of_employees': 350},
#  {'name': 'Tobii Technology', 'number_of_employees': 350},
#  {'name': 'Dot Com Infoway Australia', 'number_of_employees': 350},
#  {'name': 'mjunction services limite', 'number_of_employees': 350},
#  {'name': 'NexJ Systems', 'number_of_employees': 350},
#  {'name': 'Excel Telemarketing', 'number_of_employees': 350},
#  {'name': 'Tell Me More', 'number_of_employees': 350},
#  {'name': 'Wondershare Software', 'number_of_employees': 350},
#  {'name': 'IRIS Software Group', 'number_of_employees': 347},
#  {'name': 'AMX', 'number_of_employees': 346},
#  {'name': 'Secure Computing', 'number_of_employees': 344},
#  {'name': 'iPayment', 'number_of_employees': 330},
#  {'name': 'Wuxi Qiaolian Wind Power Technology', 'number_of_employees': 325},
#  {'name': 'LiveOps', 'number_of_employees': 320},
#  {'name': 'HotCourses', 'number_of_employees': 320},
#  {'name': 'HotCourses', 'number_of_employees': 320},
#  {'name': 'FireEye', 'number_of_employees': 320},
#  {'name': 'Elite Advanced Laser Corporation', 'number_of_employees': 320},
#  {'name': 'Trusteer', 'number_of_employees': 310},
#  {'name': 'OpenX', 'number_of_employees': 305},
#  {'name': 'optionsXpress', 'number_of_employees': 305},
#  {'name': 'TRUECar', 'number_of_employees': 303},
#  {'name': 'TRUECar', 'number_of_employees': 303},
#  {'name': 'iContact', 'number_of_employees': 300},
#  {'name': 'MobiTV', 'number_of_employees': 300},
#  {'name': 'Adknowledge', 'number_of_employees': 300},
#  {'name': 'ChannelAdvisor', 'number_of_employees': 300},
#  {'name': 'Ooyala', 'number_of_employees': 300},
#  {'name': 'Skyscanner', 'number_of_employees': 300},
#  {'name': 'Etsy', 'number_of_employees': 300},
#  {'name': 'Coverity', 'number_of_employees': 300},
#  {'name': 'VZnet Netzwerke', 'number_of_employees': 300},
#  {'name': 'Absolute Software', 'number_of_employees': 300},
#  {'name': 'SmallWorlds', 'number_of_employees': 300},
#  {'name': 'CareerNet', 'number_of_employees': 300},
#  {'name': 'NetSpend', 'number_of_employees': 300},
#  {'name': 'AdParlor', 'number_of_employees': 300},
#  {'name': 'Klee Group', 'number_of_employees': 300},
#  {'name': 'Mobiquest', 'number_of_employees': 300},
#  {'name': 'Epocrates', 'number_of_employees': 300},
#  {'name': 'Keynote Systems', 'number_of_employees': 300},
#  {'name': 'Propertyware', 'number_of_employees': 300},
#  {'name': 'Bytemobile', 'number_of_employees': 300},
#  {'name': 'Indiagames', 'number_of_employees': 300},
#  {'name': 'Grus Construction Personnel', 'number_of_employees': 300},
#  {'name': 'Jataayu Software Ltd', 'number_of_employees': 300},
#  {'name': 'Centro', 'number_of_employees': 300},
#  {'name': 'SPIL GAMES', 'number_of_employees': 300},
#  {'name': 'Jaincotech', 'number_of_employees': 300},
#  {'name': 'LoopNet', 'number_of_employees': 300},
#  {'name': 'Veritas Prep', 'number_of_employees': 300},
#  {'name': 'Quality Web Solutions', 'number_of_employees': 300},
#  {'name': 'Stored Value Systems', 'number_of_employees': 300},
#  {'name': 'TechAspect Solutions', 'number_of_employees': 300},
#  {'name': 'Icreon Communications', 'number_of_employees': 300},
#  {'name': 'Synapse', 'number_of_employees': 300},
#  {'name': 'inContact', 'number_of_employees': 300},
#  {'name': 'Paisawaisa', 'number_of_employees': 300},
#  {'name': 'AbodesIndia', 'number_of_employees': 300},
#  {'name': 'Bluewolf', 'number_of_employees': 300},
#  {'name': 'BetterTrades', 'number_of_employees': 300},
#  {'name': 'White House Business Solutions', 'number_of_employees': 300},
#  {'name': 'Binbit', 'number_of_employees': 300},
#  {'name': 'Delhitoagra', 'number_of_employees': 300},
#  {'name': 'Cogniance', 'number_of_employees': 300},
#  {'name': 'EFJohnson Technologies', 'number_of_employees': 290},
#  {'name': 'Evernote', 'number_of_employees': 280},
#  {'name': 'Practice Fusion', 'number_of_employees': 280},
#  {'name': 'Koolanoo Group', 'number_of_employees': 280},
#  {'name': 'Koolanoo Group', 'number_of_employees': 280},
#  {'name': 'InfoAppenders', 'number_of_employees': 280},
#  {'name': 'Initiate Systems', 'number_of_employees': 280},
#  {'name': 'Magento', 'number_of_employees': 275},
#  {'name': 'ioko', 'number_of_employees': 270},
#  {'name': 'Optium', 'number_of_employees': 267},
#  {'name': 'Ambassadors Group', 'number_of_employees': 267},
#  {'name': 'Sportsline', 'number_of_employees': 264},
#  {'name': 'Marketo', 'number_of_employees': 260},
#  {'name': 'NetQoS', 'number_of_employees': 260},
#  {'name': 'net-m', 'number_of_employees': 260},
#  {'name': 'Icera', 'number_of_employees': 260},
#  {'name': 'iomart Group', 'number_of_employees': 260},
#  {'name': 'Mixi', 'number_of_employees': 257},
#  {'name': 'Ustream', 'number_of_employees': 250},
#  {'name': 'Espotting', 'number_of_employees': 250},
#  {'name': 'GrubHub', 'number_of_employees': 250},
#  {'name': 'Badoo', 'number_of_employees': 250},
#  {'name': 'Kareo', 'number_of_employees': 250},
#  {'name': 'Zuora', 'number_of_employees': 250},
#  {'name': 'NetShops', 'number_of_employees': 250},
#  {'name': 'ZEDO', 'number_of_employees': 250},
#  {'name': 'RichRelevance', 'number_of_employees': 250},
#  {'name': 'Tiny Prints', 'number_of_employees': 250},
#  {'name': 'CyberCoders', 'number_of_employees': 250},
#  {'name': 'Shoplocal', 'number_of_employees': 250},
#  {'name': 'BUKA', 'number_of_employees': 250},
#  {'name': 'LateRooms', 'number_of_employees': 250},
#  {'name': 'InfoReach', 'number_of_employees': 250},
#  {'name': 'InfoReach', 'number_of_employees': 250},
#  {'name': 'Webguru-India', 'number_of_employees': 250},
#  {'name': 'Analytical Graphics', 'number_of_employees': 250},
#  {'name': 'Acquirelists', 'number_of_employees': 250},
#  {'name': 'Synaptics', 'number_of_employees': 250},
#  {'name': 'Venda', 'number_of_employees': 250},
#  {'name': 'OpenMarket', 'number_of_employees': 250},
#  {'name': 'eCopy', 'number_of_employees': 250},
#  {'name': 'Dyn', 'number_of_employees': 250},
#  {'name': 'Sunbelt Software', 'number_of_employees': 250},
#  {'name': 'SurveyMonkey', 'number_of_employees': 250},
#  {'name': 'MAQ Software', 'number_of_employees': 250},
#  {'name': 'PSR Productions', 'number_of_employees': 250},
#  {'name': 'Venere', 'number_of_employees': 250},
#  {'name': 'MarketsandMarkets', 'number_of_employees': 250},
#  {'name': 'Accurate Background', 'number_of_employees': 250},
#  {'name': 'Netsize', 'number_of_employees': 250},
#  {'name': 'Galam', 'number_of_employees': 250},
#  {'name': 'Maxymiser', 'number_of_employees': 250},
#  {'name': 'Onyx Software', 'number_of_employees': 245},
#  {'name': 'Iomega', 'number_of_employees': 240},
#  {'name': 'Geary Interactive', 'number_of_employees': 240},
#  {'name': 'ClickandBuy', 'number_of_employees': 240},
#  {'name': 'MarkLogic', 'number_of_employees': 240},
#  {'name': 'Jobnownow Recruitment Agency', 'number_of_employees': 240},
#  {'name': 'AMEC', 'number_of_employees': 240},
#  {'name': 'Genesis Communications', 'number_of_employees': 235},
#  {'name': 'Spreadshirt', 'number_of_employees': 230},
#  {'name': 'TubeMogul', 'number_of_employees': 230},
#  {'name': 'Gigya', 'number_of_employees': 230},
#  {'name': 'Astaro', 'number_of_employees': 230},
#  {'name': 'Cloudera', 'number_of_employees': 230},
#  {'name': 'SolarEdge', 'number_of_employees': 230},
#  {'name': 'Tiempo Development', 'number_of_employees': 230},
#  {'name': 'WSO2', 'number_of_employees': 228},
#  {'name': 'Zango', 'number_of_employees': 225},
#  {'name': 'Pivotal Labs', 'number_of_employees': 225},
#  {'name': 'Realtime Worlds', 'number_of_employees': 225},
#  {'name': 'Go2Net', 'number_of_employees': 225},
#  {'name': 'deltatre', 'number_of_employees': 225},
#  {'name': 'TARGUSinfo', 'number_of_employees': 225},
#  {'name': 'Next Jump', 'number_of_employees': 225},
#  {'name': 'Amber Networks', 'number_of_employees': 223},
#  {'name': 'UQ Communications', 'number_of_employees': 222},
#  {'name': 'Brightcove', 'number_of_employees': 220},
#  {'name': 'Location Labs', 'number_of_employees': 220},
#  {'name': 'Avisena', 'number_of_employees': 220},
#  {'name': 'GlobalEnglish', 'number_of_employees': 220},
#  {'name': 'Cellfish', 'number_of_employees': 220},
#  {'name': 'OZ Communications', 'number_of_employees': 220},
#  {'name': 'Liferay', 'number_of_employees': 220},
#  {'name': 'Shutterstock', 'number_of_employees': 220},
#  {'name': 'StorageNetworks', 'number_of_employees': 220},
#  {'name': 'CFH Docmail', 'number_of_employees': 220},
#  {'name': 'AuthenTec', 'number_of_employees': 220},
#  {'name': 'Alert Logic', 'number_of_employees': 217},
#  {'name': 'MentorMate', 'number_of_employees': 216},
#  {'name': 'Conduit', 'number_of_employees': 215},
#  {'name': 'Appian', 'number_of_employees': 215},
#  {'name': 'ePartners', 'number_of_employees': 215},
#  {'name': 'Pervasive Software', 'number_of_employees': 214},
#  {'name': 'TRIRIGA', 'number_of_employees': 214},
#  {'name': 'Clearwell Systems', 'number_of_employees': 210},
#  {'name': 'ZAO Begun', 'number_of_employees': 210},
#  {'name': 'iWeb Technologies', 'number_of_employees': 210},
#  {'name': 'iWeb Technologies', 'number_of_employees': 210},
#  {'name': 'Global Relay', 'number_of_employees': 210},
#  {'name': 'AvantGo', 'number_of_employees': 208},
#  {'name': 'Odnoklassniki', 'number_of_employees': 207},
#  {'name': 'Inventa Technologies', 'number_of_employees': 207},
#  {'name': 'InfoLogix', 'number_of_employees': 206},
#  {'name': 'WebVisible', 'number_of_employees': 205},
#  {'name': 'babbel', 'number_of_employees': 205},
#  {'name': 'Catapult Communications', 'number_of_employees': 205},
#  {'name': 'Meebo', 'number_of_employees': 200},
#  {'name': 'Eventbrite', 'number_of_employees': 200},
#  {'name': 'Hightail', 'number_of_employees': 200},
#  {'name': 'KIT digital', 'number_of_employees': 200},
#  {'name': 'Zimbra', 'number_of_employees': 200},
#  {'name': 'Automattic', 'number_of_employees': 200},
#  {'name': 'Payoneer', 'number_of_employees': 200},
#  {'name': 'Deezer', 'number_of_employees': 200},
#  {'name': 'Woot', 'number_of_employees': 200},
#  {'name': 'GameDuell', 'number_of_employees': 200},
#  {'name': 'Fibre2fashion', 'number_of_employees': 200},
#  {'name': 'OpenDNS', 'number_of_employees': 200},
#  {'name': 'Huddle', 'number_of_employees': 200},
#  {'name': 'PixelCrayons', 'number_of_employees': 200},
#  {'name': 'Turbine', 'number_of_employees': 200},
#  {'name': 'PatientsLikeMe', 'number_of_employees': 200},
#  {'name': 'Neutralize', 'number_of_employees': 200},
#  {'name': 'The Motley Fool', 'number_of_employees': 200},
#  {'name': 'Efficient Frontier', 'number_of_employees': 200},
#  {'name': 'Aedgency', 'number_of_employees': 200},
#  {'name': "Tom's Hardware", 'number_of_employees': 200},
#  {'name': 'Bestofmedia Group', 'number_of_employees': 200},
#  {'name': 'Optaros', 'number_of_employees': 200},
#  {'name': 'Dot Com Infoway France', 'number_of_employees': 200},
#  {'name': 'Future US', 'number_of_employees': 200},
#  {'name': 'Douban', 'number_of_employees': 200},
#  {'name': 'Nextiva', 'number_of_employees': 200},
#  {'name': 'Hexacta', 'number_of_employees': 200},
#  {'name': 'Redwood Software', 'number_of_employees': 200},
#  {'name': 'AMAX Global Services', 'number_of_employees': 200},
#  {'name': 'Stylesight', 'number_of_employees': 200},
#  {'name': 'Nextiva', 'number_of_employees': 200},
#  {'name': 'Hexacta', 'number_of_employees': 200},
#  {'name': 'Redwood Software', 'number_of_employees': 200},
#  {'name': 'AMAX Global Services', 'number_of_employees': 200},
#  {'name': 'Stylesight', 'number_of_employees': 200},
#  {'name': 'Mindjet', 'number_of_employees': 200},
#  {'name': 'Nexenta Systems', 'number_of_employees': 200},
#  {'name': 'Propellum', 'number_of_employees': 200},
#  {'name': 'Agriya', 'number_of_employees': 200},
#  {'name': 'Tekriti Software', 'number_of_employees': 200},
#  {'name': 'GENEVA SOFTWARE TECHNOLOGIES LTD', 'number_of_employees': 200},
#  {'name': 'CampusEAI', 'number_of_employees': 200},
#  {'name': 'OpSource', 'number_of_employees': 200},
#  {'name': 'Nstein Technologies', 'number_of_employees': 200},
#  {'name': 'Wink Bill', 'number_of_employees': 200},
#  {'name': 'Sonim Technologies', 'number_of_employees': 200},
#  {'name': 'OSSCube Solutions', 'number_of_employees': 200},
#  {'name': 'Radix Web', 'number_of_employees': 200},
#  {'name': 'Namco Bandai', 'number_of_employees': 200},
#  {'name': 'Compulink Systems', 'number_of_employees': 200},
#  {'name': 'National Association of Professional Women',
#   'number_of_employees': 200},
#  {'name': 'Rigel Networks', 'number_of_employees': 200},
#  {'name': 'Power-battery', 'number_of_employees': 200},
#  {'name': 'Perforce Software', 'number_of_employees': 200},
#  {'name': 'Shriv Commedia Solutions Pvt Ltd', 'number_of_employees': 200},
#  {'name': 'EyeBuyDirect', 'number_of_employees': 200},
#  {'name': 'Skytap', 'number_of_employees': 200},
#  {'name': 'Jobspring Partners', 'number_of_employees': 200},
#  {'name': 'Unity Technologies', 'number_of_employees': 200},
#  {'name': 'Idea Couture', 'number_of_employees': 200},
#  {'name': 'Sowre', 'number_of_employees': 200},
#  {'name': 'Webfusion', 'number_of_employees': 200},
#  {'name': 'Elluminate', 'number_of_employees': 200},
#  {'name': 'Teradici', 'number_of_employees': 200},
#  {'name': 'amfAR', 'number_of_employees': 200},
#  {'name': 'Minecode', 'number_of_employees': 200},
#  {'name': 'Chikka', 'number_of_employees': 200},
#  {'name': 'NetRetail Holding', 'number_of_employees': 200},
#  {'name': 'eMeter', 'number_of_employees': 200},
#  {'name': 'AeroScout', 'number_of_employees': 200},
#  {'name': 'HauteLook', 'number_of_employees': 200},
#  {'name': 'Unitrends Software', 'number_of_employees': 200},
#  {'name': 'Kerio Technologies', 'number_of_employees': 200},
#  {'name': 'Dimension Funding', 'number_of_employees': 200},
#  {'name': 'uttarbharat Inc', 'number_of_employees': 200},
#  {'name': 'Novariant', 'number_of_employees': 200},
#  {'name': 'viastore systems', 'number_of_employees': 200},
#  {'name': 'Avantium Technologies', 'number_of_employees': 200},
#  {'name': 'Yahoo! Brazil', 'number_of_employees': 200},
#  {'name': 'Idealo', 'number_of_employees': 200},
#  {'name': 'Sky Bird Travel  Tours', 'number_of_employees': 200},
#  {'name': '800APP', 'number_of_employees': 200},
#  {'name': 'SheKnows', 'number_of_employees': 200},
#  {'name': 'American Land Lease', 'number_of_employees': 195},
#  {'name': 'uShip', 'number_of_employees': 190},
#  {'name': 'SquareTrade', 'number_of_employees': 190},
#  {'name': 'Squarespace', 'number_of_employees': 190},
#  {'name': 'Yellowbrix', 'number_of_employees': 190},
#  {'name': 'Razorsight', 'number_of_employees': 190},
#  {'name': 'LearningMate', 'number_of_employees': 190},
#  {'name': 'Audience', 'number_of_employees': 189},
#  {'name': 'Cmed', 'number_of_employees': 188},
#  {'name': 'OneSource Information Services', 'number_of_employees': 185},
#  {'name': 'airG', 'number_of_employees': 180},
#  {'name': 'Glassdoor', 'number_of_employees': 180},
#  {'name': 'Lyft', 'number_of_employees': 180},
#  {'name': 'Lyft', 'number_of_employees': 180},
#  {'name': 'u-blox', 'number_of_employees': 180},
#  {'name': 'Sunrun', 'number_of_employees': 180},
#  {'name': 'Ipswitch', 'number_of_employees': 180},
#  {'name': 'NetScaler', 'number_of_employees': 180},
#  {'name': 'Swiftprosys', 'number_of_employees': 180},
#  {'name': 'Infinity Pharmaceuticals', 'number_of_employees': 179},
#  {'name': 'Interliant', 'number_of_employees': 176},
#  {'name': 'fabrik', 'number_of_employees': 175},
#  {'name': 'Courion Corporation', 'number_of_employees': 175},
#  {'name': 'Courion Corporation', 'number_of_employees': 175},
#  {'name': 'BrainPulse', 'number_of_employees': 175},
#  {'name': 'ClickSquared', 'number_of_employees': 175},
#  {'name': 'Vocalocity', 'number_of_employees': 175},
#  {'name': 'WANdisco', 'number_of_employees': 175},
#  {'name': 'Turtle Entertainment', 'number_of_employees': 175},
#  {'name': 'Jimdo', 'number_of_employees': 170},
#  {'name': 'PacketFront', 'number_of_employees': 170},
#  {'name': 'Natta', 'number_of_employees': 170},
#  {'name': 'Program-Ace', 'number_of_employees': 170},
#  {'name': 'Chelsio Communications', 'number_of_employees': 170},
#  {'name': 'eModeration', 'number_of_employees': 170},
#  {'name': 'Workbridge Associates', 'number_of_employees': 170},
#  {'name': 'Foursquare', 'number_of_employees': 170},
#  {'name': 'Tuenti Technologies', 'number_of_employees': 170},
#  {'name': 'Shopatron', 'number_of_employees': 166},
#  {'name': 'Hifn', 'number_of_employees': 166},
#  {'name': 'Five9', 'number_of_employees': 165},
#  {'name': 'Digital Marketing Solutions', 'number_of_employees': 165},
#  {'name': 'Urban Airship', 'number_of_employees': 165},
#  {'name': 'Layer 7 Technologies', 'number_of_employees': 165},
#  {'name': 'QSGI', 'number_of_employees': 164},
#  {'name': 'Gorilla Nation Media', 'number_of_employees': 163},
#  {'name': 'Tagged', 'number_of_employees': 162},
#  {'name': 'Prevail Resources', 'number_of_employees': 162},
#  {'name': 'Clickable', 'number_of_employees': 160},
#  {'name': 'Kaltura', 'number_of_employees': 160},
#  {'name': 'Cubics', 'number_of_employees': 160},
#  {'name': 'AdoTube', 'number_of_employees': 160},
#  {'name': 'Sabrix', 'number_of_employees': 160},
#  {'name': 'Sedo', 'number_of_employees': 160},
#  {'name': 'OrangeSoda', 'number_of_employees': 160},
#  {'name': 'Livebookings', 'number_of_employees': 160},
#  {'name': 'Centrify', 'number_of_employees': 160},
#  {'name': 'Centrify', 'number_of_employees': 160},
#  {'name': 'SinoTech Group', 'number_of_employees': 160},
#  {'name': 'mFoundry', 'number_of_employees': 160},
#  {'name': 'Nexway', 'number_of_employees': 160},
#  {'name': 'Quantum Secure', 'number_of_employees': 160},
#  {'name': 'Mobile Messenger', 'number_of_employees': 160},
#  {'name': 'WIT Software', 'number_of_employees': 160},
#  {'name': 'FreeWheel', 'number_of_employees': 160},
#  {'name': 'Abilis Solutions', 'number_of_employees': 160},
#  {'name': 'Savvion', 'number_of_employees': 160},
#  {'name': 'CoreMedia', 'number_of_employees': 154},
#  {'name': 'IsayBlog!', 'number_of_employees': 154},
#  {'name': 'hulu', 'number_of_employees': 153},
#  {'name': 'Innuity', 'number_of_employees': 151},
#  {'name': 'IMVU', 'number_of_employees': 150},
#  {'name': 'Blurb', 'number_of_employees': 150},
#  {'name': 'The Climate Corporation', 'number_of_employees': 150},
#  {'name': 'tyntec', 'number_of_employees': 150},
#  {'name': 'Oversee', 'number_of_employees': 150},
#  {'name': 'Adchemy', 'number_of_employees': 150},
#  {'name': 'Exalead', 'number_of_employees': 150},
#  {'name': 'Pentaho', 'number_of_employees': 150},
#  {'name': 'Flurry', 'number_of_employees': 150},
#  {'name': 'Boonty', 'number_of_employees': 150},
#  {'name': 'InMage Systems', 'number_of_employees': 150},
#  {'name': 'Allopass', 'number_of_employees': 150},
#  {'name': 'Bonobos', 'number_of_employees': 150},
#  {'name': 'iRise', 'number_of_employees': 150},
#  {'name': 'Volusion', 'number_of_employees': 150},
#  {'name': 'Daptiv', 'number_of_employees': 150},
#  {'name': 'TouchLocal', 'number_of_employees': 150},
#  {'name': 'BullsEye Telecom', 'number_of_employees': 150},
#  {'name': 'AtHoc', 'number_of_employees': 150},
#  {'name': 'Technology Evaluation Centers', 'number_of_employees': 150},
#  {'name': 'Trisoft Consulting', 'number_of_employees': 150},
#  {'name': 'Intacct', 'number_of_employees': 150},
#  {'name': 'InsideView', 'number_of_employees': 150},
#  {'name': 'NameMedia', 'number_of_employees': 150},
#  {'name': 'Mendix', 'number_of_employees': 150},
#  {'name': 'Rhapsody', 'number_of_employees': 150},
#  {'name': 'Achievers', 'number_of_employees': 150},
#  {'name': 'Milestone Systems', 'number_of_employees': 150},
#  {'name': 'Qumu', 'number_of_employees': 150},
#  {'name': 'ngmoco', 'number_of_employees': 150},
#  {'name': 'Vantage Media', 'number_of_employees': 150},
#  {'name': 'Qualiteam Software', 'number_of_employees': 150},
#  {'name': 'BCC Research', 'number_of_employees': 150},
#  {'name': 'Voxeo', 'number_of_employees': 150},
#  {'name': 'Cutter Consortium', 'number_of_employees': 150},
#  {'name': 'BCC Research', 'number_of_employees': 150},
#  {'name': 'Voxeo', 'number_of_employees': 150},
#  {'name': 'Cutter Consortium', 'number_of_employees': 150},
#  {'name': 'LogLogic', 'number_of_employees': 150},
#  {'name': 'NativeX', 'number_of_employees': 150},
#  {'name': 'EDI Specialists', 'number_of_employees': 150},
#  {'name': 'PatientKeeper', 'number_of_employees': 150},
#  {'name': 'Decho', 'number_of_employees': 150},
#  {'name': 'Appcelerator', 'number_of_employees': 150},
#  {'name': 'tBits Global', 'number_of_employees': 150},
#  {'name': 'Clarabridge', 'number_of_employees': 150},
#  {'name': 'Data Tech Computers', 'number_of_employees': 150},
#  {'name': 'Huiying Chemical Xiamen Company', 'number_of_employees': 150},
#  {'name': '88DB', 'number_of_employees': 150},
#  {'name': 'MapMyIndia', 'number_of_employees': 150},
#  {'name': 'i-Jet Media', 'number_of_employees': 150},
#  {'name': 'LeadsMarketer', 'number_of_employees': 150},
#  {'name': 'School Management Software', 'number_of_employees': 150},
#  {'name': 'Black Soft', 'number_of_employees': 150},
#  {'name': 'Imaginova', 'number_of_employees': 150},
#  {'name': 'Axcient', 'number_of_employees': 150},
#  {'name': 'Nimsoft', 'number_of_employees': 150},
#  {'name': 'Bomgar', 'number_of_employees': 150},
#  {'name': 'Birst', 'number_of_employees': 150},
#  {'name': 'NaturalMotion', 'number_of_employees': 150},
#  {'name': 'LEVEL Studios', 'number_of_employees': 150},
#  {'name': 'OpTier', 'number_of_employees': 150},
#  {'name': 'Solairedirect', 'number_of_employees': 150},
#  {'name': 'Tucows', 'number_of_employees': 150},
#  {'name': 'StreamBase Systems', 'number_of_employees': 149},
#  {'name': 'Koves Technologies', 'number_of_employees': 146},
#  {'name': 'Enliven Marketing Technologies', 'number_of_employees': 146},
#  {'name': 'Knewton', 'number_of_employees': 145},
#  {'name': 'Armjisoft Digital Rights Management Systems',
#   'number_of_employees': 145},
#  {'name': 'Continuum', 'number_of_employees': 145},
#  {'name': 'Netbiscuits', 'number_of_employees': 145},
#  {'name': 'American Broadband Family of Companies',
#   'number_of_employees': 144},
#  {'name': 'Copan Systems', 'number_of_employees': 144},
#  {'name': 'Wikimedia Foundation', 'number_of_employees': 143},
#  {'name': 'BlueKai', 'number_of_employees': 142},
#  {'name': 'Nimbuzz', 'number_of_employees': 140},
#  {'name': 'Business News Americas', 'number_of_employees': 140},
#  {'name': 'eSolar', 'number_of_employees': 140},
#  {'name': 'Medallia', 'number_of_employees': 140},
#  {'name': 'FusionOne', 'number_of_employees': 140},
#  {'name': 'Halogen Software', 'number_of_employees': 140},
#  {'name': 'Logia Group', 'number_of_employees': 140},
#  {'name': 'Orchard Information Systems', 'number_of_employees': 140},
#  {'name': 'Orchard Information Systems', 'number_of_employees': 140},
#  {'name': 'Populis', 'number_of_employees': 140},
#  {'name': 'Miniclip', 'number_of_employees': 140},
#  {'name': 'SecondMarket', 'number_of_employees': 140},
#  {'name': 'Intalio', 'number_of_employees': 140},
#  {'name': 'Adityaa Call Centre', 'number_of_employees': 140},
#  {'name': 'Brandsclub', 'number_of_employees': 140},
#  {'name': 'SolaRover', 'number_of_employees': 140},
#  {'name': 'Zemoga', 'number_of_employees': 140},
#  {'name': 'ixi mobile', 'number_of_employees': 138},
#  {'name': 'Millennial Media', 'number_of_employees': 137},
#  {'name': 'BlueLithium', 'number_of_employees': 135},
#  {'name': 'Thismoment', 'number_of_employees': 135},
#  {'name': 'CSSAGlobal', 'number_of_employees': 135},
#  {'name': 'Intelius', 'number_of_employees': 131},
#  {'name': 'PayScale', 'number_of_employees': 130},
#  {'name': 'Moz', 'number_of_employees': 130},
#  {'name': 'modu', 'number_of_employees': 130},
#  {'name': 'Zend Technologies', 'number_of_employees': 130},
#  {'name': 'Networked Insights', 'number_of_employees': 130},
#  {'name': 'TRUSTe', 'number_of_employees': 130},
#  {'name': 'CPXi', 'number_of_employees': 130},
#  {'name': 'thePlatform', 'number_of_employees': 130},
#  {'name': 'DSNR Media Group', 'number_of_employees': 130},
#  {'name': 'The Onion', 'number_of_employees': 130},
#  {'name': 'SAVO', 'number_of_employees': 130},
#  {'name': 'TradeCard', 'number_of_employees': 130},
#  {'name': 'API Outsourcing', 'number_of_employees': 130},
#  {'name': 'TradeCard', 'number_of_employees': 130},
#  {'name': 'API Outsourcing', 'number_of_employees': 130},
#  {'name': 'DERI', 'number_of_employees': 130},
#  {'name': 'Consileon Business Consultancy GmbH', 'number_of_employees': 130},
#  {'name': 'Bitam', 'number_of_employees': 130},
#  {'name': 'Elemental Technologies', 'number_of_employees': 130},
#  {'name': 'Classic Informatics', 'number_of_employees': 130},
#  {'name': 'Z2Live', 'number_of_employees': 130},
#  {'name': 'Geeknet', 'number_of_employees': 127},
#  {'name': 'Clickbooth', 'number_of_employees': 126},
#  {'name': 'Clickbooth', 'number_of_employees': 126},
#  {'name': 'Nexsan', 'number_of_employees': 126},
#  {'name': 'The Orchard', 'number_of_employees': 125},
#  {'name': 'Velocify', 'number_of_employees': 125},
#  {'name': 'Bronto Software', 'number_of_employees': 125},
#  {'name': 'TeleSciences', 'number_of_employees': 125},
#  {'name': 'MediaMath', 'number_of_employees': 125},
#  {'name': 'RGB Networks', 'number_of_employees': 125},
#  {'name': 'Pointlogic', 'number_of_employees': 125},
#  {'name': 'Fluid', 'number_of_employees': 125},
#  {'name': 'Soft-genesis', 'number_of_employees': 124},
#  {'name': 'Facebookster', 'number_of_employees': 124},
#  {'name': 'Modern Feed', 'number_of_employees': 123},
#  {'name': 'PlayNetwork', 'number_of_employees': 122},
#  {'name': 'Next New Networks', 'number_of_employees': 121},
#  {'name': 'AddThis', 'number_of_employees': 120},
#  {'name': 'Livestream', 'number_of_employees': 120},
#  {'name': 'Dailymotion', 'number_of_employees': 120},
#  {'name': 'oDesk', 'number_of_employees': 120},
#  {'name': 'spigit', 'number_of_employees': 120},
#  {'name': 'PowerReviews', 'number_of_employees': 120},
#  {'name': 'Wamba', 'number_of_employees': 120},
#  {'name': 'uTest', 'number_of_employees': 120},
#  {'name': 'MyBuys', 'number_of_employees': 120},
#  {'name': 'Vobile', 'number_of_employees': 120},
#  {'name': 'Ingenio', 'number_of_employees': 120},
#  {'name': 'TrustedID', 'number_of_employees': 120},
#  {'name': 'Voltage Security', 'number_of_employees': 120},
#  {'name': '7digital', 'number_of_employees': 120},
#  {'name': 'BlueCat Networks', 'number_of_employees': 120},
#  {'name': 'TigerLogic', 'number_of_employees': 120},
#  {'name': 'Adify', 'number_of_employees': 120},
#  {'name': 'deviantART', 'number_of_employees': 120},
#  {'name': 'Macronimous Web Solutions', 'number_of_employees': 120},
#  {'name': 'Vernalis Systems', 'number_of_employees': 120},
#  {'name': 'New Media Strategies', 'number_of_employees': 120},
#  {'name': 'Avature', 'number_of_employees': 120},
#  {'name': 'Zagat', 'number_of_employees': 120},
#  {'name': 'Integrate', 'number_of_employees': 120},
#  {'name': 'Popego', 'number_of_employees': 120},
#  {'name': 'Integrate', 'number_of_employees': 120},
#  {'name': 'Popego', 'number_of_employees': 120},
#  {'name': 'Electronics Shop Limited', 'number_of_employees': 120},
#  {'name': 'Architel LP', 'number_of_employees': 120},
#  {'name': 'Model Metrics', 'number_of_employees': 120},
#  {'name': 'LINKBYNET', 'number_of_employees': 120},
#  {'name': 'Aristotle', 'number_of_employees': 120},
#  {'name': 'Bizclickusa', 'number_of_employees': 120},
#  {'name': 'Marand', 'number_of_employees': 120},
#  {'name': 'LiveOffice', 'number_of_employees': 120},
#  {'name': 'Malwarebytes', 'number_of_employees': 120},
#  {'name': 'VFM Leonardo', 'number_of_employees': 120},
#  {'name': 'CASAMUNDO', 'number_of_employees': 120},
#  {'name': 'Digium', 'number_of_employees': 120},
#  {'name': 'Quirky', 'number_of_employees': 120},
#  {'name': 'Telenity', 'number_of_employees': 120},
#  {'name': 'Varonis Systems', 'number_of_employees': 120},
#  {'name': 'Anteryon', 'number_of_employees': 120},
#  {'name': 'Mobile Interactive Group', 'number_of_employees': 120},
#  {'name': 'Fuze Box', 'number_of_employees': 120},
#  {'name': 'Merchantrms', 'number_of_employees': 117},
#  {'name': 'Zynga', 'number_of_employees': 115},
#  {'name': 'Minted', 'number_of_employees': 115},
#  {'name': 'CASON', 'number_of_employees': 115},
#  {'name': 'SpectorSoft', 'number_of_employees': 115},
#  {'name': 'Parts Express', 'number_of_employees': 115},
#  {'name': 'Aspiro', 'number_of_employees': 115},
#  {'name': 'Cybernetics', 'number_of_employees': 115},
#  {'name': 'Sixchannels', 'number_of_employees': 114},
#  {'name': 'Grooveshark', 'number_of_employees': 113},
#  {'name': 'Jajah', 'number_of_employees': 110},
#  {'name': 'Zecco', 'number_of_employees': 110},
#  {'name': 'TheLadders', 'number_of_employees': 110},
#  {'name': 'FreshBooks', 'number_of_employees': 110},
#  {'name': 'AtomicOnline', 'number_of_employees': 110},
#  {'name': 'LiveRail', 'number_of_employees': 110},
#  {'name': 'Clarizen', 'number_of_employees': 110},
#  {'name': 'MapVersa', 'number_of_employees': 110},
#  {'name': 'Verticity', 'number_of_employees': 110},
#  {'name': 'Prezi', 'number_of_employees': 110},
#  {'name': 'Hosted Solutions', 'number_of_employees': 110},
#  {'name': 'LeapFish', 'number_of_employees': 110},
#  {'name': 'Pronto Networks', 'number_of_employees': 110},
#  {'name': 'Nalini Networks', 'number_of_employees': 110},
#  {'name': 'Neverblue', 'number_of_employees': 110},
#  {'name': 'Metricus', 'number_of_employees': 110},
#  {'name': 'mogamebo', 'number_of_employees': 110},
#  {'name': 'APICS', 'number_of_employees': 110},
#  {'name': 'Basho Technologies', 'number_of_employees': 110},
#  {'name': 'Brandtology', 'number_of_employees': 110},
#  {'name': 'AspireHR', 'number_of_employees': 110},
#  {'name': 'Innotech Solar', 'number_of_employees': 110},
#  {'name': 'MicroVision', 'number_of_employees': 110},
#  {'name': 'Postindustria', 'number_of_employees': 110},
#  {'name': 'BreakingPoint Systems', 'number_of_employees': 109},
#  {'name': 'NetMotion Wireless', 'number_of_employees': 107},
#  {'name': 'G5 Entertainment', 'number_of_employees': 107},
#  {'name': 'RockYou', 'number_of_employees': 106},
#  {'name': 'GitHub', 'number_of_employees': 106},
#  {'name': 'Tribold', 'number_of_employees': 106},
#  {'name': 'Mojiva', 'number_of_employees': 105},
#  {'name': '[x+1]', 'number_of_employees': 105},
#  {'name': 'Epic Advertising', 'number_of_employees': 105},
#  {'name': '[x+1]', 'number_of_employees': 105},
#  {'name': 'Sift', 'number_of_employees': 105},
#  {'name': 'ControlCircle', 'number_of_employees': 105},
#  {'name': '2 Minutes', 'number_of_employees': 105},
#  {'name': 'Biolex Therapeutics', 'number_of_employees': 105},
#  {'name': 'Pontis', 'number_of_employees': 105},
#  {'name': 'iWin', 'number_of_employees': 103},
#  {'name': 'SundaySky', 'number_of_employees': 103},
#  {'name': 'Jama Software', 'number_of_employees': 103},
#  {'name': 'GoGrid', 'number_of_employees': 102},
#  {'name': 'OSA Technologies', 'number_of_employees': 102},
#  {'name': 'OfficialVirtualDJ', 'number_of_employees': 102},
#  {'name': 'KAYAK', 'number_of_employees': 101},
#  {'name': 'Jedox', 'number_of_employees': 101},
#  {'name': 'Redfin', 'number_of_employees': 100},
#  {'name': 'Simply Hired', 'number_of_employees': 100},
#  {'name': 'hi5', 'number_of_employees': 100},
#  {'name': 'INgage Networks', 'number_of_employees': 100},
#  {'name': 'mig33', 'number_of_employees': 100},
#  {'name': 'Fon', 'number_of_employees': 100},
#  {'name': 'EchoSign', 'number_of_employees': 100},
#  {'name': 'TrialPay', 'number_of_employees': 100},
#  {'name': 'Firetide', 'number_of_employees': 100},
#  {'name': 'Verimatrix', 'number_of_employees': 100},
#  {'name': 'Blyk', 'number_of_employees': 100},
#  {'name': 'Survey Analytics', 'number_of_employees': 100},
#  {'name': 'Social Gaming Network', 'number_of_employees': 100},
#  {'name': 'Covario', 'number_of_employees': 100},
#  {'name': '99designs', 'number_of_employees': 100},
#  {'name': 'Elance', 'number_of_employees': 100},
#  {'name': 'Vovici', 'number_of_employees': 100},
#  {'name': '2ergo', 'number_of_employees': 100},
#  {'name': 'Cheapflights', 'number_of_employees': 100},
#  {'name': 'Medindia', 'number_of_employees': 100},
#  {'name': 'Infibeam', 'number_of_employees': 100},
#  {'name': 'Parature', 'number_of_employees': 100},
#  {'name': 'WebCollage', 'number_of_employees': 100},
#  {'name': 'Red Bend Software', 'number_of_employees': 100},
#  {'name': 'Edmodo', 'number_of_employees': 100},
#  {'name': 'Glasses Direct', 'number_of_employees': 100},
#  {'name': 'myTino', 'number_of_employees': 100},
#  {'name': 'ServePath', 'number_of_employees': 100},
#  {'name': 'Mastiff Tech', 'number_of_employees': 100},
#  {'name': 'BuildDirect', 'number_of_employees': 100},
#  {'name': 'Tealeaf', 'number_of_employees': 100},
#  {'name': 'Phonewire', 'number_of_employees': 100},
#  {'name': 'Cartedge', 'number_of_employees': 100},
#  {'name': 'FIRST ROI', 'number_of_employees': 100},
#  {'name': 'Zero9', 'number_of_employees': 100},
#  {'name': 'Cloudmark', 'number_of_employees': 100},
#  {'name': 'Vindicia', 'number_of_employees': 100},
#  {'name': 'vLex', 'number_of_employees': 100},
#  {'name': 'Making Sense', 'number_of_employees': 100},
#  {'name': 'eEye', 'number_of_employees': 100},
#  {'name': 'Uniblue', 'number_of_employees': 100},
#  {'name': 'TDI', 'number_of_employees': 100},
#  {'name': 'Braithwaite Technology Consultants', 'number_of_employees': 100},
#  {'name': 'Blueprint Software Systems', 'number_of_employees': 100},
#  {'name': 'VBS TV', 'number_of_employees': 100},
#  {'name': 'Photobucket', 'number_of_employees': 100},
#  {'name': 'Troux Technologies', 'number_of_employees': 100},
#  {'name': 'Easypano', 'number_of_employees': 100},
#  {'name': 'plista', 'number_of_employees': 100},
#  {'name': 'TRSR Software', 'number_of_employees': 100},
#  {'name': 'Message Systems', 'number_of_employees': 100},
#  {'name': 'Cklear', 'number_of_employees': 100},
#  {'name': 'Black Duck Software', 'number_of_employees': 100},
#  {'name': 'Unicsis Technologies', 'number_of_employees': 100},
#  {'name': 'Ableton', 'number_of_employees': 100},
#  {'name': 'SpringSource', 'number_of_employees': 100},
#  {'name': 'Industria', 'number_of_employees': 100},
#  {'name': 'Passlogix', 'number_of_employees': 100},
#  {'name': 'SothinkMedia', 'number_of_employees': 100},
#  {'name': 'J-Curve Technologies', 'number_of_employees': 100},
#  {'name': 'Stack Exchange', 'number_of_employees': 100},
#  {'name': 'StepOut', 'number_of_employees': 100},
#  {'name': 'Procera Networks', 'number_of_employees': 100},
#  {'name': 'HexaCorp', 'number_of_employees': 100},
#  {'name': 'Fusion Garage', 'number_of_employees': 100},
#  {'name': 'Vichara Technologies', 'number_of_employees': 100},
#  {'name': 'XBOSoft', 'number_of_employees': 100},
#  {'name': 'J-Curve Technologies', 'number_of_employees': 100},
#  {'name': 'Stack Exchange', 'number_of_employees': 100},
#  {'name': 'StepOut', 'number_of_employees': 100},
#  {'name': 'Procera Networks', 'number_of_employees': 100},
#  {'name': 'HexaCorp', 'number_of_employees': 100},
#  {'name': 'Fusion Garage', 'number_of_employees': 100},
#  {'name': 'Vichara Technologies', 'number_of_employees': 100},
#  {'name': 'XBOSoft', 'number_of_employees': 100},
#  {'name': 'FetchBack', 'number_of_employees': 100},
#  {'name': 'Magnet Technologies India', 'number_of_employees': 100},
#  {'name': 'Telera', 'number_of_employees': 100},
#  {'name': 'inTALK', 'number_of_employees': 100},
#  {'name': 'SEO Services Group', 'number_of_employees': 100},
#  {'name': 'RiseSmart', 'number_of_employees': 100},
#  {'name': 'Whereismyboss', 'number_of_employees': 100},
#  {'name': 'InPage Incorporated', 'number_of_employees': 100},
#  {'name': 'The Hyperfactory', 'number_of_employees': 100},
#  {'name': 'Vuclip', 'number_of_employees': 100},
#  {'name': 'SolArc', 'number_of_employees': 100},
#  {'name': 'Think  Future', 'number_of_employees': 100},
#  {'name': 'SOASTA', 'number_of_employees': 100},
#  {'name': 'Open-Xchange', 'number_of_employees': 100},
#  {'name': 'JR Language Translation Services', 'number_of_employees': 100},
#  {'name': 'Trustpilot', 'number_of_employees': 100},
#  {'name': 'Trivantis Corporation', 'number_of_employees': 100},
#  {'name': 'Meirc Training and Consulting', 'number_of_employees': 100},
#  {'name': 'ShipServ', 'number_of_employees': 100},
#  {'name': 'ZipWeb', 'number_of_employees': 100},
#  {'name': 'Sendmail', 'number_of_employees': 100},
#  {'name': 'Twilio', 'number_of_employees': 100},
#  {'name': 'Cataphora', 'number_of_employees': 100},
#  {'name': 'Marden Edwards', 'number_of_employees': 100},
#  {'name': 'Novem -- China website development', 'number_of_employees': 100},
#  {'name': 'Jump Lab', 'number_of_employees': 100},
#  {'name': 'CyberSynchs', 'number_of_employees': 100},
#  {'name': 'DotNext', 'number_of_employees': 100},
#  {'name': 'Proxibid', 'number_of_employees': 100},
#  {'name': 'Exit41', 'number_of_employees': 100},
#  {'name': 'ScienceLogic', 'number_of_employees': 100},
#  {'name': 'QualSoft Services', 'number_of_employees': 100},
#  {'name': 'Solbright', 'number_of_employees': 100},
#  {'name': 'LawCrossing', 'number_of_employees': 100},
#  {'name': 'BCG Attorney Search', 'number_of_employees': 100},
#  {'name': 'Convate Consultancy Services  Private Ltd',
#   'number_of_employees': 100},
#  {'name': 'Legal Authority', 'number_of_employees': 100},
#  {'name': 'e-Spirit', 'number_of_employees': 100},
#  {'name': 'Fuel Industries', 'number_of_employees': 100},
#  {'name': 'Digimind', 'number_of_employees': 100},
#  {'name': 'InteQ', 'number_of_employees': 100},
#  {'name': 'Skout', 'number_of_employees': 100},
#  {'name': 'DesignArt Networks', 'number_of_employees': 100},
#  {'name': 'Naseeb Networks', 'number_of_employees': 100},
#  {'name': 'Compolette guide to weight loss', 'number_of_employees': 100},
#  {'name': 'DoublePositive', 'number_of_employees': 100},
#  {'name': 'Leo TechnoSoft', 'number_of_employees': 100},
#  {'name': 'NearSoft Europe', 'number_of_employees': 100},
#  {'name': 'Apalon', 'number_of_employees': 100},
#  {'name': 'Brothersoft', 'number_of_employees': 100},
#  {'name': 'Hirshorn Zuckerman Design Group', 'number_of_employees': 100},
#  {'name': 'Orca Interactive', 'number_of_employees': 100},
#  {'name': 'ZillionTV', 'number_of_employees': 100},
#  {'name': 'TIS India', 'number_of_employees': 100},
#  {'name': 'Lingo24', 'number_of_employees': 100},
#  {'name': 'Openbravo', 'number_of_employees': 100},
#  {'name': 'BelWo', 'number_of_employees': 100},
#  {'name': 'Smartbuzz', 'number_of_employees': 100},
#  {'name': 'NuView Systems', 'number_of_employees': 100},
#  {'name': 'SEOP', 'number_of_employees': 100},
#  {'name': 'Perception System', 'number_of_employees': 100},
#  {'name': 'Yourwovenphotos', 'number_of_employees': 100},
#  {'name': 'Broadband Suppliers', 'number_of_employees': 100},
#  {'name': 'Red Engineering Design', 'number_of_employees': 100},
#  {'name': 'Lehren Entertainment Pvt Ltd', 'number_of_employees': 100},
#  {'name': 'oscommerce experts', 'number_of_employees': 100},
#  {'name': 'Quallion', 'number_of_employees': 100},
#  {'name': 'Bullhorn', 'number_of_employees': 100},
#  {'name': 'Corvil', 'number_of_employees': 100},
#  {'name': 'Quality Copperworks LLC', 'number_of_employees': 100},
#  {'name': 'Canopy Financial', 'number_of_employees': 100},
#  {'name': 'Lending Stream', 'number_of_employees': 100},
#  {'name': 'Acme Scale Systems', 'number_of_employees': 100},
#  {'name': 'SatNav Technologies', 'number_of_employees': 100},
#  {'name': 'ContinuumGlobal', 'number_of_employees': 100},
#  {'name': 'Soffront', 'number_of_employees': 100},
#  {'name': 'Taipan Publishing Group', 'number_of_employees': 100},
#  {'name': 'Autoquake', 'number_of_employees': 100},
#  {'name': 'AVST', 'number_of_employees': 100},
#  {'name': 'GGK Tech', 'number_of_employees': 100},
#  {'name': 'Ergon Informatik', 'number_of_employees': 100},
#  {'name': 'EdeniQ', 'number_of_employees': 100},
#  {'name': 'Pathway Genomics', 'number_of_employees': 100},
#  {'name': 'Navtrak', 'number_of_employees': 100},
#  {'name': 'ZoomSystems', 'number_of_employees': 100},
#  {'name': 'Exent', 'number_of_employees': 100},
#  {'name': 'Mashable', 'number_of_employees': 100},
#  {'name': 'Applied Language Solutions', 'number_of_employees': 100},
#  {'name': 'NextLabs', 'number_of_employees': 100}]

# %% [markdown]
# ### 9. Order all the companies by their IPO price in a descending order.

# %%
list(colec.find({'ipo.valuation_amount':{'$gt':0}},
            
            {'name':1,'_id':0,'ipo.valuation_amount':1}).sort('ipo.valuation_amount',-1))
# Out:
# [{'name': 'GREE', 'ipo': {'valuation_amount': 108960000000}},
#  {'name': 'Facebook', 'ipo': {'valuation_amount': 104000000000}},
#  {'name': 'Amazon', 'ipo': {'valuation_amount': 100000000000}},
#  {'name': 'Twitter', 'ipo': {'valuation_amount': 18100000000}},
#  {'name': 'Groupon', 'ipo': {'valuation_amount': 12800000000}},
#  {'name': 'Tencent', 'ipo': {'valuation_amount': 11000000000}},
#  {'name': 'Western Digital', 'ipo': {'valuation_amount': 9430000000}},
#  {'name': 'LinkedIn', 'ipo': {'valuation_amount': 9310000000}},
#  {'name': 'BMC Software', 'ipo': {'valuation_amount': 6000000000}},
#  {'name': 'Rackspace', 'ipo': {'valuation_amount': 5440000000}},
#  {'name': 'Baidu', 'ipo': {'valuation_amount': 4000000000}},
#  {'name': 'TripAdvisor', 'ipo': {'valuation_amount': 3273770000}},
#  {'name': 'HomeAway', 'ipo': {'valuation_amount': 3000000000}},
#  {'name': 'Zillow', 'ipo': {'valuation_amount': 2550000000}},
#  {'name': 'Nielsen', 'ipo': {'valuation_amount': 1600000000}},
#  {'name': 'Yelp', 'ipo': {'valuation_amount': 1300000000}},
#  {'name': 'Chegg', 'ipo': {'valuation_amount': 1100000000}},
#  {'name': 'Chegg', 'ipo': {'valuation_amount': 1100000000}},
#  {'name': 'RPX Corporation', 'ipo': {'valuation_amount': 1096000000}},
#  {'name': 'Higher One', 'ipo': {'valuation_amount': 1060000000}},
#  {'name': 'OpenTable', 'ipo': {'valuation_amount': 1050000000}},
#  {'name': 'Jive Software', 'ipo': {'valuation_amount': 1000000000}},
#  {'name': 'BrightSource Energy', 'ipo': {'valuation_amount': 1000000000}},
#  {'name': 'QlikTech', 'ipo': {'valuation_amount': 1000000000}},
#  {'name': 'Millennial Media', 'ipo': {'valuation_amount': 973500000}},
#  {'name': 'Mixi', 'ipo': {'valuation_amount': 970000000}},
#  {'name': 'Cornerstone OnDemand', 'ipo': {'valuation_amount': 900000000}},
#  {'name': 'Infoblox', 'ipo': {'valuation_amount': 824000000}},
#  {'name': 'SolarWinds', 'ipo': {'valuation_amount': 803000000}},
#  {'name': 'Wix', 'ipo': {'valuation_amount': 750000000}},
#  {'name': 'Marketo', 'ipo': {'valuation_amount': 465000000}},
#  {'name': 'Opsware', 'ipo': {'valuation_amount': 450000000}},
#  {'name': 'Emdeon', 'ipo': {'valuation_amount': 367350000}},
#  {'name': 'Shutterfly', 'ipo': {'valuation_amount': 350000000}},
#  {'name': 'Telenav', 'ipo': {'valuation_amount': 337000000}},
#  {'name': 'Rally Software', 'ipo': {'valuation_amount': 315000000}},
#  {'name': 'STR', 'ipo': {'valuation_amount': 300000000}},
#  {'name': 'Brightcove', 'ipo': {'valuation_amount': 290000000}},
#  {'name': 'ChannelAdvisor', 'ipo': {'valuation_amount': 287000000}},
#  {'name': 'Elster Group', 'ipo': {'valuation_amount': 275000000}},
#  {'name': 'DemandTec', 'ipo': {'valuation_amount': 245000000}},
#  {'name': 'KIT digital', 'ipo': {'valuation_amount': 235000000}},
#  {'name': 'Tudou', 'ipo': {'valuation_amount': 174000000}},
#  {'name': 'DivX', 'ipo': {'valuation_amount': 160000000}},
#  {'name': 'QuinStreet', 'ipo': {'valuation_amount': 140000000}},
#  {'name': 'Geeknet', 'ipo': {'valuation_amount': 134000000}},
#  {'name': 'Salesforce', 'ipo': {'valuation_amount': 110000000}},
#  {'name': 'JumpTV', 'ipo': {'valuation_amount': 100000000}},
#  {'name': 'EnerNOC', 'ipo': {'valuation_amount': 95500000}},
#  {'name': 'Meru Networks', 'ipo': {'valuation_amount': 66600000}},
#  {'name': 'Real Goods Solar', 'ipo': {'valuation_amount': 55000000}},
#  {'name': 'Global Water', 'ipo': {'valuation_amount': 50000000}},
#  {'name': 'Pironet', 'ipo': {'valuation_amount': 44000000}},
#  {'name': 'Pironet', 'ipo': {'valuation_amount': 44000000}},
#  {'name': 'Inuvo', 'ipo': {'valuation_amount': 30000000}},
#  {'name': 'Inuvo', 'ipo': {'valuation_amount': 30000000}},
#  {'name': 'Energy and Power Solutions', 'ipo': {'valuation_amount': 25000000}},
#  {'name': 'Vringo', 'ipo': {'valuation_amount': 11003200}},
#  {'name': 'GT Solar', 'ipo': {'valuation_amount': 5000000}},
#  {'name': 'DeNA', 'ipo': {'valuation_amount': 117900}},
#  {'name': 'DeNA', 'ipo': {'valuation_amount': 117900}}]

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
list(colec.find({},
                
                {'name':1, '_id':0,'number_of_employees':1}).sort('number_of_employees',-1).limit(10))
# Out:
# [{'name': 'Siemens', 'number_of_employees': 405000},
#  {'name': 'IBM', 'number_of_employees': 388000},
#  {'name': 'Toyota', 'number_of_employees': 320000},
#  {'name': 'PayPal', 'number_of_employees': 300000},
#  {'name': 'Nippon Telegraph and Telephone Corporation',
#   'number_of_employees': 227000},
#  {'name': 'Samsung Electronics', 'number_of_employees': 221726},
#  {'name': 'Accenture', 'number_of_employees': 205000},
#  {'name': 'Tata Consultancy Services', 'number_of_employees': 200300},
#  {'name': 'Flextronics International', 'number_of_employees': 200000},
#  {'name': 'Safeway', 'number_of_employees': 186000}]

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
list(colec.find({'founded_month':{'$gte':6}},
            {'name':1, '_id':0, 'founded_month':1}).limit(1000))
# Out:
# [{'name': 'Wetpaint', 'founded_month': 10},
#  {'name': 'Zoho', 'founded_month': 9},
#  {'name': 'Digg', 'founded_month': 10},
#  {'name': 'Omnidrive', 'founded_month': 11},
#  {'name': 'Postini', 'founded_month': 6},
#  {'name': 'Geni', 'founded_month': 6},
#  {'name': 'Fox Interactive Media', 'founded_month': 6},
#  {'name': 'eBay', 'founded_month': 9},
#  {'name': 'Joost', 'founded_month': 10},
#  {'name': 'Plaxo', 'founded_month': 11},
#  {'name': 'Powerset', 'founded_month': 10},
#  {'name': 'Technorati', 'founded_month': 6},
#  {'name': 'Sparter', 'founded_month': 6},
#  {'name': 'Kyte', 'founded_month': 12},
#  {'name': 'Thoof', 'founded_month': 12},
#  {'name': 'Jingle Networks', 'founded_month': 9},
#  {'name': 'LifeLock', 'founded_month': 8},
#  {'name': 'Wesabe', 'founded_month': 12},
#  {'name': 'SmugMug', 'founded_month': 11},
#  {'name': 'Google', 'founded_month': 9},
#  {'name': 'Skype', 'founded_month': 8},
#  {'name': 'Pando Networks', 'founded_month': 7},
#  {'name': 'Ikan', 'founded_month': 12},
#  {'name': 'delicious', 'founded_month': 9},
#  {'name': 'Topix', 'founded_month': 6},
#  {'name': 'Pownce', 'founded_month': 6},
#  {'name': 'AllPeers', 'founded_month': 8},
#  {'name': 'Wize', 'founded_month': 8},
#  {'name': 'AllofMP3', 'founded_month': 6},
#  {'name': 'SellABand', 'founded_month': 8},
#  {'name': 'iContact', 'founded_month': 7},
#  {'name': 'MeeVee', 'founded_month': 7},
#  {'name': 'blinkx', 'founded_month': 12},
#  {'name': 'Zlio', 'founded_month': 11},
#  {'name': 'Yelp', 'founded_month': 7},
#  {'name': 'Jaiku', 'founded_month': 7},
#  {'name': 'Yapta', 'founded_month': 7},
#  {'name': 'Fleck', 'founded_month': 11},
#  {'name': 'SideStep', 'founded_month': 11},
#  {'name': 'RockYou', 'founded_month': 11},
#  {'name': 'Instructables', 'founded_month': 8},
#  {'name': 'Netvibes', 'founded_month': 9},
#  {'name': 'Swivel', 'founded_month': 12},
#  {'name': 'Slide', 'founded_month': 8},
#  {'name': 'TripHub', 'founded_month': 6},
#  {'name': 'CrowdVine', 'founded_month': 8},
#  {'name': 'TheFind', 'founded_month': 10},
#  {'name': 'TVtrip', 'founded_month': 6},
#  {'name': 'PBworks', 'founded_month': 6},
#  {'name': 'Sway', 'founded_month': 12},
#  {'name': 'CornerWorld', 'founded_month': 9},
#  {'name': 'WatZatSong', 'founded_month': 6},
#  {'name': 'FlickIM', 'founded_month': 12},
#  {'name': 'Terabitz', 'founded_month': 7},
#  {'name': 'Kaboodle', 'founded_month': 10},
#  {'name': 'GigaOM', 'founded_month': 7},
#  {'name': 'Redfin', 'founded_month': 10},
#  {'name': 'Wink', 'founded_month': 8},
#  {'name': 'Go2Web20', 'founded_month': 9},
#  {'name': 'Seesmic', 'founded_month': 6},
#  {'name': 'TechnologyGuide', 'founded_month': 10},
#  {'name': 'Hotelicopter', 'founded_month': 6},
#  {'name': 'Techmeme', 'founded_month': 10},
#  {'name': 'Ujogo', 'founded_month': 7},
#  {'name': 'Recipezaar', 'founded_month': 9},
#  {'name': 'Gumiyo', 'founded_month': 11},
#  {'name': 'stylediary', 'founded_month': 8},
#  {'name': 'Piczo', 'founded_month': 11},
#  {'name': 'Cyworld', 'founded_month': 7},
#  {'name': 'Socialtext', 'founded_month': 12},
#  {'name': 'spigit', 'founded_month': 6},
#  {'name': 'ConnectMeAnywhere', 'founded_month': 9},
#  {'name': 'hi5', 'founded_month': 12},
#  {'name': 'Clipperz', 'founded_month': 11},
#  {'name': 'Tagged', 'founded_month': 10},
#  {'name': 'Nintendo', 'founded_month': 9},
#  {'name': 'Indeed', 'founded_month': 11},
#  {'name': 'Jaxtr', 'founded_month': 10},
#  {'name': 'Cerado', 'founded_month': 7},
#  {'name': 'ONEsite', 'founded_month': 9},
#  {'name': 'Wallhogs', 'founded_month': 8},
#  {'name': 'Respectance', 'founded_month': 6},
#  {'name': 'eBuddy', 'founded_month': 9},
#  {'name': 'Grockit', 'founded_month': 12},
#  {'name': 'Adobe Systems', 'founded_month': 12},
#  {'name': 'JumpBox', 'founded_month': 7},
#  {'name': 'Phonezoo', 'founded_month': 11},
#  {'name': 'LongJump', 'founded_month': 7},
#  {'name': 'Relationals', 'founded_month': 7},
#  {'name': 'Wishpot', 'founded_month': 11},
#  {'name': 'Forbes', 'founded_month': 8},
#  {'name': 'Boonex', 'founded_month': 7},
#  {'name': 'IntenseDebate', 'founded_month': 12},
#  {'name': 'Rebtel', 'founded_month': 7},
#  {'name': 'Buxfer', 'founded_month': 7},
#  {'name': 'boo-box', 'founded_month': 7},
#  {'name': 'TextPayMe', 'founded_month': 12},
#  {'name': 'BillMonk', 'founded_month': 9},
#  {'name': 'PayPal', 'founded_month': 12},
#  {'name': 'MeeMix', 'founded_month': 6},
#  {'name': 'The Walt Disney Company', 'founded_month': 10},
#  {'name': 'Alstrasoft', 'founded_month': 6},
#  {'name': 'WebbAlert', 'founded_month': 8},
#  {'name': 'Rocketboom', 'founded_month': 8},
#  {'name': 'WallStrip', 'founded_month': 10},
#  {'name': 'IAC', 'founded_month': 8},
#  {'name': 'Techstars', 'founded_month': 10},
#  {'name': 'Nirvanix', 'founded_month': 7},
#  {'name': 'Zwinky', 'founded_month': 6},
#  {'name': 'Mokitown', 'founded_month': 11},
#  {'name': 'ActiveWorlds', 'founded_month': 6},
#  {'name': 'Neopets', 'founded_month': 11},
#  {'name': 'KnockaTV', 'founded_month': 8},
#  {'name': 'Pickle', 'founded_month': 6},
#  {'name': 'Revver', 'founded_month': 10},
#  {'name': 'Metacafe', 'founded_month': 7},
#  {'name': 'MindTouch', 'founded_month': 12},
#  {'name': 'ChaCha', 'founded_month': 12},
#  {'name': 'Sportingo', 'founded_month': 7},
#  {'name': 'Akamai Technologies', 'founded_month': 8},
#  {'name': 'Dropbox', 'founded_month': 6},
#  {'name': 'Splashup', 'founded_month': 10},
#  {'name': 'Curverider', 'founded_month': 8},
#  {'name': 'MobiTV', 'founded_month': 11},
#  {'name': 'SomethingSimpler', 'founded_month': 8},
#  {'name': 'Six Apart', 'founded_month': 9},
#  {'name': 'BitTorrent', 'founded_month': 9},
#  {'name': 'SuicideGirls', 'founded_month': 9},
#  {'name': 'Goowy', 'founded_month': 10},
#  {'name': 'MySpace', 'founded_month': 8},
#  {'name': 'InviteShare', 'founded_month': 7},
#  {'name': 'Doostang', 'founded_month': 6},
#  {'name': 'TechCrunch', 'founded_month': 6},
#  {'name': 'Docstoc', 'founded_month': 8},
#  {'name': 'Vlingo', 'founded_month': 6},
#  {'name': 'Mevio', 'founded_month': 10},
#  {'name': 'BitPass', 'founded_month': 12},
#  {'name': 'Alibaba', 'founded_month': 6},
#  {'name': 'eHarmony', 'founded_month': 8},
#  {'name': 'Yeigo', 'founded_month': 6},
#  {'name': 'TubeMogul', 'founded_month': 11},
#  {'name': 'Shopzilla', 'founded_month': 6},
#  {'name': 'dpreview', 'founded_month': 12},
#  {'name': 'Lastminute', 'founded_month': 10},
#  {'name': 'Multiply', 'founded_month': 12},
#  {'name': 'Webshots', 'founded_month': 6},
#  {'name': 'LimeLife', 'founded_month': 6},
#  {'name': 'OpenTable', 'founded_month': 7},
#  {'name': 'MocoSpace', 'founded_month': 10},
#  {'name': 'YouBeQB', 'founded_month': 8},
#  {'name': 'ChannelAdvisor', 'founded_month': 7},
#  {'name': 'Quattro Wireless', 'founded_month': 10},
#  {'name': 'Thumbplay', 'founded_month': 9},
#  {'name': 'Wonga', 'founded_month': 10},
#  {'name': 'Tutor', 'founded_month': 11},
#  {'name': 'Collagr', 'founded_month': 6},
#  {'name': 'SayNow', 'founded_month': 9},
#  {'name': 'CircleUp', 'founded_month': 10},
#  {'name': 'ContactOffice', 'founded_month': 7},
#  {'name': 'Yugma', 'founded_month': 10},
#  {'name': 'imeem', 'founded_month': 11},
#  {'name': 'AdMob', 'founded_month': 12},
#  {'name': 'AgentMatch', 'founded_month': 6},
#  {'name': 'Attributor', 'founded_month': 10},
#  {'name': 'Nemedia', 'founded_month': 7},
#  {'name': 'PeekYou', 'founded_month': 11},
#  {'name': 'ZocDoc', 'founded_month': 9},
#  {'name': 'WooMe', 'founded_month': 12},
#  {'name': 'Viewdle', 'founded_month': 7},
#  {'name': 'TripIt', 'founded_month': 10},
#  {'name': 'PubMatic', 'founded_month': 9},
#  {'name': 'app2you', 'founded_month': 10},
#  {'name': 'Orgoo', 'founded_month': 11},
#  {'name': 'HylioSoft', 'founded_month': 6},
#  {'name': 'YourStreet', 'founded_month': 11},
#  {'name': 'Ceedo Technologies', 'founded_month': 10},
#  {'name': 'FlowPlay', 'founded_month': 12},
#  {'name': 'IPartee', 'founded_month': 10},
#  {'name': 'Feedjit', 'founded_month': 7},
#  {'name': 'Viewpoints', 'founded_month': 8},
#  {'name': 'RatePoint', 'founded_month': 9},
#  {'name': 'ThisNext', 'founded_month': 12},
#  {'name': 'Avvo', 'founded_month': 6},
#  {'name': 'Clickable', 'founded_month': 12},
#  {'name': 'Extravigator', 'founded_month': 6},
#  {'name': 'mig33', 'founded_month': 12},
#  {'name': 'Animoto', 'founded_month': 8},
#  {'name': 'GamerDNA', 'founded_month': 10},
#  {'name': 'Pakt', 'founded_month': 10},
#  {'name': 'mEgo', 'founded_month': 10},
#  {'name': 'Realius', 'founded_month': 11},
#  {'name': 'Metaplace', 'founded_month': 7},
#  {'name': 'CafeScribe', 'founded_month': 10},
#  {'name': 'Fixya', 'founded_month': 6},
#  {'name': 'Syntraxis', 'founded_month': 11},
#  {'name': 'BrightQube', 'founded_month': 10},
#  {'name': 'BuzzDash', 'founded_month': 9},
#  {'name': 'BigSwerve', 'founded_month': 9},
#  {'name': 'Styky', 'founded_month': 12},
#  {'name': 'Goojet', 'founded_month': 12},
#  {'name': 'GroupSwim', 'founded_month': 10},
#  {'name': 'Diigo', 'founded_month': 7},
#  {'name': 'EkkoTV', 'founded_month': 9},
#  {'name': 'Kaltura', 'founded_month': 10},
#  {'name': 'Notemarks', 'founded_month': 10},
#  {'name': 'mPortico', 'founded_month': 10},
#  {'name': 'itsmylife', 'founded_month': 11},
#  {'name': 'Mobivox', 'founded_month': 10},
#  {'name': 'eGenerations', 'founded_month': 7},
#  {'name': 'FriendFeed', 'founded_month': 10},
#  {'name': 'Youlicit', 'founded_month': 9},
#  {'name': 'Babylon', 'founded_month': 9},
#  {'name': 'FlexiScale', 'founded_month': 9},
#  {'name': 'earthmine', 'founded_month': 7},
#  {'name': 'zSlide', 'founded_month': 12},
#  {'name': 'LocoGopher', 'founded_month': 6},
#  {'name': 'RecipeMatcher', 'founded_month': 10},
#  {'name': 'Whiskey Media', 'founded_month': 10},
#  {'name': 'alluc', 'founded_month': 6},
#  {'name': 'CondoDomain', 'founded_month': 10},
#  {'name': 'Confabb', 'founded_month': 6},
#  {'name': 'Automattic', 'founded_month': 7},
#  {'name': 'uTest', 'founded_month': 8},
#  {'name': 'Songkick', 'founded_month': 6},
#  {'name': 'Shopatron', 'founded_month': 10},
#  {'name': 'EchoSign', 'founded_month': 7},
#  {'name': 'Buzzwire', 'founded_month': 7},
#  {'name': 'Ubertor', 'founded_month': 6},
#  {'name': 'Crusher', 'founded_month': 9},
#  {'name': 'YowTRIP', 'founded_month': 9},
#  {'name': 'Rollbase', 'founded_month': 8},
#  {'name': 'XLNTads', 'founded_month': 11},
#  {'name': 'All-Scrap', 'founded_month': 10},
#  {'name': 'FeedMorf', 'founded_month': 10},
#  {'name': 'Moko Social Media', 'founded_month': 8},
#  {'name': 'blueKiwi', 'founded_month': 7},
#  {'name': 'Gydget', 'founded_month': 10},
#  {'name': 'Gigya', 'founded_month': 6},
#  {'name': 'Baynote', 'founded_month': 11},
#  {'name': 'YourSports', 'founded_month': 6},
#  {'name': 'Defensio', 'founded_month': 6},
#  {'name': 'Jango', 'founded_month': 11},
#  {'name': 'SezWho', 'founded_month': 10},
#  {'name': 'Qloud', 'founded_month': 11},
#  {'name': 'Pelago', 'founded_month': 12},
#  {'name': 'Upcoming', 'founded_month': 9},
#  {'name': 'DraftMix', 'founded_month': 6},
#  {'name': 'Excite@Home', 'founded_month': 12},
#  {'name': 'Zilok', 'founded_month': 10},
#  {'name': 'Faves', 'founded_month': 12},
#  {'name': 'BrainKeeper', 'founded_month': 10},
#  {'name': 'Evi', 'founded_month': 8},
#  {'name': 'GotCast', 'founded_month': 10},
#  {'name': 'MerchantCircle', 'founded_month': 10},
#  {'name': 'Zmags', 'founded_month': 12},
#  {'name': 'StreetFire', 'founded_month': 6},
#  {'name': 'Zecco', 'founded_month': 7},
#  {'name': 'Congoo', 'founded_month': 7},
#  {'name': 'Jackson Fish Market', 'founded_month': 11},
#  {'name': 'RealSelf', 'founded_month': 10},
#  {'name': 'GeoSentric', 'founded_month': 6},
#  {'name': 'ThriveSmart', 'founded_month': 9},
#  {'name': 'doof', 'founded_month': 9},
#  {'name': 'Bloglines', 'founded_month': 6},
#  {'name': 'OurStage', 'founded_month': 10},
#  {'name': 'GameLayers', 'founded_month': 7},
#  {'name': 'LinkStorm', 'founded_month': 8},
#  {'name': 'Zoji', 'founded_month': 10},
#  {'name': 'Entrecard', 'founded_month': 11},
#  {'name': 'Apprema', 'founded_month': 8},
#  {'name': 'HelpHookup', 'founded_month': 11},
#  {'name': 'Skribit', 'founded_month': 11},
#  {'name': 'ProductWiki', 'founded_month': 6},
#  {'name': 'Hark', 'founded_month': 10},
#  {'name': 'Splunk', 'founded_month': 10},
#  {'name': 'Shutterfly', 'founded_month': 9},
#  {'name': 'Localeze', 'founded_month': 10},
#  {'name': 'Youku', 'founded_month': 12},
#  {'name': 'YouOS', 'founded_month': 12},
#  {'name': 'Sendori', 'founded_month': 8},
#  {'name': 'Adhysteria', 'founded_month': 9},
#  {'name': 'Paltalk', 'founded_month': 6},
#  {'name': 'Songza', 'founded_month': 11},
#  {'name': 'SkreemR Search', 'founded_month': 6},
#  {'name': 'CollegeFanz', 'founded_month': 9},
#  {'name': 'Deezer', 'founded_month': 8},
#  {'name': 'italki', 'founded_month': 7},
#  {'name': 'eyeOS', 'founded_month': 8},
#  {'name': 'Desktoptwo', 'founded_month': 8},
#  {'name': 'MyNeighborhood', 'founded_month': 7},
#  {'name': 'HubSpot', 'founded_month': 6},
#  {'name': 'Utterz', 'founded_month': 9},
#  {'name': 'eventsbot', 'founded_month': 7},
#  {'name': 'Criticker', 'founded_month': 11},
#  {'name': 'Dapper', 'founded_month': 10},
#  {'name': 'ClickTale', 'founded_month': 6},
#  {'name': 'Twipster', 'founded_month': 12},
#  {'name': 'Twenga', 'founded_month': 9},
#  {'name': 'TradeKing', 'founded_month': 12},
#  {'name': 'Viadeo', 'founded_month': 6},
#  {'name': 'Jacked', 'founded_month': 6},
#  {'name': 'Iotum', 'founded_month': 12},
#  {'name': 'eBurl', 'founded_month': 11},
#  {'name': 'Vemo', 'founded_month': 11},
#  {'name': 'Smilebox', 'founded_month': 8},
#  {'name': 'Bahu', 'founded_month': 7},
#  {'name': 'AppJet', 'founded_month': 6},
#  {'name': 'Seethroo', 'founded_month': 7},
#  {'name': 'Summize', 'founded_month': 11},
#  {'name': 'HubPages', 'founded_month': 8},
#  {'name': 'Squidoo', 'founded_month': 10},
#  {'name': 'GoLark', 'founded_month': 8},
#  {'name': 'WeShow', 'founded_month': 6},
#  {'name': 'Qik', 'founded_month': 6},
#  {'name': 'Chictini', 'founded_month': 7},
#  {'name': 'Picktastic', 'founded_month': 10},
#  {'name': 'PlayFirst', 'founded_month': 9},
#  {'name': 'Libersy', 'founded_month': 8},
#  {'name': 'RipCode', 'founded_month': 8},
#  {'name': 'Mobissimo', 'founded_month': 10},
#  {'name': 'Etsy', 'founded_month': 6},
#  {'name': 'Causes', 'founded_month': 9},
#  {'name': 'SnapVillage', 'founded_month': 6},
#  {'name': 'PollDaddy', 'founded_month': 9},
#  {'name': 'Pinger', 'founded_month': 11},
#  {'name': 'Driftr', 'founded_month': 10},
#  {'name': 'Blekko', 'founded_month': 6},
#  {'name': 'jellyfish', 'founded_month': 12},
#  {'name': 'ice', 'founded_month': 9},
#  {'name': 'Workface', 'founded_month': 10},
#  {'name': 'Mogad', 'founded_month': 6},
#  {'name': 'Livemocha', 'founded_month': 9},
#  {'name': 'Mpayy', 'founded_month': 6},
#  {'name': 'fabrik', 'founded_month': 8},
#  {'name': 'CheerOutLoud', 'founded_month': 9},
#  {'name': 'DoYouBuzz', 'founded_month': 8},
#  {'name': 'FamCorner', 'founded_month': 6},
#  {'name': 'AF83', 'founded_month': 11},
#  {'name': 'Zynga', 'founded_month': 7},
#  {'name': 'Enforta', 'founded_month': 10},
#  {'name': 'Smaato', 'founded_month': 8},
#  {'name': 'AnsMart', 'founded_month': 12},
#  {'name': 'Mumboe', 'founded_month': 8},
#  {'name': 'Badoo', 'founded_month': 10},
#  {'name': 'UnLtdWorld', 'founded_month': 10},
#  {'name': 'Scrabulous', 'founded_month': 7},
#  {'name': 'Pornotube', 'founded_month': 7},
#  {'name': 'ReimagineMemories', 'founded_month': 11},
#  {'name': 'XING', 'founded_month': 8},
#  {'name': 'HouseFront', 'founded_month': 10},
#  {'name': 'Bizak', 'founded_month': 11},
#  {'name': 'Lijit Networks', 'founded_month': 6},
#  {'name': 'WorldTV', 'founded_month': 10},
#  {'name': '5pm', 'founded_month': 9},
#  {'name': 'GeoDentist', 'founded_month': 6},
#  {'name': 'Heroku', 'founded_month': 7},
#  {'name': 'Lookery', 'founded_month': 8},
#  {'name': 'comScore', 'founded_month': 8},
#  {'name': 'YouPorn', 'founded_month': 8},
#  {'name': 'TV Shack', 'founded_month': 12},
#  {'name': 'XLR8 Mobile', 'founded_month': 9},
#  {'name': 'Bigsight Media Group', 'founded_month': 9},
#  {'name': 'Sharetivity', 'founded_month': 7},
#  {'name': 'Taptu', 'founded_month': 10},
#  {'name': 'Deal Comet', 'founded_month': 12},
#  {'name': 'Web2Wave', 'founded_month': 9},
#  {'name': 'Maugans Corp', 'founded_month': 9},
#  {'name': 'BreakingPoint Systems', 'founded_month': 8},
#  {'name': 'Reshade', 'founded_month': 7},
#  {'name': 'VisualCV', 'founded_month': 12},
#  {'name': 'HonestMall', 'founded_month': 9},
#  {'name': 'mSpoke', 'founded_month': 6},
#  {'name': 'FutonMedia', 'founded_month': 10},
#  {'name': 'ZiFiMusic', 'founded_month': 11},
#  {'name': 'myfirstpaycheck', 'founded_month': 6},
#  {'name': 'memelabs', 'founded_month': 7},
#  {'name': 'PopShops', 'founded_month': 7},
#  {'name': 'MetaNotes', 'founded_month': 8},
#  {'name': 'MerchantOS', 'founded_month': 8},
#  {'name': 'SimpleFeed', 'founded_month': 6},
#  {'name': 'eNotes', 'founded_month': 8},
#  {'name': 'TripnTale', 'founded_month': 11},
#  {'name': 'Mergelab', 'founded_month': 10},
#  {'name': 'Tvosz', 'founded_month': 7},
#  {'name': 'VentureBeat', 'founded_month': 9},
#  {'name': 'b5media', 'founded_month': 6},
#  {'name': 'Weblogs', 'founded_month': 9},
#  {'name': 'idiomag', 'founded_month': 8},
#  {'name': 'mobileStorm', 'founded_month': 10},
#  {'name': 'TalentSpring', 'founded_month': 10},
#  {'name': 'Metromole', 'founded_month': 10},
#  {'name': 'apivision', 'founded_month': 12},
#  {'name': 'China-8', 'founded_month': 10},
#  {'name': 'Mobiance', 'founded_month': 10},
#  {'name': 'Brownstoner Media', 'founded_month': 10},
#  {'name': 'SpotXchange', 'founded_month': 11},
#  {'name': 'GiveStream', 'founded_month': 6},
#  {'name': 'PlanJam', 'founded_month': 11},
#  {'name': 'Vuzit', 'founded_month': 6},
#  {'name': 'Mixbook', 'founded_month': 8},
#  {'name': 'VisitorNetworks', 'founded_month': 9},
#  {'name': 'GameDuell', 'founded_month': 12},
#  {'name': 'Paglo', 'founded_month': 7},
#  {'name': 'What They Like', 'founded_month': 8},
#  {'name': 'Yodio', 'founded_month': 11},
#  {'name': 'LittleEngine', 'founded_month': 10},
#  {'name': 'stickK', 'founded_month': 7},
#  {'name': 'Cellware', 'founded_month': 12},
#  {'name': 'ManageMyAdvertising', 'founded_month': 10},
#  {'name': 'LyfeSystems', 'founded_month': 9},
#  {'name': 'Kaddoz', 'founded_month': 12},
#  {'name': 'Principal Axis', 'founded_month': 12},
#  {'name': 'eTeacher', 'founded_month': 11},
#  {'name': 'amiando', 'founded_month': 12},
#  {'name': 'SpinSnap', 'founded_month': 7},
#  {'name': 'Qype', 'founded_month': 11},
#  {'name': 'GumGum', 'founded_month': 10},
#  {'name': 'Pivotal Labs', 'founded_month': 7},
#  {'name': 'MyCityFaces', 'founded_month': 12},
#  {'name': 'Clicks2Customers', 'founded_month': 6},
#  {'name': 'Qifang', 'founded_month': 8},
#  {'name': 'PPDai', 'founded_month': 6},
#  {'name': 'PicScout', 'founded_month': 12},
#  {'name': 'UnsubCentral', 'founded_month': 12},
#  {'name': 'openPeople', 'founded_month': 7},
#  {'name': 'ChoiceStream', 'founded_month': 9},
#  {'name': 'GroundReport', 'founded_month': 6},
#  {'name': '2 under entertainment', 'founded_month': 6},
#  {'name': 'LibraryThing', 'founded_month': 8},
#  {'name': 'MomentVille', 'founded_month': 9},
#  {'name': 'TheLadders', 'founded_month': 7},
#  {'name': 'QponDirect', 'founded_month': 12},
#  {'name': 'Fat Goose', 'founded_month': 9},
#  {'name': 'DeaLoco', 'founded_month': 12},
#  {'name': 'LexDex', 'founded_month': 7},
#  {'name': 'Subimage', 'founded_month': 8},
#  {'name': 'MOG', 'founded_month': 6},
#  {'name': 'ShareMethods', 'founded_month': 10},
#  {'name': 'Danger', 'founded_month': 12},
#  {'name': 'Devunity', 'founded_month': 8},
#  {'name': 'AskPoodle', 'founded_month': 9},
#  {'name': 'Scary Ideas', 'founded_month': 11},
#  {'name': 'Skyrove', 'founded_month': 6},
#  {'name': 'Fortify Software', 'founded_month': 10},
#  {'name': 'Planbus', 'founded_month': 10},
#  {'name': 'QuickInsert', 'founded_month': 8},
#  {'name': 'FaceTec', 'founded_month': 9},
#  {'name': 'Sitemasher', 'founded_month': 12},
#  {'name': 'Ownersite Technologies', 'founded_month': 10},
#  {'name': 'fotopedia', 'founded_month': 10},
#  {'name': 'Foneshow', 'founded_month': 9},
#  {'name': 'cScape', 'founded_month': 9},
#  {'name': 'Compulsivo', 'founded_month': 11},
#  {'name': 'ePrep', 'founded_month': 11},
#  {'name': 'YouNoodle', 'founded_month': 7},
#  {'name': 'Los Angeles Times Media Group', 'founded_month': 12},
#  {'name': 'mobikade', 'founded_month': 7},
#  {'name': 'Echobit', 'founded_month': 8},
#  {'name': 'Pollsit', 'founded_month': 12},
#  {'name': 'Group2call', 'founded_month': 10},
#  {'name': 'YouCastr', 'founded_month': 6},
#  {'name': 'GenieTown', 'founded_month': 10},
#  {'name': 'Paprika Lab', 'founded_month': 9},
#  {'name': 'RiffTrax', 'founded_month': 7},
#  {'name': 'Unype', 'founded_month': 10},
#  {'name': 'World Reviewer', 'founded_month': 10},
#  {'name': 'GeniusRocket', 'founded_month': 9},
#  {'name': 'BBC', 'founded_month': 7},
#  {'name': 'MyApartmentMap', 'founded_month': 8},
#  {'name': '8coupons', 'founded_month': 8},
#  {'name': 'Cloudo', 'founded_month': 7},
#  {'name': 'JuicyCampus', 'founded_month': 8},
#  {'name': 'Ad Infuse', 'founded_month': 11},
#  {'name': 'Inform Technologies', 'founded_month': 8},
#  {'name': 'EVO Media Group', 'founded_month': 10},
#  {'name': 'SendMe', 'founded_month': 6},
#  {'name': 'Starfish Community Group', 'founded_month': 7},
#  {'name': 'TripSailor', 'founded_month': 6},
#  {'name': 'Blog Talk Radio', 'founded_month': 7},
#  {'name': 'HealtheHuman', 'founded_month': 8},
#  {'name': 'HealthLat', 'founded_month': 8},
#  {'name': 'Tiny Pictures', 'founded_month': 8},
#  {'name': 'Zorpia', 'founded_month': 7},
#  {'name': 'iRovr', 'founded_month': 6},
#  {'name': 'ooVoo', 'founded_month': 6},
#  {'name': 'Popularo', 'founded_month': 10},
#  {'name': 'Animax Entertainment', 'founded_month': 10},
#  {'name': 'EMOB', 'founded_month': 12},
#  {'name': 'FanDuel', 'founded_month': 11},
#  {'name': 'Evri', 'founded_month': 7},
#  {'name': 'Parametric Ventures', 'founded_month': 8},
#  {'name': 'Gamers Media', 'founded_month': 8},
#  {'name': 'FixSor', 'founded_month': 9},
#  {'name': 'YaData', 'founded_month': 7},
#  {'name': 'NAVIS', 'founded_month': 10},
#  {'name': 'MoFuse', 'founded_month': 9},
#  {'name': 'TolMol', 'founded_month': 10},
#  {'name': 'Quintura', 'founded_month': 8},
#  {'name': 'Qiro', 'founded_month': 11},
#  {'name': 'PayLoadz', 'founded_month': 8},
#  {'name': 'Love2Trade', 'founded_month': 11},
#  {'name': 'QVC', 'founded_month': 11},
#  {'name': 'Sporting Connections', 'founded_month': 11},
#  {'name': 'Volagratis', 'founded_month': 7},
#  {'name': 'MercadoFechado', 'founded_month': 9},
#  {'name': 'homSALE', 'founded_month': 9},
#  {'name': 'Myrimis', 'founded_month': 9},
#  {'name': 'Webtronic', 'founded_month': 7},
#  {'name': 'Aullo', 'founded_month': 9},
#  {'name': 'Folkstr', 'founded_month': 10},
#  {'name': 'Napster', 'founded_month': 6},
#  {'name': "IT'S ART", 'founded_month': 8},
#  {'name': 'LouderVoice', 'founded_month': 11},
#  {'name': 'EASEUS', 'founded_month': 8},
#  {'name': 'I-stats', 'founded_month': 10},
#  {'name': 'Sportgenic', 'founded_month': 9},
#  {'name': 'Innofidei', 'founded_month': 9},
#  {'name': 'SEO Intelligence', 'founded_month': 6},
#  {'name': 'Mapicurious', 'founded_month': 6},
#  {'name': 'Printfection', 'founded_month': 7},
#  {'name': 'RingBranch', 'founded_month': 11},
#  {'name': 'Rivals4Ever', 'founded_month': 12},
#  {'name': 'OpenDNS', 'founded_month': 11},
#  {'name': 'Pidgin Technologies', 'founded_month': 6},
#  {'name': 'VZnet Netzwerke', 'founded_month': 10},
#  {'name': 'Asterpix', 'founded_month': 10},
#  {'name': 'Astrails', 'founded_month': 12},
#  {'name': 'LiveHit', 'founded_month': 9},
#  {'name': 'WebRidesTV', 'founded_month': 8},
#  {'name': 'Innovid', 'founded_month': 7},
#  {'name': 'Aidmas Corporation', 'founded_month': 8},
#  {'name': 'Kulabyte', 'founded_month': 11},
#  {'name': 'Rutube', 'founded_month': 11},
#  {'name': 'Feng-GUI', 'founded_month': 11},
#  {'name': 'Footnote', 'founded_month': 6},
#  {'name': 'Akoha', 'founded_month': 12},
#  {'name': 'BrightSide Software', 'founded_month': 6},
#  {'name': 'doXtop', 'founded_month': 7},
#  {'name': 'PacketFront', 'founded_month': 8},
#  {'name': 'Zicasso', 'founded_month': 6},
#  {'name': 'JigJak', 'founded_month': 7},
#  {'name': 'Litmos', 'founded_month': 8},
#  {'name': 'Ad Chap', 'founded_month': 7},
#  {'name': 'The FeedRoom', 'founded_month': 9},
#  {'name': 'SportsUltra', 'founded_month': 9},
#  {'name': 'Mobenga', 'founded_month': 12},
#  {'name': 'Janrain', 'founded_month': 9},
#  {'name': 'SearchMe', 'founded_month': 7},
#  {'name': 'Tokiva Technologies', 'founded_month': 9},
#  {'name': 'Global Roaming', 'founded_month': 8},
#  {'name': 'Panizon', 'founded_month': 9},
#  {'name': 'Discovery Engine', 'founded_month': 6},
#  {'name': 'Revolution Health', 'founded_month': 7},
#  {'name': 'Zooors Interactive Yachting Society', 'founded_month': 11},
#  {'name': 'Sazze', 'founded_month': 7},
#  {'name': 'Norg Media', 'founded_month': 8},
#  {'name': 'Eyealike', 'founded_month': 10},
#  {'name': 'Skydeck', 'founded_month': 12},
#  {'name': 'JobThread', 'founded_month': 11},
#  {'name': 'Snaptalent', 'founded_month': 11},
#  {'name': 'Twhirl', 'founded_month': 11},
#  {'name': 'TeamWork Live', 'founded_month': 10},
#  {'name': 'Daikana', 'founded_month': 10},
#  {'name': 'CrewedUp', 'founded_month': 6},
#  {'name': 'Three Innovators', 'founded_month': 6},
#  {'name': 'Weplug', 'founded_month': 12},
#  {'name': 'Arclight Media Technology', 'founded_month': 11},
#  {'name': '500 Hats', 'founded_month': 9},
#  {'name': 'Voltage Security', 'founded_month': 6},
#  {'name': 'SupplyFrame', 'founded_month': 6},
#  {'name': 'Authenticlick', 'founded_month': 8},
#  {'name': 'GasBuddy', 'founded_month': 6},
#  {'name': 'Playfish', 'founded_month': 10},
#  {'name': 'CitySquares', 'founded_month': 8},
#  {'name': 'Qlubb', 'founded_month': 9},
#  {'name': 'Coordinatr', 'founded_month': 9},
#  {'name': 'Snipshot', 'founded_month': 12},
#  {'name': 'MyDogSpace', 'founded_month': 8},
#  {'name': 'The Friday Pint Ltd', 'founded_month': 7},
#  {'name': 'Akampus', 'founded_month': 9},
#  {'name': 'Toufee', 'founded_month': 7},
#  {'name': 'Slicethepie', 'founded_month': 6},
#  {'name': 'MyTrade', 'founded_month': 8},
#  {'name': 'Taaz', 'founded_month': 7},
#  {'name': 'BMC Software', 'founded_month': 9},
#  {'name': 'SIMchronise', 'founded_month': 9},
#  {'name': 'FASTALLEY', 'founded_month': 11},
#  {'name': 'Dadaphile', 'founded_month': 6},
#  {'name': 'Eatup Drinkup', 'founded_month': 11},
#  {'name': 'Moblica', 'founded_month': 7},
#  {'name': 'Zebtab', 'founded_month': 8},
#  {'name': 'Music Arsenal', 'founded_month': 12},
#  {'name': 'XIHA', 'founded_month': 9},
#  {'name': 'Shvoong', 'founded_month': 8},
#  {'name': 'tunesBag', 'founded_month': 10},
#  {'name': 'BroadSoft', 'founded_month': 9},
#  {'name': 'Public Domain Archive and Reprints Service', 'founded_month': 11},
#  {'name': 'FuelMyBlog', 'founded_month': 7},
#  {'name': 'AnchorFree', 'founded_month': 11},
#  {'name': 'Sonecast', 'founded_month': 7},
#  {'name': 'Infibeam', 'founded_month': 7},
#  {'name': 'OrangeSoda', 'founded_month': 10},
#  {'name': 'CJReport', 'founded_month': 8},
#  {'name': 'Webreakstuff', 'founded_month': 6},
#  {'name': 'DevHD', 'founded_month': 11},
#  {'name': 'Devolia', 'founded_month': 9},
#  {'name': 'Wellwrittenwords', 'founded_month': 6},
#  {'name': 'Raw Signal', 'founded_month': 12},
#  {'name': 'Infovark', 'founded_month': 10},
#  {'name': 'RelevantMind', 'founded_month': 10},
#  {'name': 'GotVoice', 'founded_month': 10},
#  {'name': 'BlogFlux', 'founded_month': 7},
#  {'name': 'Notches', 'founded_month': 12},
#  {'name': 'DeliciousSafari', 'founded_month': 7},
#  {'name': 'iHound Software', 'founded_month': 8},
#  {'name': 'babbel', 'founded_month': 8},
#  {'name': 'Parature', 'founded_month': 6},
#  {'name': 'Domegos', 'founded_month': 8},
#  {'name': 'itbreaks', 'founded_month': 6},
#  {'name': 'SeatNation', 'founded_month': 11},
#  {'name': 'Zigtag', 'founded_month': 10},
#  {'name': 'Wikimedia Foundation', 'founded_month': 6},
#  {'name': 'Clearwell Systems', 'founded_month': 12},
#  {'name': 'AsesorSeguros', 'founded_month': 9},
#  {'name': 'BlueCat Networks', 'founded_month': 12},
#  {'name': 'TriValleyBook', 'founded_month': 8},
#  {'name': 'The Echo Nest', 'founded_month': 7},
#  {'name': 'Zemanta', 'founded_month': 9},
#  {'name': 'Social Sauce', 'founded_month': 6},
#  {'name': 'iovation', 'founded_month': 6},
#  {'name': 'Mindpark', 'founded_month': 9},
#  {'name': 'Bango', 'founded_month': 10},
#  {'name': 'Glassdoor', 'founded_month': 6},
#  {'name': 'Faraday Media', 'founded_month': 6},
#  {'name': '31000emploi', 'founded_month': 8},
#  {'name': 'ki work', 'founded_month': 11},
#  {'name': 'Pressflip', 'founded_month': 6},
#  {'name': 'Skycore', 'founded_month': 11},
#  {'name': 'Fresho', 'founded_month': 10},
#  {'name': 'Get the Point', 'founded_month': 9},
#  {'name': 'Berkeley Design Automation', 'founded_month': 10},
#  {'name': 'itzbig', 'founded_month': 6},
#  {'name': 'Toluu', 'founded_month': 9},
#  {'name': 'Achievers Point Knowledge Systems', 'founded_month': 9},
#  {'name': 'Bonobos', 'founded_month': 6},
#  {'name': 'NoseRub', 'founded_month': 8},
#  {'name': 'Vello', 'founded_month': 9},
#  {'name': '3Tera', 'founded_month': 8},
#  {'name': 'Edmodo', 'founded_month': 9},
#  {'name': 'Noovo', 'founded_month': 8},
#  {'name': 'ZEDO', 'founded_month': 11},
#  {'name': 'Spongecell', 'founded_month': 9},
#  {'name': 'Franson Technology AB', 'founded_month': 6},
#  {'name': 'Phototeez', 'founded_month': 6},
#  {'name': 'Adlucent', 'founded_month': 7},
#  {'name': 'CapAlly', 'founded_month': 6},
#  {'name': 'Metaversum', 'founded_month': 7},
#  {'name': 'Naubo', 'founded_month': 6},
#  {'name': 'Familybuilder', 'founded_month': 6},
#  {'name': 'Kudzu', 'founded_month': 6},
#  {'name': 'TheNextBigWriter', 'founded_month': 10},
#  {'name': 'RiDE Group', 'founded_month': 11},
#  {'name': 'CarDomain Network', 'founded_month': 9},
#  {'name': 'TagLauncher', 'founded_month': 12},
#  {'name': 'Kublax', 'founded_month': 8},
#  {'name': 'Topspin Media', 'founded_month': 6},
#  {'name': 'Nota', 'founded_month': 12},
#  {'name': 'MaybeMike', 'founded_month': 11},
#  {'name': '51 Give', 'founded_month': 9},
#  {'name': 'HRSnap! Corporation', 'founded_month': 10},
#  {'name': 'Babuki', 'founded_month': 9},
#  {'name': 'Myplaylist', 'founded_month': 10},
#  {'name': 'MyWellnessSpace', 'founded_month': 12},
#  {'name': 'TripSay', 'founded_month': 9},
#  {'name': 'GroupSpaces', 'founded_month': 10},
#  {'name': 'South Park Studios', 'founded_month': 8},
#  {'name': 'Zong', 'founded_month': 11},
#  {'name': 'HelpMeSue', 'founded_month': 12},
#  {'name': 'Odeo', 'founded_month': 7},
#  {'name': 'Simkl', 'founded_month': 12},
#  {'name': 'Pure Digital Technologies', 'founded_month': 9},
#  {'name': 'Axosoft', 'founded_month': 8},
#  {'name': 'SoftLogica', 'founded_month': 6},
#  {'name': 'Trellon', 'founded_month': 8},
#  {'name': 'Coull', 'founded_month': 10},
#  {'name': 'andUNITE', 'founded_month': 9},
#  {'name': 'Huddle', 'founded_month': 11},
#  {'name': 'Trampoline Systems', 'founded_month': 10},
#  {'name': 'Omnistar Interactive', 'founded_month': 7},
#  {'name': 'SiBEAM', 'founded_month': 12},
#  {'name': '83 Degrees', 'founded_month': 10},
#  {'name': 'Baidu', 'founded_month': 10},
#  {'name': 'Vivity Labs', 'founded_month': 12},
#  {'name': 'Open Source Living', 'founded_month': 12},
#  {'name': 'Support Intelligence', 'founded_month': 10},
#  {'name': 'Boxbe', 'founded_month': 12},
#  {'name': 'Honeypot Marketing', 'founded_month': 12},
#  {'name': 'Octeth', 'founded_month': 11},
#  {'name': 'SYIANT technologies', 'founded_month': 7},
#  {'name': 'Artabase', 'founded_month': 12},
#  {'name': 'Acme Mobile', 'founded_month': 10},
#  {'name': 'Moviestorm', 'founded_month': 6},
#  {'name': 'Nsyght', 'founded_month': 6},
#  {'name': 'Fourth Media Technologies', 'founded_month': 8},
#  {'name': 'GreatDomainRace', 'founded_month': 10},
#  {'name': 'Labmeeting', 'founded_month': 7},
#  {'name': 'Shopflick', 'founded_month': 7},
#  {'name': 'Trovit', 'founded_month': 10},
#  {'name': 'Reach Machines', 'founded_month': 9},
#  {'name': 'Berro', 'founded_month': 9},
#  {'name': 'iKnowlej', 'founded_month': 7},
#  {'name': 'LocalWineEvents', 'founded_month': 7},
#  {'name': 'Palamida', 'founded_month': 12},
#  {'name': 'British Telecom', 'founded_month': 10},
#  {'name': 'myTino', 'founded_month': 8},
#  {'name': 'CVN Networks', 'founded_month': 10},
#  {'name': 'ProcServe', 'founded_month': 8},
#  {'name': 'OnOneMap', 'founded_month': 8},
#  {'name': 'HealthWorldWeb', 'founded_month': 6},
#  {'name': 'Janmedia Interactive', 'founded_month': 6},
#  {'name': 'Park Sidekick', 'founded_month': 6},
#  {'name': 'Pipl', 'founded_month': 12},
#  {'name': 'walabok', 'founded_month': 11},
#  {'name': 'Plexonic', 'founded_month': 11},
#  {'name': 'MEDgle', 'founded_month': 9},
#  {'name': 'Picoy', 'founded_month': 10},
#  {'name': 'The Beer Mapping Project', 'founded_month': 10},
#  {'name': 'Iminent', 'founded_month': 10},
#  {'name': 'BMAT', 'founded_month': 12},
#  {'name': 'SOSIUS', 'founded_month': 9},
#  {'name': 'Mercury Intermedia', 'founded_month': 10},
#  {'name': 'BizRate', 'founded_month': 6},
#  {'name': 'Strutta', 'founded_month': 6},
#  {'name': 'DataPortability', 'founded_month': 11},
#  {'name': 'PhoneFavs', 'founded_month': 12},
#  {'name': 'ImageShack', 'founded_month': 11},
#  {'name': 'Beep Interactive', 'founded_month': 9},
#  {'name': 'PluggedIn', 'founded_month': 8},
#  {'name': 'AdShuffle', 'founded_month': 12},
#  {'name': 'Red Oxygen', 'founded_month': 7},
#  {'name': 'W3Counter', 'founded_month': 6},
#  {'name': 'imcandy', 'founded_month': 6},
#  {'name': 'Pixifi', 'founded_month': 7},
#  {'name': 'Whois', 'founded_month': 10},
#  {'name': 'Apture', 'founded_month': 6},
#  {'name': 'Soocial', 'founded_month': 11},
#  {'name': 'Daptiv', 'founded_month': 6},
#  {'name': 'SocialSplash', 'founded_month': 12},
#  {'name': 'Medioh!', 'founded_month': 9},
#  {'name': 'PetBrags', 'founded_month': 8},
#  {'name': 'Beer Universe', 'founded_month': 12},
#  {'name': 'SaneBull', 'founded_month': 8},
#  {'name': 'IdiotsTrafficSchool', 'founded_month': 9},
#  {'name': 'BubbleShare', 'founded_month': 6},
#  {'name': 'ReVou', 'founded_month': 12},
#  {'name': 'Drop Magazine', 'founded_month': 8},
#  {'name': 'Dial Plus', 'founded_month': 12},
#  {'name': 'TeachStreet', 'founded_month': 6},
#  {'name': 'Muxlim', 'founded_month': 11},
#  {'name': 'ForteMall', 'founded_month': 7},
#  {'name': 'ChickAdvisor', 'founded_month': 7},
#  {'name': 'Wayfair', 'founded_month': 8},
#  {'name': '3tailer', 'founded_month': 12},
#  {'name': 'StoryMash', 'founded_month': 11},
#  {'name': 'venyoo', 'founded_month': 9},
#  {'name': 'Rankopedia', 'founded_month': 6},
#  {'name': 'Fog Creek Software', 'founded_month': 9},
#  {'name': 'Vegtaste', 'founded_month': 12},
#  {'name': 'BuildDirect', 'founded_month': 7},
#  {'name': 'Exago', 'founded_month': 7},
#  {'name': 'Omnivents', 'founded_month': 11},
#  {'name': 'Interarbor Solutions', 'founded_month': 7},
#  {'name': 'Bizooki', 'founded_month': 10},
#  {'name': 'Superblock', 'founded_month': 10},
#  {'name': 'Lemonade', 'founded_month': 9},
#  {'name': 'Aardvark', 'founded_month': 7},
#  {'name': 'Piwik', 'founded_month': 9},
#  {'name': 'SuperVirals', 'founded_month': 10},
#  {'name': 'Flaptor', 'founded_month': 12},
#  {'name': 'iSquare', 'founded_month': 9},
#  {'name': 'SQLstream', 'founded_month': 12},
#  {'name': 'PurpleTrail', 'founded_month': 11},
#  {'name': 'Viewzi', 'founded_month': 12},
#  {'name': 'Voices', 'founded_month': 10},
#  {'name': 'Triggit', 'founded_month': 10},
#  {'name': 'PIER Systems', 'founded_month': 8},
#  {'name': 'YouBeats', 'founded_month': 12},
#  {'name': 'RateBuilding', 'founded_month': 12},
#  {'name': 'Savvy Circle', 'founded_month': 11},
#  {'name': 'Presdo', 'founded_month': 7},
#  {'name': 'Android', 'founded_month': 10},
#  {'name': 'FreedomSpeaks', 'founded_month': 11},
#  {'name': 'Zigron', 'founded_month': 11},
#  {'name': 'Jetcost', 'founded_month': 6},
#  {'name': 'Wordie', 'founded_month': 11},
#  {'name': 'TuneWiki', 'founded_month': 12},
#  {'name': 'Amanager', 'founded_month': 9},
#  {'name': 'Estately', 'founded_month': 12},
#  {'name': 'Springleap', 'founded_month': 8},
#  {'name': 'Youcode', 'founded_month': 8},
#  {'name': 'URockHard', 'founded_month': 11},
#  {'name': 'Adify', 'founded_month': 8},
#  {'name': 'Techrigy', 'founded_month': 6},
#  {'name': 'Lingoloopy', 'founded_month': 9},
#  {'name': 'Kabam', 'founded_month': 11},
#  {'name': 'Profy', 'founded_month': 9},
#  {'name': 'TraceWorks', 'founded_month': 10},
#  {'name': 'mappery', 'founded_month': 7},
#  {'name': 'UNYK', 'founded_month': 9},
#  {'name': 'BioWizard', 'founded_month': 8},
#  {'name': 'Syncplicity', 'founded_month': 11},
#  {'name': 'AVIS eSolutions', 'founded_month': 9},
#  {'name': 'Streamzy', 'founded_month': 11},
#  {'name': 'Luminotes', 'founded_month': 8},
#  {'name': 'Voices in Business', 'founded_month': 11},
#  {'name': 'Phonewire', 'founded_month': 8},
#  {'name': 'Diabetic Days', 'founded_month': 9},
#  {'name': 'Gimeney', 'founded_month': 9},
#  {'name': 'HyperCalc', 'founded_month': 12},
#  {'name': 'The Ad Database', 'founded_month': 12},
#  {'name': 'MakeUseOf', 'founded_month': 6},
#  {'name': 'Danogo', 'founded_month': 10},
#  {'name': 'Opsware', 'founded_month': 9},
#  {'name': 'Empire Group', 'founded_month': 10},
#  {'name': 'Zeer', 'founded_month': 6},
#  {'name': 'Memopal', 'founded_month': 10},
#  {'name': 'svcmart', 'founded_month': 7},
#  {'name': 'FantasyBook', 'founded_month': 12},
#  {'name': 'Conenza', 'founded_month': 10},
#  {'name': 'Fanzter', 'founded_month': 6},
#  {'name': 'Neutralize', 'founded_month': 9},
#  {'name': 'MediResource', 'founded_month': 6},
#  {'name': 'Phi Media', 'founded_month': 9},
#  {'name': 'onebluebrick', 'founded_month': 6},
#  {'name': 'ChatAny', 'founded_month': 8},
#  {'name': 'Traffic Broker', 'founded_month': 8},
#  {'name': 'Talend', 'founded_month': 9},
#  {'name': 'ESPN', 'founded_month': 9},
#  {'name': 'Telenav', 'founded_month': 9},
#  {'name': 'FirstString', 'founded_month': 8},
#  {'name': 'Musopen', 'founded_month': 6},
#  {'name': 'twidox', 'founded_month': 11},
#  {'name': 'zweitgeist', 'founded_month': 6},
#  {'name': 'allyve', 'founded_month': 9},
#  {'name': 'Your Survival', 'founded_month': 10},
#  {'name': 'locr', 'founded_month': 9},
#  {'name': 'RouteNote', 'founded_month': 8},
#  {'name': 'Andera', 'founded_month': 6},
#  {'name': 'Boulevard R', 'founded_month': 6},
#  {'name': 'The Motley Fool', 'founded_month': 7},
#  {'name': 'WebVet', 'founded_month': 11},
#  {'name': 'RupeeTimes', 'founded_month': 9},
#  {'name': 'SEO Workers', 'founded_month': 10},
#  {'name': 'CTAB Mortgage Desk', 'founded_month': 8},
#  {'name': 'Picitup', 'founded_month': 8},
#  {'name': 'Facilitas', 'founded_month': 8},
#  {'name': 'KangarooBox', 'founded_month': 8},
#  {'name': 'TuneUp', 'founded_month': 8},
#  {'name': 'Textensor', 'founded_month': 12},
#  {'name': 'Squace', 'founded_month': 9},
#  {'name': 'Mozes', 'founded_month': 6},
#  {'name': 'rVita', 'founded_month': 7},
#  {'name': 'OpenSocial Foundation', 'founded_month': 11},
#  {'name': 'findingDulcinea', 'founded_month': 9},
#  {'name': 'Weeno Media', 'founded_month': 6},
#  {'name': 'DealQUE', 'founded_month': 12},
#  {'name': 'Futurlink', 'founded_month': 6},
#  {'name': 'Hypertag', 'founded_month': 8},
#  {'name': 'Dezide', 'founded_month': 12},
#  {'name': 'Hobnox', 'founded_month': 12},
#  {'name': 'Cognition Technologies', 'founded_month': 9},
#  {'name': 'Cellity', 'founded_month': 10},
#  {'name': 'OleOle', 'founded_month': 12},
#  {'name': 'TerraPass', 'founded_month': 10},
#  {'name': 'BusinessCard2', 'founded_month': 8},
#  {'name': 'Sometrics', 'founded_month': 9},
#  {'name': 'Crowded Games', 'founded_month': 6},
#  {'name': 'U Sphere', 'founded_month': 7},
#  {'name': 'deviantART', 'founded_month': 8},
#  {'name': 'mpw Technologies', 'founded_month': 12},
#  {'name': 'JustMeans', 'founded_month': 10},
#  {'name': 'The Travel Editor', 'founded_month': 8},
#  {'name': 'WrapMail', 'founded_month': 10},
#  {'name': 'Crunchlabz', 'founded_month': 6},
#  {'name': 'mywaves', 'founded_month': 12},
#  {'name': 'NextBio', 'founded_month': 11},
#  {'name': 'Zoosk', 'founded_month': 11},
#  {'name': 'Aprius', 'founded_month': 6},
#  {'name': 'Pixaria', 'founded_month': 10},
#  {'name': 'Bluetise', 'founded_month': 8},
#  {'name': 'WujWuj', 'founded_month': 7},
#  {'name': 'CityHubb', 'founded_month': 12},
#  {'name': 'Elite Renting', 'founded_month': 11},
#  {'name': 'Viridus', 'founded_month': 12},
#  {'name': 'adflyer', 'founded_month': 9},
#  {'name': 'ITSportsNet', 'founded_month': 11},
#  {'name': 'GameFly', 'founded_month': 11},
#  {'name': 'Flixya', 'founded_month': 7},
#  {'name': 'Aster Data Systems', 'founded_month': 7},
#  {'name': 'OmniTI', 'founded_month': 9},
#  {'name': 'Global Business Development Services', 'founded_month': 10},
#  {'name': 'Roku', 'founded_month': 10},
#  {'name': 'Yandex', 'founded_month': 9},
#  {'name': 'Batipi', 'founded_month': 11},
#  {'name': 'Sonico', 'founded_month': 7},
#  {'name': 'SmallWorlds', 'founded_month': 12},
#  {'name': 'Stagevu', 'founded_month': 11},
#  {'name': 'Jitterbit', 'founded_month': 12},
#  {'name': 'Symora Networks', 'founded_month': 7},
#  {'name': 'Global Property Guide', 'founded_month': 6},
#  {'name': 'Locify', 'founded_month': 10},
#  {'name': 'RabbleDabble', 'founded_month': 10},
#  {'name': 'PeopleAhead', 'founded_month': 6},
#  {'name': 'GlobeShooter', 'founded_month': 8},
#  {'name': 'CompareNetworks', 'founded_month': 7},
#  {'name': 'Sxip Identity', 'founded_month': 10},
#  {'name': 'sph3re', 'founded_month': 8},
#  {'name': 'Dotmenu', 'founded_month': 9},
#  {'name': 'Open Television Network', 'founded_month': 8},
#  {'name': 'CarArt', 'founded_month': 6},
#  {'name': 'Zecter', 'founded_month': 6},
#  {'name': 'Votigo', 'founded_month': 7},
#  {'name': 'iBiz Software', 'founded_month': 6},
#  {'name': 'C4Media', 'founded_month': 10},
#  {'name': 'iWin', 'founded_month': 8},
#  {'name': 'Savvy Cellar Wines', 'founded_month': 12},
#  {'name': 'B3 Software', 'founded_month': 6},
#  {'name': 'urlBorg', 'founded_month': 11},
#  {'name': 'InterGraphicDESIGNS', 'founded_month': 8},
#  {'name': 'Pangaeaa Enterprises', 'founded_month': 11},
#  {'name': 'PurePlay', 'founded_month': 11},
#  {'name': 'Aruspex', 'founded_month': 12},
#  {'name': 'Oxynade', 'founded_month': 10},
#  {'name': 'Jowba', 'founded_month': 11},
#  {'name': 'BipBip', 'founded_month': 6},
#  {'name': 'Southern Growth Studio', 'founded_month': 11},
#  {'name': 'Propertyqube', 'founded_month': 12},
#  {'name': 'Agent Shield Technologies', 'founded_month': 7},
#  {'name': 'Enterprise Concept', 'founded_month': 11},
#  {'name': 'Handmark', 'founded_month': 7},
#  {'name': 'Market Sentinel', 'founded_month': 9},
#  {'name': 'Fabric Interactive', 'founded_month': 8},
#  {'name': 'The Television Writers Vault', 'founded_month': 6},
#  {'name': 'Aedgency', 'founded_month': 11},
#  {'name': 'UNIFLIP', 'founded_month': 8},
#  {'name': 'FliteHaus Creative Agency', 'founded_month': 7},
#  {'name': 'Jambool', 'founded_month': 8},
#  {'name': 'DigiSynd', 'founded_month': 6},
#  {'name': 'FanDriveMedia', 'founded_month': 12},
#  {'name': 'Versaly Entertainment', 'founded_month': 10},
#  {'name': 'MicroGiving', 'founded_month': 11},
#  {'name': 'Hive7', 'founded_month': 6},
#  {'name': 'SRI International', 'founded_month': 11},
#  {'name': 'Ipoki', 'founded_month': 12},
#  {'name': 'Camp BizSmart', 'founded_month': 9},
#  {'name': 'Niwango', 'founded_month': 11},
#  {'name': 'Quividi', 'founded_month': 7},
#  {'name': 'OneScreen', 'founded_month': 10},
#  {'name': 'snuzu', 'founded_month': 6},
#  {'name': 'ArtistData', 'founded_month': 7},
#  {'name': 'PageUp People', 'founded_month': 10},
#  {'name': 'Cypal Solutions', 'founded_month': 8},
#  {'name': 'Jigsaw', 'founded_month': 10},
#  {'name': 'NetProspex', 'founded_month': 11},
#  {'name': 'DriverSide', 'founded_month': 9},
#  {'name': 'Inertia Beverage Group', 'founded_month': 10},
#  {'name': 'TuneCore', 'founded_month': 11},
#  {'name': 'Open-E', 'founded_month': 9},
#  {'name': 'Cheehee', 'founded_month': 6},
#  {'name': 'CCP Games', 'founded_month': 6},
#  {'name': 'WSO2', 'founded_month': 8},
#  {'name': 'Crowd Science', 'founded_month': 12},
#  {'name': 'MarketSimplified', 'founded_month': 6},
#  {'name': 'SightWorks', 'founded_month': 9},
#  {'name': 'Zacsoft', 'founded_month': 6},
#  {'name': 'Dizzywood', 'founded_month': 11},
#  {'name': 'DotSpots', 'founded_month': 9},
#  {'name': 'Limbo', 'founded_month': 10},
#  {'name': 'CohesiveFT', 'founded_month': 7},
#  {'name': 'Coolboysoft', 'founded_month': 10},
#  {'name': 'Macronimous Web Solutions', 'founded_month': 12},
#  {'name': 'Majides', 'founded_month': 12},
#  {'name': 'TickerHound', 'founded_month': 6},
#  {'name': 'StreamFocus', 'founded_month': 11},
#  {'name': 'ArcStone Technologies', 'founded_month': 6},
#  {'name': 'CGI Group', 'founded_month': 6},
#  {'name': 'Prospection', 'founded_month': 9},
#  {'name': 'Intelliworks', 'founded_month': 12},
#  {'name': 'Jungle Jam Tv', 'founded_month': 10},
#  {'name': 'feedbackZone', 'founded_month': 6},
#  {'name': 'Afrizi', 'founded_month': 6},
#  {'name': 'iePlexus', 'founded_month': 9},
#  {'name': 'SpaBoom', 'founded_month': 8},
#  {'name': 'Muecs', 'founded_month': 10},
#  {'name': 'Capterra', 'founded_month': 11},
#  {'name': 'Openfilm', 'founded_month': 11},
#  {'name': 'uCubd', 'founded_month': 9},
#  {'name': 'MyGreat', 'founded_month': 7},
#  {'name': 'SquareClock', 'founded_month': 12},
#  {'name': 'MyPronostic', 'founded_month': 8}]

# %% [markdown]
# ### 12. All the companies founded before 2000 that have an acquisition amount of more than 10.000.00

# %%
list(colec.find({'$and':[{'founded_year':{'$lt':2000}},
                         {'acquisition.price_amount':{'$gt':1e7}}]}, 
                {'_id':0, 'name':1,'acquisition.price_amount':1}).sort('acquisition.price_amount',-1))
# Out:
# [{'name': 'BEA Systems', 'acquisition': {'price_amount': 8500000000}},
#  {'name': 'Navteq', 'acquisition': {'price_amount': 8100000000}},
#  {'name': 'Sun Microsystems', 'acquisition': {'price_amount': 7400000000}},
#  {'name': 'Pixar', 'acquisition': {'price_amount': 7400000000}},
#  {'name': 'LSI', 'acquisition': {'price_amount': 6600000000}},
#  {'name': 'National Semiconductor',
#   'acquisition': {'price_amount': 6500000000}},
#  {'name': 'aQuantive', 'acquisition': {'price_amount': 6400000000}},
#  {'name': 'Siebel Systems', 'acquisition': {'price_amount': 5850000000}},
#  {'name': 'Sybase', 'acquisition': {'price_amount': 5800000000}},
#  {'name': 'Affiliated Computer Services',
#   'acquisition': {'price_amount': 5750000000}},
#  {'name': 'Sabre', 'acquisition': {'price_amount': 4300000000}},
#  {'name': 'Netscape', 'acquisition': {'price_amount': 4200000000}},
#  {'name': 'Marvel Entertainment', 'acquisition': {'price_amount': 4000000000}},
#  {'name': 'Sterling Commerce', 'acquisition': {'price_amount': 3900000000}},
#  {'name': 'NetLogic Microsystems',
#   'acquisition': {'price_amount': 3700000000}},
#  {'name': 'Stiefel', 'acquisition': {'price_amount': 3600000000}},
#  {'name': 'The Weather Channel', 'acquisition': {'price_amount': 3500000000}},
#  {'name': 'Lotus Development Corporation',
#   'acquisition': {'price_amount': 3500000000}},
#  {'name': 'Macromedia', 'acquisition': {'price_amount': 3400000000}},
#  {'name': 'Qualcomm Atheros', 'acquisition': {'price_amount': 3100000000}},
#  {'name': 'Foundry Networks', 'acquisition': {'price_amount': 3000000000}},
#  {'name': 'Global Crossing', 'acquisition': {'price_amount': 3000000000}},
#  {'name': 'Global Crossing', 'acquisition': {'price_amount': 3000000000}},
#  {'name': 'GeoCities', 'acquisition': {'price_amount': 2870000000}},
#  {'name': 'Berkeley Networks', 'acquisition': {'price_amount': 2800000000}},
#  {'name': '3Com', 'acquisition': {'price_amount': 2700000000}},
#  {'name': '3Com', 'acquisition': {'price_amount': 2700000000}},
#  {'name': 'Novell', 'acquisition': {'price_amount': 2200000000}},
#  {'name': 'Omniture', 'acquisition': {'price_amount': 1800000000}},
#  {'name': 'Applied Systems', 'acquisition': {'price_amount': 1800000000}},
#  {'name': 'Opsware', 'acquisition': {'price_amount': 1600000000}},
#  {'name': 'PayPal', 'acquisition': {'price_amount': 1500000000}},
#  {'name': 'Responsys', 'acquisition': {'price_amount': 1500000000}},
#  {'name': 'RightNow Technologies',
#   'acquisition': {'price_amount': 1500000000}},
#  {'name': 'Equallogic', 'acquisition': {'price_amount': 1400000000}},
#  {'name': 'Vertafore', 'acquisition': {'price_amount': 1400000000}},
#  {'name': 'Digitas', 'acquisition': {'price_amount': 1300000000}},
#  {'name': 'Blue Coat Systems', 'acquisition': {'price_amount': 1300000000}},
#  {'name': 'Kenexa', 'acquisition': {'price_amount': 1300000000}},
#  {'name': 'Zappos', 'acquisition': {'price_amount': 1200000000}},
#  {'name': 'SPSS', 'acquisition': {'price_amount': 1200000000}},
#  {'name': 'DoubleClick', 'acquisition': {'price_amount': 1100000000}},
#  {'name': 'MapQuest', 'acquisition': {'price_amount': 1100000000}},
#  {'name': 'Lastminute', 'acquisition': {'price_amount': 1008000000}},
#  {'name': 'Alibaba', 'acquisition': {'price_amount': 1000000000}},
#  {'name': 'Centennial Communications Corp',
#   'acquisition': {'price_amount': 944000000}},
#  {'name': 'Wind River', 'acquisition': {'price_amount': 884000000}},
#  {'name': 'Eloqua', 'acquisition': {'price_amount': 871000000}},
#  {'name': 'Sophos', 'acquisition': {'price_amount': 830000000}},
#  {'name': 'Interwoven', 'acquisition': {'price_amount': 775000000}},
#  {'name': 'Sonic Solutions', 'acquisition': {'price_amount': 720000000}},
#  {'name': 'Metrologic Instruments',
#   'acquisition': {'price_amount': 720000000}},
#  {'name': 'SonicWALL', 'acquisition': {'price_amount': 717000000}},
#  {'name': 'Gateway', 'acquisition': {'price_amount': 710000000}},
#  {'name': 'MessageLabs', 'acquisition': {'price_amount': 695000000}},
#  {'name': 'Phase Forward', 'acquisition': {'price_amount': 685000000}},
#  {'name': 'TARGUSinfo', 'acquisition': {'price_amount': 650000000}},
#  {'name': 'Axsys', 'acquisition': {'price_amount': 643000000}},
#  {'name': 'Internet Brands', 'acquisition': {'price_amount': 640000000}},
#  {'name': 'Internet Brands', 'acquisition': {'price_amount': 640000000}},
#  {'name': 'VMware', 'acquisition': {'price_amount': 635000000}},
#  {'name': 'SafeNet', 'acquisition': {'price_amount': 634000000}},
#  {'name': 'Postini', 'acquisition': {'price_amount': 625000000}},
#  {'name': 'iVillage', 'acquisition': {'price_amount': 600000000}},
#  {'name': 'Intermec', 'acquisition': {'price_amount': 600000000}},
#  {'name': 'Unilever', 'acquisition': {'price_amount': 575000000}},
#  {'name': 'Unilever', 'acquisition': {'price_amount': 575000000}},
#  {'name': 'Lightera', 'acquisition': {'price_amount': 552000000}},
#  {'name': 'BizRate', 'acquisition': {'price_amount': 525000000}},
#  {'name': 'Aprimo', 'acquisition': {'price_amount': 525000000}},
#  {'name': 'MovieFone', 'acquisition': {'price_amount': 525000000}},
#  {'name': 'Danger', 'acquisition': {'price_amount': 500000000}},
#  {'name': 'Direct Hit', 'acquisition': {'price_amount': 500000000}},
#  {'name': 'Various', 'acquisition': {'price_amount': 500000000}},
#  {'name': 'Agile Software', 'acquisition': {'price_amount': 495000000}},
#  {'name': 'PriceGrabber', 'acquisition': {'price_amount': 485000000}},
#  {'name': 'NuTech Solutions', 'acquisition': {'price_amount': 471390000}},
#  {'name': 'Secure Computing', 'acquisition': {'price_amount': 465000000}},
#  {'name': 'DemandTec', 'acquisition': {'price_amount': 440000000}},
#  {'name': 'American Land Lease', 'acquisition': {'price_amount': 438000000}},
#  {'name': 'eGroups', 'acquisition': {'price_amount': 432000000}},
#  {'name': 'LinkShare', 'acquisition': {'price_amount': 425000000}},
#  {'name': 'AuthenTec', 'acquisition': {'price_amount': 356000000}},
#  {'name': 'LowerMyBills', 'acquisition': {'price_amount': 330000000}},
#  {'name': 'iCrossing', 'acquisition': {'price_amount': 325000000}},
#  {'name': 'Vignette', 'acquisition': {'price_amount': 310000000}},
#  {'name': 'Snapfish', 'acquisition': {'price_amount': 300000000}},
#  {'name': 'PGP Corporation', 'acquisition': {'price_amount': 300000000}},
#  {'name': 'Audible', 'acquisition': {'price_amount': 300000000}},
#  {'name': 'NetCracker Technology', 'acquisition': {'price_amount': 300000000}},
#  {'name': 'NetScaler', 'acquisition': {'price_amount': 300000000}},
#  {'name': 'Photon Dynamics', 'acquisition': {'price_amount': 290000000}},
#  {'name': 'Omneon', 'acquisition': {'price_amount': 274000000}},
#  {'name': 'Transmeta', 'acquisition': {'price_amount': 255600000}},
#  {'name': 'HowStuffWorks', 'acquisition': {'price_amount': 250000000}},
#  {'name': 'Alexa', 'acquisition': {'price_amount': 250000000}},
#  {'name': 'PeopleSupport', 'acquisition': {'price_amount': 250000000}},
#  {'name': 'HireRight', 'acquisition': {'price_amount': 249000000}},
#  {'name': 'AeroScout', 'acquisition': {'price_amount': 238800000}},
#  {'name': 'Iomega', 'acquisition': {'price_amount': 213000000}},
#  {'name': 'MediaVast', 'acquisition': {'price_amount': 202000000}},
#  {'name': 'MediaVast', 'acquisition': {'price_amount': 202000000}},
#  {'name': 'NetQoS', 'acquisition': {'price_amount': 200000000}},
#  {'name': 'AKQA', 'acquisition': {'price_amount': 200000000}},
#  {'name': 'AKQA', 'acquisition': {'price_amount': 200000000}},
#  {'name': 'Vocollect', 'acquisition': {'price_amount': 190000000}},
#  {'name': 'ICQ', 'acquisition': {'price_amount': 187500000}},
#  {'name': 'SideStep', 'acquisition': {'price_amount': 180000000}},
#  {'name': 'Sierra Monolithics', 'acquisition': {'price_amount': 180000000}},
#  {'name': 'AllRecipes', 'acquisition': {'price_amount': 175000000}},
#  {'name': 'Homestead Technologies',
#   'acquisition': {'price_amount': 170000000}},
#  {'name': 'Gracenote', 'acquisition': {'price_amount': 170000000}},
#  {'name': 'mindSHIFT Technologies',
#   'acquisition': {'price_amount': 167000000}},
#  {'name': 'Eveready', 'acquisition': {'price_amount': 167000000}},
#  {'name': 'Amcom Software', 'acquisition': {'price_amount': 163300000}},
#  {'name': 'KAZ Group', 'acquisition': {'price_amount': 161000000}},
#  {'name': 'Neopets', 'acquisition': {'price_amount': 160000000}},
#  {'name': 'Razorfish', 'acquisition': {'price_amount': 160000000}},
#  {'name': 'Ciao', 'acquisition': {'price_amount': 154000000}},
#  {'name': 'Ciao', 'acquisition': {'price_amount': 154000000}},
#  {'name': 'Zagat', 'acquisition': {'price_amount': 151000000}},
#  {'name': 'Voxeo', 'acquisition': {'price_amount': 150000000}},
#  {'name': 'Voxeo', 'acquisition': {'price_amount': 150000000}},
#  {'name': 'EachNet', 'acquisition': {'price_amount': 150000000}},
#  {'name': 'iWeb Technologies', 'acquisition': {'price_amount': 145000000}},
#  {'name': 'iWeb Technologies', 'acquisition': {'price_amount': 145000000}},
#  {'name': 'Zeus', 'acquisition': {'price_amount': 140000000}},
#  {'name': 'Phoenix Technologies', 'acquisition': {'price_amount': 139000000}},
#  {'name': 'Fastclick', 'acquisition': {'price_amount': 132000000}},
#  {'name': 'Speedera Networks', 'acquisition': {'price_amount': 130000000}},
#  {'name': 'Channel Intelligence', 'acquisition': {'price_amount': 125000000}},
#  {'name': 'SwapDrive', 'acquisition': {'price_amount': 123000000}},
#  {'name': 'Napster', 'acquisition': {'price_amount': 121000000}},
#  {'name': 'Auditude', 'acquisition': {'price_amount': 120000000}},
#  {'name': 'DigitalThink', 'acquisition': {'price_amount': 120000000}},
#  {'name': 'LiveOffice', 'acquisition': {'price_amount': 115000000}},
#  {'name': 'Catapult Communications',
#   'acquisition': {'price_amount': 106140000}},
#  {'name': 'CyberCoders', 'acquisition': {'price_amount': 105000000}},
#  {'name': 'Tidal Software', 'acquisition': {'price_amount': 105000000}},
#  {'name': 'Tundra Semiconductor', 'acquisition': {'price_amount': 100830000}},
#  {'name': 'RealAge', 'acquisition': {'price_amount': 100000000}},
#  {'name': 'VideoSurf', 'acquisition': {'price_amount': 100000000}},
#  {'name': 'VideoSurf', 'acquisition': {'price_amount': 100000000}},
#  {'name': 'AlltheWeb', 'acquisition': {'price_amount': 100000000}},
#  {'name': 'Orbiscom', 'acquisition': {'price_amount': 100000000}},
#  {'name': 'ioko', 'acquisition': {'price_amount': 91400000}},
#  {'name': 'GlobalEnglish', 'acquisition': {'price_amount': 90000000}},
#  {'name': 'Linux Networx', 'acquisition': {'price_amount': 90000000}},
#  {'name': 'Integration Associates', 'acquisition': {'price_amount': 87110000}},
#  {'name': 'InsureMe', 'acquisition': {'price_amount': 85000000}},
#  {'name': 'UGO Entertainment', 'acquisition': {'price_amount': 85000000}},
#  {'name': 'Extend Media', 'acquisition': {'price_amount': 80000000}},
#  {'name': 'Wedding Channel', 'acquisition': {'price_amount': 78000000}},
#  {'name': 'MyNewPlace', 'acquisition': {'price_amount': 74400000}},
#  {'name': 'NetManage', 'acquisition': {'price_amount': 73300000}},
#  {'name': 'Webshots', 'acquisition': {'price_amount': 71000000}},
#  {'name': 'Enliven Marketing Technologies',
#   'acquisition': {'price_amount': 71000000}},
#  {'name': 'Whale Communications', 'acquisition': {'price_amount': 70000000}},
#  {'name': 'EyeWonder', 'acquisition': {'price_amount': 66000000}},
#  {'name': 'EyeWonder', 'acquisition': {'price_amount': 66000000}},
#  {'name': 'Offermatica', 'acquisition': {'price_amount': 65000000}},
#  {'name': 'Sportsline', 'acquisition': {'price_amount': 64000000}},
#  {'name': 'Hifn', 'acquisition': {'price_amount': 63230000}},
#  {'name': 'Estech', 'acquisition': {'price_amount': 60000000}},
#  {'name': 'LigoCyte Pharmaceuticals',
#   'acquisition': {'price_amount': 60000000}},
#  {'name': 'AppStream', 'acquisition': {'price_amount': 53000000}},
#  {'name': 'NetThruPut', 'acquisition': {'price_amount': 52200000}},
#  {'name': 'Match', 'acquisition': {'price_amount': 50000000}},
#  {'name': 'Savvion', 'acquisition': {'price_amount': 49000000}},
#  {'name': 'Alpine Biomed', 'acquisition': {'price_amount': 46950000}},
#  {'name': 'Tek-Tools Software', 'acquisition': {'price_amount': 42000000}},
#  {'name': 'Applimation', 'acquisition': {'price_amount': 40000000}},
#  {'name': 'Voxmobili', 'acquisition': {'price_amount': 35120000}},
#  {'name': 'SoftImage', 'acquisition': {'price_amount': 35000000}},
#  {'name': 'Q-go', 'acquisition': {'price_amount': 34000000}},
#  {'name': 'OpenAir', 'acquisition': {'price_amount': 33000000}},
#  {'name': 'Xerox', 'acquisition': {'price_amount': 32500000}},
#  {'name': "eBaum's World", 'acquisition': {'price_amount': 32500000}},
#  {'name': 'Xdrive', 'acquisition': {'price_amount': 30000000}},
#  {'name': 'Veeco Instruments', 'acquisition': {'price_amount': 30000000}},
#  {'name': 'Inventa Technologies', 'acquisition': {'price_amount': 30000000}},
#  {'name': 'Muniservices', 'acquisition': {'price_amount': 29350000}},
#  {'name': 'InfoInterActive', 'acquisition': {'price_amount': 28200000}},
#  {'name': 'Tell Me More', 'acquisition': {'price_amount': 28000000}},
#  {'name': 'Onsite3', 'acquisition': {'price_amount': 28000000}},
#  {'name': 'Aleri Global Banking', 'acquisition': {'price_amount': 28000000}},
#  {'name': 'Recipezaar', 'acquisition': {'price_amount': 25000000}},
#  {'name': 'Ars Technica', 'acquisition': {'price_amount': 25000000}},
#  {'name': 'Digital Forest', 'acquisition': {'price_amount': 24820000}},
#  {'name': 'Universal Microwave', 'acquisition': {'price_amount': 23200000}},
#  {'name': 'Sendmail', 'acquisition': {'price_amount': 23000000}},
#  {'name': 'Guava Technologies', 'acquisition': {'price_amount': 22600000}},
#  {'name': 'NextBus', 'acquisition': {'price_amount': 20600000}},
#  {'name': 'QuickArrow', 'acquisition': {'price_amount': 19400000}},
#  {'name': 'Air2Web', 'acquisition': {'price_amount': 19000000}},
#  {'name': 'Advanced Control Components',
#   'acquisition': {'price_amount': 18780000}},
#  {'name': 'Kaboose', 'acquisition': {'price_amount': 18400000}},
#  {'name': 'Bookrags', 'acquisition': {'price_amount': 18000000}},
#  {'name': 'Contemporary Computer Services',
#   'acquisition': {'price_amount': 15040000}},
#  {'name': 'Iron Solutions', 'acquisition': {'price_amount': 15000000}},
#  {'name': 'Connect3 Systems', 'acquisition': {'price_amount': 13450000}},
#  {'name': 'Litmus Media', 'acquisition': {'price_amount': 13000000}},
#  {'name': 'Litmus Media', 'acquisition': {'price_amount': 13000000}},
#  {'name': 'MIVA', 'acquisition': {'price_amount': 11600000}},
#  {'name': 'Easyspace', 'acquisition': {'price_amount': 10500000}}]

# %% [markdown]
# ### 13. All the companies that have been acquired after 2010, order by the acquisition amount, and retrieve only their `name` and `acquisition` field.

# %%
list(colec.find({'acquisition.acquired_year':{'$lt':2010}},
                       
                {'_id':0, 'name':1,'acquisition.acquired_year':1}).sort('acquisition.acquired_year',-1))
# Out:
# [{'name': 'StumbleUpon', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Gizmoz', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Lala', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Joost', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SpinVox', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Jajah', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Spock', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Coghead', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'iLike', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Jaxtr', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Going', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Kiptronic', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'NowPublic', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sportingo', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Brightkite', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Veotag', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sun Microsystems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Zappos', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Friendster', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Narrowstep', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'MIVA', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SnapTell', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'imeem', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AdMob', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Kerpoof', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ChessPark', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Dopplr', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Kaboose', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'm-Qube', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'GroupSwim', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ENURGI', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Mobivox', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'FriendFeed', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'FlexiScale', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Dash', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Gydget', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'PicksPal', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Defensio', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SezWho', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'HiveLive', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Casero', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'StreetFire', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Omniture', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Interwoven', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sneakerplay', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Entrecard', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'FiveRuns', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Jott', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Takkle', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AppJet', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Delver', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'fabrik', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Wellsphere', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'fbExchange', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Mill River Labs', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Imified', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Movaya', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'TwoFish', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'EveryBlock', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Open Source Food', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AirMagnet', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Opinity', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Market Hardware', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Ad Infuse', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Inuk Networks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Kluster', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Tiny Pictures', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Kazeon', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Panther Express', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'GoodBarry', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Thrive', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'The FeedRoom', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Giant Realm', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sabrix', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Outblaze', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'PopularMedia', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sedo', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Yosemite Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Playfish', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Viddyou', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'MyMiniLife', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'GotVoice', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'DivShare', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Cemaphore Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Vizible', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Dimestore Media', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Xoopit', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Q-Layer', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Emurse', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'BooRah', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Weardrobe', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Krugle', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Pure Digital Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Tideway', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Velocix', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Centive', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Shopflick', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SharpForge', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Heysan', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'slinkset', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Medioh!', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'PIER Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Retail Convergence', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Wordie', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Greenbox', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Techrigy', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'eVapt', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Vignette', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Cellity', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Increo Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Cyber Communications', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'GigPark', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'J2Play', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Tapatap', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Placebase', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'GreenNote', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Pinch Media', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ShopIt', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'TickerHound', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Hyperic', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Marvel Entertainment', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Vusion', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Vumber', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Ziplocal', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Textic', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Keibi Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Greenfield Online', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Ounce Labs', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Interactive Networks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Jobitorial', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Apartment Home Living', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Data Domain', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Urbanspoon', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Borland', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Dexterra', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Wuala', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Hands-On Mobile', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Digimix', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Ku6', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SpringSource', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SPSS', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Paymo', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'NetQoS', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Propertyware', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Koolanoo Group', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Deadline Hollywood Daily', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Purewire', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Groople', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Alfabetic', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Spare Change Payments', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Weightview', 'acquisition': {'acquired_year': 2009}},
#  {'name': '3Com', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Finjan', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Apptism', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Koolanoo Group', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Deadline Hollywood Daily', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Purewire', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Groople', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Alfabetic', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Spare Change Payments', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Weightview', 'acquisition': {'acquired_year': 2009}},
#  {'name': '3Com', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Finjan', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Apptism', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Plum', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Exaprotect', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Lexcycle', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Berrystore', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'cligs', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Silicon Graphics', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Guardium', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'MX Logic', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'WedSnap', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SoberCircle', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'DocVerse', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Centennial Communications Corp',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Cassatt', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Zubican', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'QuickArrow', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SkyPilot Networks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Mi5 Networks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Clear Standards', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'WiChorus', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ClearSight Networks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Freshman Fund', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'net-m', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Zilog', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Mix2r', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Tipzu', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sterling Commerce', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Plusmo', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Conformia Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'DynaTech-Hosting', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'WildBlue', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Packet Island', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Symphony Vida', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ONStor', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Intellon Corporation', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Orbiscom', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Mobillcash', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Exeros', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Xumii', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'MediaXstream', 'acquisition': {'acquired_year': 2009}},
#  {'name': '1Up', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Certess', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Naverus', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Pulse Entertainment', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'id Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': '6th Sense Analytics', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'MonoSphere', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Total Music Group', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'BlueRoads', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'DuneNetworks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'HiWired', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'NetStreams', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Good Technology', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Turin Networks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'FastScaleTechnology', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'XStreet SL', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'onRez', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Woven Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ReserveAmerica', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Mazu Networks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Luminary Micro', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Teracent', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Grocery iQ', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ubroadcast', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AdaptiveAds', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'TV Games Network', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'CMWare', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Shacknews', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Tutpup', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'mValent', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'FreundeNews', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Homelidays', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Headshift', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'FreeRange', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ProtectPoint', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Applimation', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Cinario', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'FlipGloss', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Intercasting', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Ockham Research', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Imaginova', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Storyz', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Tizor Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'CVTips', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'GrooveJob', 'acquisition': {'acquired_year': 2009}},
#  {'name': "Steve's Digicams", 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SellMyCar', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Digital Fountain', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Lombardi Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'After the Deadline', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Patch', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Youth Bloggers Network', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Chronicle Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'TrafficGauge', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Networks in Motion', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Echodio', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AnySource Media', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'BeautyRiot', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Adventure Central', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'WikiCity', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'BorderWare Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sports Pickle', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Fluid Routing Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AdWhirl', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Red McCombs Media', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'HBOlab', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AMD Handheld Graphics', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'HI-TECH Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'RevenueDirect', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Datatel', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Identiphi', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'PayCycle', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'iZumi Bio', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ScreenToaster', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Planet Out', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Avocent', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Geotate', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Neonseven', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'BiPar Sciences', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Affair Match', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'BrandsOfTheWorld', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Solid Cactus', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Third Brigade', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'BigPark', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Starion Instruments', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Clean Machine', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Puget Energy', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'GeoDigm', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'CORPAK MedSystems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Professional Speech Processing Group of Siemens AG',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Brabeion Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Fail Dogs', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Big Huge Games', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Clacendix', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SunEdison', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'GlobalThoughtz', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Rosetta Biosoftware', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'MedServe', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Wind River', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Workbits', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'PharmaNet', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Ovation Pharmaceuticals', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'UPC Solar', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Unomedical Woundcare and Ophthalmic Business',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Applied Cell Sciences', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Cellatope', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Guava Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Software Techniques', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AllHealthCareJobs', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'InterNoded', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Alpine Biomed', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Innovative Spinal Technologies',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Airstream Energy', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Columbian Chemicals', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Gearworks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Virtual Heroes', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Anacomp', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Informatix Laboratories Corporation',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Axsys', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Raza Microelectronics', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Prism Circuits', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'DRC Computer', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'eQuilibrium Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Ntech Industries', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Primaeva Medical', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Monogram Biosciences', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Mint.com', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ESBATech', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Visiogen', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Intradigm Corporation', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'FromDriven', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ChipSolutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ExcellerateHRO', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Twinpoint Consulting Partners',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'dream ad', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Securityworks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Delphi Thermal Liquid Cooling',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Savant', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Genix Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Towers Perrin', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Cloud Cap Technology', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Micro Memory Bank', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Professional Development Software',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'eV Products', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Trio Enterprises', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'NetThruPut', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Symphony Allegro', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Brandclick', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'NetXen', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'IDT B', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Unibar', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AddressDoctor', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Tundra Semiconductor', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'New Energy Finance', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Eveready', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Grubby Games', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Internet Properties Group', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Promptext', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Mstar', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Arco Energy', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'BI Documenter', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'eileo', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Neoteric Technology', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Altivation Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'DisplayTech', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'UnoMobi Group', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Nitro Group LLC', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Axiom Microdevices', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Athenix', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Integrated Network Services',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'HxTechnologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Circuit Board Express', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Syfact', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Anix Group', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Affiliated Computer Services',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Relex Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Magen BioSciences', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AbCRO', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'IntelliPro', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Draka OPGW', 'acquisition': {'acquired_year': 2009}},
#  {'name': '3D Markets', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Route Sense', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'MobiApps', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Waban Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'MedManage Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'NetSimplify', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'North Central Communications',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Intexys', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Eldorado', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Phonestack', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Stiefel', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Report Hawk', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Galazar', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'BasePoint Analytics', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Channel Blade Technologies',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'ScanControl', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Bullrun Financial', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Esteam', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Intellifit', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'QuickPen', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'PulseMark', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Netupdate', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Interactive Management Systems',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Bowen Technical Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ICE Risk Management', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'KPI Online', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Acuity Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'DDK Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Helm Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Talcomp Management Solutions',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Compassoft', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SDC Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Radianta', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Warehouse Intellect', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Radius Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'tekGIANTS', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Insight Distribution Software',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Advent Solar', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Richards-Zeta Building Intelligence',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Innovative Enterprise Solutions',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Roundstone Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Tavilo', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Provident Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Powerway', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'DDP Police Services', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Global Software Corporation',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'ZEH Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Conformix', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'SoftTouch', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Ciclon Semiconductor Device Corporation',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Excelergy', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Verdict Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Coral8', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Metronome', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AlterPoint', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'MTC Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sana Security', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'NYTOR Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'High Tower Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Pelorus Technology', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Mirage Networks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'CompuExpert', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Darby Corporate Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Lydian Data Services', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'WKD Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Firefly Database Solutions',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Internetseer', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Control Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Siboney Learning Group', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Edgenuity', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Gastronaut Studios', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Snowblind Studios', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Increase CRM', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Fortefi', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'AIM Technology', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Lateral Net', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ATW Information Technology Systems',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Ulysses IT', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Teksys', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'KAZ Group', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Purple Labs', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Hifn', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Octopi', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Xperts', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Onsite3', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Digital Forest', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Connect3 Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ChoicePay', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Financial Media Net', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Infrasolve', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Video Furnace', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Atexis', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'LaurelTech', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Electrix', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Valco Data Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Scrugy', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'PA SportsTicker', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'VCentrix', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'CSS Creme', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'E-Strategic Solutions', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'TrekServe', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Aisle 19', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Tier Four Data Centers', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Bamboo Media Casting', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Progressive Service Management',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Tidal Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Access Data', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'eRx Network', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Contexo Media', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Corporate Lodging Consultants',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'PicoSolve', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Midway Games', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Danoo', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'CMS Direct', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Blink Twice', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Motive Technology', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Streamlogics', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sierra Monolithics', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Configuresoft', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'TZero Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Asempra Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ME2 Security', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Nexsem', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Enable Semiconductors', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Touchdown Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Fluens Corporation', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Veeco Instruments', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Crucial Security', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'TradeTrans', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'eWish', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'DataCities', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'BenefitStreet', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Cyveillance', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'The WEB Channel Network', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'XtEnterprise', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'E-register', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'California 7 Studios', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Xwave New England Corp', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Fox River Audio Visual', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Priority Time Systems', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Homesaver', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'eXMeritus', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Informance International', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Virtual Iron Software', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Catapult Communications', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'LocationLogic', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Cura Risk Management Software',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'ColdSpark', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Assessment Evaluation Services',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'Ambric', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Castify Holdings', 'acquisition': {'acquired_year': 2009}},
#  {'name': '10East', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'MMAAdNet', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'm35 Limited', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sysnet Info-tech', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'RapidSwitch', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Indlaw', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ASTECH InterMedia', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'ReferenceDataFactory', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'EZ Finder Phonebooks', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Sirific Wireless', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Inventa Technologies', 'acquisition': {'acquired_year': 2009}},
#  {'name': "Kler's", 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Universal Microwave', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Mu-Gahat Enterprises', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Advanced Control Components',
#   'acquisition': {'acquired_year': 2009}},
#  {'name': 'EnterSys Group', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Intergy', 'acquisition': {'acquired_year': 2009}},
#  {'name': 'Helio', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Plaxo', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Powerset', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Livestream', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Pownce', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'MeeVee', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Farecast', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Pageflakes', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Wink', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Truemors', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'IntenseDebate', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'madKast', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Revver', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Social Platform', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Snocap', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Socialthing', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'PartnerUp', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Fathom Online', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Goowy', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'ZYB', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Ruckus', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Pluck', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Kelkoo', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'MusicGremlin', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'MySQL', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'IMSafer', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Auctomatic', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'BigSwerve', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'buddystumbler', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Tioti', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Rupture', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Qloud', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Plazes', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Compete', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Peerflix', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'eSnips', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Songza', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Snapvine', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Fraud Sciences', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'expensr', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Summize', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Ribbit', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'PollDaddy', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Onaro', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'HaloScan', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Nexo', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Mogad', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'TicketsNow', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'FriendsAbroad', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'DevZuz', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'CleverSet', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Lookery', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Aductions', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Maven Networks', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Q Interactive', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Zync', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Shelfari', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Danger', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Kindo Network', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Calista Technologies', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Tacit Software', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'imity', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'MessageOne', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Answerology', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'BEA Systems', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'The Bump', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Napster', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Ingrian Networks', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Boonty', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Generate', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Rutube', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Origin Digital', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'CustomerSat', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Credentica', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'PI Corporation', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Vidmeter', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Platform Solutions', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Clickpass', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'DailyStrength', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Chalk', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Kidaro', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Twhirl', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Rapt', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Omnisio', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'DayPort', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'PeopleSupport', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'BladeLogic', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'AdEngage', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Pikum', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Homestead Technologies', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'BeInSync', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'GameVee', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'FoxyTunes', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Jotlet', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Special Ops Media', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Sim4travel', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Iomega', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'AddMe', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Kasenna', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'MessageLabs', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Social Median', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'FlipKey', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Apperceptive', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Rising Sun Research', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Tripath Technology', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Adify', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Umbria', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Verisign DBMS', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'MyAnimeList', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'DynoPlex', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'YourTechOnline', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'FantasyBook', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Vurv Technology', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Inquisitor', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Packeteer', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'NameIntelligence', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'F2 Interactive', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Arseblog', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Telelogic', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'NetworthIQ', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Ars Technica', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'SFO*MEDIA', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'StarNet Interactive', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Hymotion', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'PA Semi', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Sirtris Pharmaceuticals', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Jamba', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Kamera', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Identyx', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Etchstar', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Activeweave', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Apertio', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'M:Metrics', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Tejit', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'B-hive Networks', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Sylantro', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'OpenAir', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Navic Networks', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Personifi', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'H-care', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Lexico Publishing Group', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Codefast', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'SwapDrive', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Projity', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Mapufacture', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Ideal Bite', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Bankaholic', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Sport Interactiva', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Imagekind', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Mousebreaker', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Audible', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'UGENmedia', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Mobile Trend', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'MobiComp', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'IONA Technologies', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'SightSpeed', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'LuckySurf', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'GrayBoxx', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'PixVerse', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Linspire', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'VirtualTourist', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'OneTime', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Cellidea', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'The Weather Channel', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Reconnex', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Lefthand Networks', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Discovery Mining', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Triana Global', 'acquisition': {'acquired_year': 2008}},
# ...
#  {'name': 'Blogdigger', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Aftervote', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Codex Media', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Navteq', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Bloombla', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'EyeSpot', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Idolator', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Absolute Punk', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'My Family', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Broad Street Digital', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Fundamental Data Limited', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Mercado', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Media by Numbers', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Buddy Press', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Europa Australia', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Komoku', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Caligari Corporation', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'acerno', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Mezimedia', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'NICHE', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Mediaselling', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Visual Connection', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Slicehost', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Amazon DVD rental', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'DooYoo', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Reflexive Entertainment', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Trovix', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Mobile Trends', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Real Cities', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'inDplay', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Media River', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Simple Hosting', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Sportacular', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'g2One', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'e-dialog', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'BitLeap', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Wayport', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Illuminex', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Adonomics', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Decho', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Wysiwyg', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'YelloYello', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Transitive', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'SoftImage', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Mindreef', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Codegear', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Attenex', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Morpheum', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Values of n', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Tribal Agency', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'knowledgewhere', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'v7n Network', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Vuvox', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Orbital Management', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Wayfinder', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Clear Technology', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Cognos', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Transmeta', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'ILOG', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Tumbleweed Communications', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Sennari Entertainment', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Picdar', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Radiance', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Where To', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Koders', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Rocket Science', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Voxant', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'RadioSherpa', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Me2day', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Mobitween', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Livemarkets', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'EB2 International', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Box Office Mojo', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'KeyToSound', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'ScreenLife', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'ParentsClick Network', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'FierceMarkets', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'SpaTrade', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Network Management Partners',
#   'acquisition': {'acquired_year': 2008}},
#  {'name': 'CapitalStream', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'RichFX', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'XIV', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'ITM Software', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Linux Networx', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Sitescape', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Innotek', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Twistbox Entertainment', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'CellGate', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'SCPanel', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'NextHop Technologies', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Secure Computing', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Questra', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'WBS', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'SWI Digital', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'AdultMint', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Frontline Direct', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'RedLever', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'ESGUT', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'MINICK Group', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Holiday Watchdog', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Move Marketing', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Accendra', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'PC Tools', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Indicative Software', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'GreenOptions Media', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Soar Consulting', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Payzone - Open Loop Gift business',
#   'acquisition': {'acquired_year': 2008}},
#  {'name': 'Paisley', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Diligent Technologies', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Applied Insights', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Nanny Providers Canada', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Xiam', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Huge', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Brandspace', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Performics', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Venere', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'WysDM Software', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Amlink Technologies', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Actimis Pharmaceuticals', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Telisma', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'HighBeam Research', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'CareGain', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'The Kelsey Group', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'eTelecare', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Accent Food Services', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'American Land Lease', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'SportVU', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Targeted Molecular Diagnostics',
#   'acquisition': {'acquired_year': 2008}},
#  {'name': 'Biosystems International', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Chesapeake Solar', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Proprius', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Adaptive Real Estate Services',
#   'acquisition': {'acquired_year': 2008}},
#  {'name': 'DuBois', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'BioMed Central', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'MACNOTES', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'UpToDate', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Pagamento Digital', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'F-Control', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Vehix', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Openware', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'S3I', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'SI Government Solutions', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'GP Solar', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Cadence Network', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'OATSystems', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Vativ Technologies', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Kintera', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'TripleArc', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'AppStream', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'ProLogic', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Expro Meters', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Enliven Marketing Technologies',
#   'acquisition': {'acquired_year': 2008}},
#  {'name': 'NetManage', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Primarion', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Identity Systems', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Integration Associates', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Pro Brand International', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Era', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Oberon Associates', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Zetex', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'JAZZ TECHNOLOGIES', 'acquisition': {'acquired_year': 2008}},
#  {'name': "Don't Shoot Enterprises", 'acquisition': {'acquired_year': 2008}},
#  {'name': 'AdaNet', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Radyne', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Optium', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'HireRight', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Moldflow', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Photon Dynamics', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'NetCracker Technology', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'PlantCML', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'NuTech Solutions', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Metrologic Instruments', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Relevantis', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'System Innovators', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Trinary Systems', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'EduCard', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'ViaNovus', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Interprise Software Solutions',
#   'acquisition': {'acquired_year': 2008}},
#  {'name': 'Incuity Software', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Shape Games', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'FullTilt Solutions', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'DebtFolio', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Translucent', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Tizbi', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'MBH Solutions', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Dial Assurance', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Jiangsu Shunda Semiconductor Development',
#   'acquisition': {'acquired_year': 2008}},
#  {'name': 'The MacNeal Group', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Aware Interweave', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Warelex', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Center Line Data', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Ponte Solutions', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Onvaio', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'AccessFlow', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Technologies and Devices International',
#   'acquisition': {'acquired_year': 2008}},
#  {'name': 'REApplications', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Datum Legal', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Vidavee', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Bookrags', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Open E Cry', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Skywire Software', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Multispectral Solutions', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Commercial Communications', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Provost Systems', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Aleri Global Banking', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Muniservices', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Lyrio', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Nuova Systems', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'DocuVault', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'AmeriVault', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Multispectral Imaging', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'The Dialog Corporation', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'PowerOneData', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Elephant Entertaiment', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Collaboration Online', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Cyberspace Communcation', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Cogent Technologies', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Vertical Passion Media', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'InfoDyne Corporation', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Montalvo Systems', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Storm Semiconductor', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'AddVal Technology', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'TheFashionSpot', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'AdminServer', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'EzValidation', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Quotit', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'OnDemandIQ', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Focus Views', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Fast Data Technology', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'iPartyTV', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'Evolutionary Technologies International',
#   'acquisition': {'acquired_year': 2008}},
#  {'name': 'Direct Technology Innovations',
#   'acquisition': {'acquired_year': 2008}},
#  {'name': 'RayScale', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'LogicLibrary', 'acquisition': {'acquired_year': 2008}},
#  {'name': 'AGEIA Technologies', 'acquisition': {'acquired_year': 2008}},
#  ...]

# %% [markdown]
# ### 14. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
list(colec.find({},
    {'name':1, '_id':0,'founded_year':1}).sort('founded_year',-1))
# Out:
# [{'name': 'Fixya', 'founded_year': 2013},
#  {'name': 'Wamba', 'founded_year': 2013},
#  {'name': 'Advaliant', 'founded_year': 2013},
#  {'name': 'Fluc', 'founded_year': 2013},
#  {'name': 'iBazar', 'founded_year': 2013},
#  {'name': 'Gimigo', 'founded_year': 2013},
#  {'name': 'SEOGroup', 'founded_year': 2013},
#  {'name': 'Clowdy', 'founded_year': 2013},
#  {'name': 'WhosCall', 'founded_year': 2013},
#  {'name': 'Pikk', 'founded_year': 2013},
#  {'name': 'Tongxue', 'founded_year': 2013},
#  {'name': 'Shopseen', 'founded_year': 2013},
#  {'name': 'VistaGen Therapeutics', 'founded_year': 2013},
#  {'name': 'PeekYou', 'founded_year': 2012},
#  {'name': 'headr', 'founded_year': 2012},
#  {'name': 'Pinger', 'founded_year': 2012},
#  {'name': 'Widgetbox', 'founded_year': 2012},
#  {'name': 'Mobiluck', 'founded_year': 2012},
#  {'name': 'Skydeck', 'founded_year': 2012},
#  {'name': 'Simplicant', 'founded_year': 2012},
#  {'name': 'Springleap', 'founded_year': 2012},
#  {'name': 'Jumbuck Entertainment', 'founded_year': 2012},
#  {'name': 'Carfeine', 'founded_year': 2012},
#  {'name': 'Bling Easy', 'founded_year': 2012},
#  {'name': 'FoodCare', 'founded_year': 2012},
#  {'name': 'Non-Member Films', 'founded_year': 2012},
#  {'name': 'Non-Member Films', 'founded_year': 2012},
#  {'name': 'Navara', 'founded_year': 2012},
#  {'name': 'PriceHub', 'founded_year': 2012},
#  {'name': 'Ptch', 'founded_year': 2012},
#  {'name': 'LoveAccess', 'founded_year': 2012},
#  {'name': 'Newstree', 'founded_year': 2012},
#  {'name': 'FAT Media', 'founded_year': 2012},
#  {'name': 'Fliggo', 'founded_year': 2012},
#  {'name': 'Topify', 'founded_year': 2012},
#  {'name': 'Pict', 'founded_year': 2012},
#  {'name': 'RipCloud', 'founded_year': 2012},
#  {'name': 'Plug in SEO', 'founded_year': 2012},
#  {'name': 'Veewow', 'founded_year': 2012},
#  {'name': 'Insignia Technologies', 'founded_year': 2012},
#  {'name': 'Easel', 'founded_year': 2012},
#  {'name': 'Red Ambiental', 'founded_year': 2012},
#  {'name': 'DocASAP', 'founded_year': 2012},
#  {'name': 'Mokitown', 'founded_year': 2011},
#  {'name': 'CircleUp', 'founded_year': 2011},
#  {'name': 'RazorGator', 'founded_year': 2011},
#  {'name': 'Social Gaming Network', 'founded_year': 2011},
#  {'name': 'Moblica', 'founded_year': 2011},
#  {'name': 'Streamzy', 'founded_year': 2011},
#  {'name': 'FirstString', 'founded_year': 2011},
#  {'name': 'Fuzz', 'founded_year': 2011},
#  {'name': 'Whisper Labs', 'founded_year': 2011},
#  {'name': 'Ziippi', 'founded_year': 2011},
#  {'name': 'Mousebreaker', 'founded_year': 2011},
#  {'name': 'Pixelmatic', 'founded_year': 2011},
#  {'name': 'EasyBib', 'founded_year': 2011},
#  {'name': 'N-Play', 'founded_year': 2011},
#  {'name': 'Advisor', 'founded_year': 2011},
#  {'name': 'Mercedez Benz', 'founded_year': 2011},
#  {'name': 'travelmob', 'founded_year': 2011},
#  {'name': 'Kidos', 'founded_year': 2011},
#  {'name': 'travelmob', 'founded_year': 2011},
#  {'name': 'Kidos', 'founded_year': 2011},
#  {'name': 'Hany', 'founded_year': 2011},
#  {'name': 'FamilyDen', 'founded_year': 2011},
#  {'name': 'Baveo', 'founded_year': 2011},
#  {'name': 'Emotive Communications', 'founded_year': 2011},
#  {'name': 'GroupTable', 'founded_year': 2011},
#  {'name': 'Cyphercor', 'founded_year': 2011},
#  {'name': 'Queralt', 'founded_year': 2011},
#  {'name': 'TwitBacks', 'founded_year': 2011},
#  {'name': 'You Are Truly Loved', 'founded_year': 2011},
#  {'name': 'Unison Technologies', 'founded_year': 2011},
#  {'name': 'NetCitadel', 'founded_year': 2011},
#  {'name': 'VisualOn', 'founded_year': 2011},
#  {'name': 'troovy', 'founded_year': 2011},
#  {'name': 'zahdoo', 'founded_year': 2011},
#  {'name': 'Plabesk', 'founded_year': 2011},
#  {'name': '4shared', 'founded_year': 2011},
#  {'name': 'CompareChecker', 'founded_year': 2011},
#  {'name': 'Taggify', 'founded_year': 2011},
#  {'name': 'Jively', 'founded_year': 2011},
#  {'name': 'Hayen Company', 'founded_year': 2011},
#  {'name': 'Molecube', 'founded_year': 2011},
#  {'name': 'Pitchie', 'founded_year': 2011},
#  {'name': 'Treehouse', 'founded_year': 2011},
#  {'name': 'GENWI', 'founded_year': 2010},
#  {'name': 'Needium', 'founded_year': 2010},
#  {'name': 'Quirk', 'founded_year': 2010},
#  {'name': 'YouNoodle', 'founded_year': 2010},
#  {'name': 'Magento', 'founded_year': 2010},
#  {'name': 'Pixsta', 'founded_year': 2010},
#  {'name': 'CollegeConvo', 'founded_year': 2010},
#  {'name': 'Titan Gaming', 'founded_year': 2010},
#  {'name': 'SiSense', 'founded_year': 2010},
#  {'name': 'MaroonDoor', 'founded_year': 2010},
#  {'name': 'JumpForward', 'founded_year': 2010},
#  {'name': 'OTOY', 'founded_year': 2010},
#  {'name': 'Localist', 'founded_year': 2010},
#  {'name': 'Integrate', 'founded_year': 2010},
#  {'name': 'vufind', 'founded_year': 2010},
#  {'name': 'UsingMiles', 'founded_year': 2010},
#  {'name': 'Cellogic', 'founded_year': 2010},
#  {'name': 'Localist', 'founded_year': 2010},
#  {'name': 'Integrate', 'founded_year': 2010},
#  {'name': 'vufind', 'founded_year': 2010},
#  {'name': 'UsingMiles', 'founded_year': 2010},
#  {'name': 'Cellogic', 'founded_year': 2010},
#  {'name': 'MxThinkShare', 'founded_year': 2010},
#  {'name': 'BizEquity', 'founded_year': 2010},
#  {'name': 'Equedia', 'founded_year': 2010},
#  {'name': 'Webmoblink', 'founded_year': 2010},
#  {'name': 'Webtab', 'founded_year': 2010},
#  {'name': 'Diffbot', 'founded_year': 2010},
#  {'name': 'Yipit', 'founded_year': 2010},
#  {'name': 'fruux', 'founded_year': 2010},
#  {'name': 'FeedHenry', 'founded_year': 2010},
#  {'name': 'Tengaged', 'founded_year': 2010},
#  {'name': 'Reachoo', 'founded_year': 2010},
#  {'name': 'Avenir Medical', 'founded_year': 2010},
#  {'name': 'Indee', 'founded_year': 2010},
#  {'name': 'Twitpay', 'founded_year': 2010},
#  {'name': 'eCampusCash', 'founded_year': 2010},
#  {'name': 'WebriQ', 'founded_year': 2010},
#  {'name': 'kinDragon', 'founded_year': 2010},
#  {'name': 'The Scene', 'founded_year': 2010},
#  {'name': 'Aquavation', 'founded_year': 2010},
#  {'name': 'BASH Gaming', 'founded_year': 2010},
#  {'name': 'AppNeta', 'founded_year': 2010},
#  {'name': 'MyLikes', 'founded_year': 2010},
#  {'name': 'Memetales', 'founded_year': 2010},
#  {'name': 'Jobzle', 'founded_year': 2010},
#  {'name': 'Mashape', 'founded_year': 2010},
#  {'name': 'Ajiel', 'founded_year': 2010},
#  {'name': 'Abengoa', 'founded_year': 2010},
#  {'name': 'Flixxy', 'founded_year': 2010},
#  {'name': 'KarmaKorn', 'founded_year': 2010},
#  {'name': 'Blurtt', 'founded_year': 2010},
#  {'name': 'Fliptop', 'founded_year': 2010},
#  {'name': 'ekidnaworld', 'founded_year': 2010},
#  {'name': 'Chicisimo', 'founded_year': 2010},
#  {'name': 'IndieByChoice', 'founded_year': 2010},
#  {'name': 'AudioBoo', 'founded_year': 2010},
#  {'name': 'ticketea', 'founded_year': 2010},
#  {'name': 'Shreppy', 'founded_year': 2010},
#  {'name': 'Start Mobile', 'founded_year': 2010},
#  {'name': 'Mobovivo', 'founded_year': 2009},
#  {'name': 'alluc', 'founded_year': 2009},
#  {'name': 'Crootpad', 'founded_year': 2009},
#  {'name': 'Ninite', 'founded_year': 2009},
#  {'name': 'Handipoints', 'founded_year': 2009},
#  {'name': 'TeamSnap', 'founded_year': 2009},
#  {'name': 'Trunkt', 'founded_year': 2009},
#  {'name': 'Macroaxis', 'founded_year': 2009},
#  {'name': 'Supercool School', 'founded_year': 2009},
#  {'name': 'Stagevu', 'founded_year': 2009},
#  {'name': 'OneScreen', 'founded_year': 2009},
#  {'name': 'BrandYourself', 'founded_year': 2009},
#  {'name': 'Vusion', 'founded_year': 2009},
#  {'name': 'BitRock', 'founded_year': 2009},
#  {'name': 'KelBillet', 'founded_year': 2009},
#  {'name': 'NewsEndorser', 'founded_year': 2009},
#  {'name': 'Digimix', 'founded_year': 2009},
#  {'name': 'HEPHESTO', 'founded_year': 2009},
#  {'name': 'Prezi', 'founded_year': 2009},
#  {'name': 'Hellofam', 'founded_year': 2009},
#  {'name': 'Garena', 'founded_year': 2009},
#  {'name': 'CompareAway', 'founded_year': 2009},
#  {'name': 'GetYourGuide', 'founded_year': 2009},
#  {'name': 'Burt', 'founded_year': 2009},
#  {'name': 'Inuvo', 'founded_year': 2009},
#  {'name': 'Burt', 'founded_year': 2009},
#  {'name': 'Inuvo', 'founded_year': 2009},
#  {'name': 'Magoosh', 'founded_year': 2009},
#  {'name': 'perceptu', 'founded_year': 2009},
#  {'name': 'payByMobile', 'founded_year': 2009},
#  {'name': 'Mybandstock', 'founded_year': 2009},
#  {'name': 'Formspring', 'founded_year': 2009},
#  {'name': 'isocket', 'founded_year': 2009},
#  {'name': "Lil'Grams", 'founded_year': 2009},
#  {'name': 'Netzsprecher', 'founded_year': 2009},
#  {'name': 'Stupeflix', 'founded_year': 2009},
#  {'name': 'Star Fever Agency', 'founded_year': 2009},
#  {'name': 'Kwanzoo', 'founded_year': 2009},
#  {'name': 'StudyBlue', 'founded_year': 2009},
#  {'name': 'Storenvy', 'founded_year': 2009},
#  {'name': 'Carsala', 'founded_year': 2009},
#  {'name': 'HyperWeek', 'founded_year': 2009},
#  {'name': 'LaunchPad Coworking', 'founded_year': 2009},
#  {'name': 'BookingBug', 'founded_year': 2009},
#  {'name': 'StyleHop', 'founded_year': 2009},
#  {'name': 'Social1000', 'founded_year': 2009},
#  {'name': 'Livekick', 'founded_year': 2009},
#  {'name': 'Jolicloud', 'founded_year': 2009},
#  {'name': 'Calisto100', 'founded_year': 2009},
#  {'name': 'Revenue Architects', 'founded_year': 2009},
#  {'name': 'JumpFox', 'founded_year': 2009},
#  {'name': 'Tweba', 'founded_year': 2009},
#  {'name': 'GymFu', 'founded_year': 2009},
#  {'name': 'Do You Wanna Hook Up?', 'founded_year': 2009},
#  {'name': 'Twiturm', 'founded_year': 2009},
#  {'name': 'Wappalyzer', 'founded_year': 2009},
#  {'name': 'facelovefinder', 'founded_year': 2009},
#  {'name': 'Infor', 'founded_year': 2009},
#  {'name': 'fefoo', 'founded_year': 2009},
#  {'name': 'Crowd Rent', 'founded_year': 2009},
#  {'name': 'ScaleMP', 'founded_year': 2009},
#  {'name': 'Otalo', 'founded_year': 2009},
#  {'name': 'SaveTable', 'founded_year': 2009},
#  {'name': 'BNO News', 'founded_year': 2009},
#  {'name': 'mysoogal', 'founded_year': 2009},
#  {'name': 'Tweetvisor', 'founded_year': 2009},
#  {'name': 'Digital Meld', 'founded_year': 2009},
#  {'name': 'Stuffpit', 'founded_year': 2009},
#  {'name': 'Twtapps', 'founded_year': 2009},
#  {'name': 'Heyzap', 'founded_year': 2009},
#  {'name': 'Fail Fund', 'founded_year': 2009},
#  {'name': 'iShopWiser', 'founded_year': 2009},
#  {'name': 'Talk to a Celeb', 'founded_year': 2009},
#  {'name': 'AudioCrunch', 'founded_year': 2009},
#  {'name': 'Raise for Future', 'founded_year': 2009},
#  {'name': 'Errorlytics', 'founded_year': 2009},
#  {'name': 'Meez', 'founded_year': 2009},
#  {'name': 'TownSync', 'founded_year': 2009},
#  {'name': 'Pilus Energy', 'founded_year': 2009},
#  {'name': 'About Me!', 'founded_year': 2009},
#  {'name': 'Zeemp', 'founded_year': 2009},
#  {'name': 'Ninth Division', 'founded_year': 2009},
#  {'name': 'TwTip', 'founded_year': 2009},
#  {'name': 'GrouperEye', 'founded_year': 2009},
#  {'name': 'MyFolio', 'founded_year': 2009},
#  {'name': 'Skilto', 'founded_year': 2009},
#  {'name': 'Lebxshells', 'founded_year': 2009},
#  {'name': 'ikywim creative', 'founded_year': 2009},
#  {'name': 'iplotz', 'founded_year': 2009},
#  {'name': 'apnakoi', 'founded_year': 2009},
#  {'name': 'twit4hire', 'founded_year': 2009},
#  {'name': 'Talari Networks', 'founded_year': 2009},
#  {'name': 'Openviv', 'founded_year': 2009},
#  {'name': 'Isai', 'founded_year': 2009},
#  {'name': 'Filter My Jobs', 'founded_year': 2009},
#  {'name': 'TechnoFinger', 'founded_year': 2009},
#  {'name': 'Twittelligence', 'founded_year': 2009},
#  {'name': 'Zammr', 'founded_year': 2009},
#  {'name': 'Shutl', 'founded_year': 2009},
#  {'name': 'Interacto', 'founded_year': 2009},
#  {'name': 'Asurrent', 'founded_year': 2009},
#  {'name': 'Ontology2', 'founded_year': 2009},
#  {'name': 'Music For Busy People', 'founded_year': 2009},
#  {'name': 'Centillion', 'founded_year': 2009},
#  {'name': 'alteregoweb', 'founded_year': 2009},
#  {'name': 'Curiously Green', 'founded_year': 2009},
#  {'name': 'Milabra', 'founded_year': 2009},
#  {'name': 'MightyBrand', 'founded_year': 2009},
#  {'name': 'Craave', 'founded_year': 2009},
#  {'name': 'Embedit', 'founded_year': 2009},
#  {'name': 'web seo masters', 'founded_year': 2009},
#  {'name': 'D-Modules', 'founded_year': 2009},
#  {'name': 'HREF', 'founded_year': 2009},
#  {'name': 'AdCause', 'founded_year': 2009},
#  {'name': 'FootyTweets', 'founded_year': 2009},
#  {'name': 'Komverse', 'founded_year': 2009},
#  {'name': 'VouChaCha', 'founded_year': 2009},
#  {'name': 'CanvasGrafix', 'founded_year': 2009},
#  {'name': 'Zibutu', 'founded_year': 2009},
#  {'name': 'Mojella', 'founded_year': 2009},
#  {'name': 'mogamebo', 'founded_year': 2009},
#  {'name': 'Live Txt', 'founded_year': 2009},
#  {'name': 'Tweetube', 'founded_year': 2009},
#  {'name': 'Carmony', 'founded_year': 2009},
#  {'name': 'PerSquareFeet', 'founded_year': 2009},
#  {'name': 'Travellr', 'founded_year': 2009},
#  {'name': 'Minojo', 'founded_year': 2009},
#  {'name': 'Web Momentum', 'founded_year': 2009},
#  {'name': 'Rouse Media', 'founded_year': 2009},
#  {'name': 'BuzzNova Media', 'founded_year': 2009},
#  {'name': 'Reflect7', 'founded_year': 2009},
#  {'name': 'LaunchMind', 'founded_year': 2009},
#  {'name': 'DediServe', 'founded_year': 2009},
#  {'name': 'nanonet', 'founded_year': 2009},
#  {'name': 'eDori', 'founded_year': 2009},
#  {'name': 'Tinychat', 'founded_year': 2009},
#  {'name': 'InterneTV', 'founded_year': 2009},
#  {'name': 'Transifex', 'founded_year': 2009},
#  {'name': 'CSRware', 'founded_year': 2009},
#  {'name': 'completelyprivatefiles', 'founded_year': 2009},
#  {'name': 'Advanced Advocates', 'founded_year': 2009},
#  {'name': 'brdcstr', 'founded_year': 2009},
#  {'name': 'Moovum', 'founded_year': 2009},
#  {'name': 'SEO Jobs Finder', 'founded_year': 2009},
#  {'name': 'Plupper', 'founded_year': 2009},
#  {'name': 'BidPlace SB', 'founded_year': 2009},
#  {'name': 'Foliospaces', 'founded_year': 2009},
#  {'name': 'imFORZA Marketing', 'founded_year': 2009},
#  {'name': 'Coralmap', 'founded_year': 2009},
#  {'name': 'Mailbeans', 'founded_year': 2009},
#  {'name': 'HealthyTweet', 'founded_year': 2009},
#  {'name': 'Startup Revival', 'founded_year': 2009},
#  {'name': 'IamStocks', 'founded_year': 2009},
#  {'name': 'Tech Profuse', 'founded_year': 2009},
#  {'name': 'MallCrawl', 'founded_year': 2009},
#  {'name': 'YardWorkerz', 'founded_year': 2009},
#  {'name': 'CitySpur', 'founded_year': 2009},
#  {'name': "Freakn' Sweet", 'founded_year': 2009},
#  {'name': 'Jobshouts', 'founded_year': 2009},
#  {'name': 'GreenITers', 'founded_year': 2009},
#  {'name': 'ClickMeter', 'founded_year': 2009},
#  {'name': 'AnyPrice', 'founded_year': 2009},
#  {'name': 'AppZero', 'founded_year': 2009},
#  {'name': 'Obsessed TV', 'founded_year': 2009},
#  {'name': 'betterchange', 'founded_year': 2009},
#  {'name': 'Message Motivator', 'founded_year': 2009},
#  {'name': 'PebbleForge', 'founded_year': 2009},
#  {'name': 'TwitterCorp', 'founded_year': 2009},
#  {'name': 'Zooity', 'founded_year': 2009},
#  {'name': 'Legal River', 'founded_year': 2009},
#  {'name': 'Tomato Picker', 'founded_year': 2009},
#  {'name': 'Embedr', 'founded_year': 2009},
#  {'name': 'Action Sports Branding', 'founded_year': 2009},
#  {'name': 'RealUp', 'founded_year': 2009},
#  {'name': 'India Home Tips', 'founded_year': 2009},
#  {'name': 'Bhiring', 'founded_year': 2009},
#  {'name': 'Load Impact', 'founded_year': 2009},
#  {'name': 'Founder Institute', 'founded_year': 2009},
#  {'name': 'KidSwirl', 'founded_year': 2009},
#  {'name': 'Clasilistados', 'founded_year': 2009},
#  {'name': 'The Vertical Action Group', 'founded_year': 2009},
#  {'name': 'Divvyshot', 'founded_year': 2009},
#  {'name': 'txtmailer', 'founded_year': 2009},
#  {'name': 'Cognitive Match', 'founded_year': 2009},
#  {'name': 'Simulmedia', 'founded_year': 2009},
#  {'name': 'Socialbel', 'founded_year': 2009},
#  {'name': 'Tenant Txt', 'founded_year': 2009},
#  {'name': 'VocalBuzz', 'founded_year': 2009},
#  {'name': 'UnHub', 'founded_year': 2009},
#  {'name': 'Point Motive', 'founded_year': 2009},
#  {'name': 'rent2friend', 'founded_year': 2009},
#  {'name': 'VideoCustomizer', 'founded_year': 2009},
#  {'name': 'Wolfram Alpha', 'founded_year': 2009},
#  {'name': 'Twits Mag', 'founded_year': 2009},
#  {'name': 'Gridstore', 'founded_year': 2009},
#  {'name': 'Tweet Top', 'founded_year': 2009},
#  {'name': 'VitalLock', 'founded_year': 2009},
#  {'name': 'MYiLIVE', 'founded_year': 2009},
#  {'name': 'bluewalks', 'founded_year': 2009},
#  {'name': 'Azure Web Design', 'founded_year': 2009},
#  {'name': "i'm veg", 'founded_year': 2009},
#  {'name': 'Honk', 'founded_year': 2009},
#  {'name': 'Devoted Domains', 'founded_year': 2009},
#  {'name': 'OBE Pro', 'founded_year': 2009},
#  {'name': 'Harkopen', 'founded_year': 2009},
#  {'name': 'Tweetizen', 'founded_year': 2009},
#  {'name': 'Internet Marketing Academy Australia', 'founded_year': 2009},
#  {'name': 'thredUP', 'founded_year': 2009},
#  {'name': 'IndiMedicos', 'founded_year': 2009},
#  {'name': 'IrishCentral', 'founded_year': 2009},
#  {'name': 'Cloud Disk', 'founded_year': 2009},
#  {'name': 'Cloudkick', 'founded_year': 2009},
#  {'name': 'Blippitt', 'founded_year': 2009},
#  {'name': 'eSocialWeb', 'founded_year': 2009},
#  {'name': 'Roosst!', 'founded_year': 2009},
#  {'name': 'Layoff Support Network', 'founded_year': 2009},
#  {'name': 'Cuteness Pet Community', 'founded_year': 2009},
#  {'name': 'yiid', 'founded_year': 2009},
#  {'name': 'Sterlind Data Vault', 'founded_year': 2009},
#  {'name': 'Echodio', 'founded_year': 2009},
#  {'name': 'myRoomies', 'founded_year': 2009},
#  {'name': 'Foursquare', 'founded_year': 2009},
#  {'name': 'Mashed jobs', 'founded_year': 2009},
#  {'name': 'TringAll', 'founded_year': 2009},
#  {'name': 'Skysheet', 'founded_year': 2009},
#  {'name': 'Picurio', 'founded_year': 2009},
#  {'name': 'Nambii', 'founded_year': 2009},
#  {'name': 'High Desert Technologies', 'founded_year': 2009},
#  {'name': 'Greenovations At Home', 'founded_year': 2009},
#  {'name': 'Jobs Mojo', 'founded_year': 2009},
#  {'name': 'Guias Local', 'founded_year': 2009},
#  {'name': 'Next Steps Software', 'founded_year': 2009},
#  {'name': 'ArtWorks Venue', 'founded_year': 2009},
#  {'name': 'SlideMap', 'founded_year': 2009},
#  {'name': 'PathMotion', 'founded_year': 2009},
#  {'name': 'StoreBlogs', 'founded_year': 2009},
#  {'name': 'Job Search Page', 'founded_year': 2009},
#  {'name': 'Reclamacion Bancaria', 'founded_year': 2009},
#  {'name': 'Telegram Stop', 'founded_year': 2009},
#  {'name': 'Fotomina', 'founded_year': 2009},
#  {'name': 'Brainwave Apps', 'founded_year': 2009},
#  {'name': 'IBWIRE Inc', 'founded_year': 2009},
#  {'name': 'GlobalCityBreak', 'founded_year': 2009},
#  {'name': 'Setster', 'founded_year': 2009},
#  {'name': 'Smart E-Commerce', 'founded_year': 2009},
#  {'name': 'GameChanger Media', 'founded_year': 2009},
#  {'name': 'Klezio', 'founded_year': 2009},
#  {'name': 'highdefnow', 'founded_year': 2009},
#  {'name': 'fReado', 'founded_year': 2009},
#  {'name': 'Z2Live', 'founded_year': 2009},
#  {'name': 'Gate 53|10 Technologies', 'founded_year': 2009},
#  {'name': 'Yazzem', 'founded_year': 2009},
#  {'name': 'JobSpice', 'founded_year': 2009},
#  {'name': 'Y Media Labs', 'founded_year': 2009},
#  {'name': 'PunchT', 'founded_year': 2009},
#  {'name': 'Rseven Mobile', 'founded_year': 2009},
#  {'name': 'RockDex', 'founded_year': 2009},
#  {'name': 'Colligent', 'founded_year': 2009},
#  {'name': 'Tongal', 'founded_year': 2009},
#  {'name': 'SHOCAS', 'founded_year': 2009},
#  {'name': 'oneforty', 'founded_year': 2009},
#  {'name': 'Rhyme Library', 'founded_year': 2009},
#  {'name': 'Nuke Web Solution - SEO Services', 'founded_year': 2009},
#  {'name': 'ShopTimeSaver', 'founded_year': 2009},
#  {'name': 'Muziic', 'founded_year': 2009},
#  {'name': 'Earthenhive Architects', 'founded_year': 2009},
#  {'name': 'Blog Traffic Exchange', 'founded_year': 2009},
#  {'name': 'Operative Mind', 'founded_year': 2009},
#  {'name': 'Chartbeat', 'founded_year': 2009},
#  {'name': 'TweetPhoto', 'founded_year': 2009},
#  {'name': 'Aigc middleast', 'founded_year': 2009},
#  {'name': 'crush tweet', 'founded_year': 2009},
#  {'name': 'MarketFriends', 'founded_year': 2009},
#  {'name': 'Centralino', 'founded_year': 2009},
#  {'name': 'zeaLOG', 'founded_year': 2009},
#  {'name': 'One Kings Lane', 'founded_year': 2009},
#  {'name': "Vetrina's", 'founded_year': 2009},
#  {'name': 'NaijaPulse', 'founded_year': 2009},
#  {'name': 'Eggosbase', 'founded_year': 2009},
#  {'name': 'The Aspiring Professional', 'founded_year': 2009},
#  {'name': 'Trigora', 'founded_year': 2009},
#  {'name': 'Talent Spree', 'founded_year': 2009},
#  {'name': 'Novelion Media', 'founded_year': 2009},
#  {'name': 'Weebiz', 'founded_year': 2009},
#  {'name': 'veedemus', 'founded_year': 2009},
#  {'name': 'Brandsclub', 'founded_year': 2009},
#  {'name': 'Search PDF Books', 'founded_year': 2009},
#  {'name': 'TV Pixie', 'founded_year': 2009},
#  {'name': 'Broadersheet', 'founded_year': 2009},
#  {'name': 'CineSoft', 'founded_year': 2009},
#  {'name': 'Our Convo', 'founded_year': 2009},
#  {'name': 'Blogs with Balls', 'founded_year': 2009},
#  {'name': 'CoTweet', 'founded_year': 2009},
#  {'name': 'Antelink', 'founded_year': 2009},
#  {'name': 'MyHandle', 'founded_year': 2009},
#  {'name': 'Tweet on the Street', 'founded_year': 2009},
#  {'name': 'TribeHQ', 'founded_year': 2009},
#  {'name': 'TenantcY', 'founded_year': 2009},
#  {'name': 'HD Cloud', 'founded_year': 2009},
#  {'name': 'VetAnyware', 'founded_year': 2009},
#  {'name': 'Novira Therapeutics', 'founded_year': 2009},
#  {'name': 'Swimwire', 'founded_year': 2009},
#  {'name': 'Leadjini', 'founded_year': 2009},
#  {'name': 'Insurance4everyone', 'founded_year': 2009},
#  {'name': 'Wowd', 'founded_year': 2009},
#  {'name': 'Twazzup', 'founded_year': 2009},
#  {'name': 'TwitterMass', 'founded_year': 2009},
#  {'name': 'Ffffoundtape', 'founded_year': 2009},
#  {'name': 'Fan2Win', 'founded_year': 2009},
#  {'name': 'Mojo Media', 'founded_year': 2009},
#  {'name': 'GAY Submit', 'founded_year': 2009},
#  {'name': 'We Are Hunted', 'founded_year': 2009},
#  {'name': 'Serpslogic', 'founded_year': 2009},
#  {'name': 'Actridge', 'founded_year': 2009},
#  {'name': 'BlazingStreams', 'founded_year': 2009},
#  {'name': 'Compel Interaction', 'founded_year': 2009},
#  {'name': 'BookTour', 'founded_year': 2009},
#  {'name': 'DataXu', 'founded_year': 2009},
#  {'name': 'Tweenjo', 'founded_year': 2009},
#  {'name': 'psychiatryRounds', 'founded_year': 2009},
#  {'name': 'TwitterContd', 'founded_year': 2009},
#  {'name': 'Mancala Time', 'founded_year': 2009},
#  {'name': 'Atenea tech', 'founded_year': 2009},
#  {'name': 'Top Fans', 'founded_year': 2009},
#  {'name': 'FairSpin', 'founded_year': 2009},
#  {'name': 'Mobile Roadie', 'founded_year': 2009},
#  {'name': 'Dora', 'founded_year': 2009},
#  {'name': 'Space Spare', 'founded_year': 2009},
#  {'name': 'iSyndica', 'founded_year': 2009},
#  {'name': 'Webteilchen', 'founded_year': 2009},
#  {'name': 'MyEdu', 'founded_year': 2009},
#  {'name': 'Movylo', 'founded_year': 2009},
#  {'name': 'Gameleaper', 'founded_year': 2009},
#  {'name': 'AlertFox', 'founded_year': 2009},
#  {'name': 'Open Fashion', 'founded_year': 2009},
#  {'name': 'ReverbDesk', 'founded_year': 2009},
#  {'name': 'Catchafire', 'founded_year': 2009},
#  {'name': 'Factery', 'founded_year': 2009},
#  {'name': 'Blogpuzzle', 'founded_year': 2009},
#  {'name': 'Ikanos', 'founded_year': 2009},
#  {'name': 'quoobs', 'founded_year': 2009},
#  {'name': 'TownHall', 'founded_year': 2009},
#  {'name': 'Pikchur', 'founded_year': 2009},
#  {'name': 'PowerMand', 'founded_year': 2009},
#  {'name': '1calendar', 'founded_year': 2009},
#  {'name': 'Infochimps', 'founded_year': 2009},
#  {'name': 'Play Free Online Games', 'founded_year': 2009},
#  {'name': '5to1', 'founded_year': 2009},
#  {'name': 'Spdy Me', 'founded_year': 2009},
#  {'name': 'CellBharat', 'founded_year': 2009},
#  {'name': 'printium', 'founded_year': 2009},
#  {'name': 'Envy Sportswear', 'founded_year': 2009},
#  {'name': 'YesFreelance', 'founded_year': 2009},
#  {'name': 'EazyBusiness', 'founded_year': 2009},
#  {'name': 'View2Gether', 'founded_year': 2009},
#  {'name': 'Swinyx', 'founded_year': 2009},
#  {'name': 'BIT TV', 'founded_year': 2009},
#  {'name': 'TheWantedEdition', 'founded_year': 2009},
#  {'name': 'WebMilker', 'founded_year': 2009},
#  {'name': 'all140', 'founded_year': 2009},
#  {'name': 'Mental Workout', 'founded_year': 2009},
#  {'name': 'Date or Done', 'founded_year': 2009},
#  {'name': 'AlphaPoint Technology', 'founded_year': 2009},
#  {'name': 'Imakumo', 'founded_year': 2009},
#  {'name': 'Absolute Media', 'founded_year': 2009},
#  {'name': 'Distimo', 'founded_year': 2009},
#  {'name': 'Tempolib', 'founded_year': 2009},
#  {'name': 'GotNew', 'founded_year': 2009},
#  {'name': 'Locofoco', 'founded_year': 2009},
#  {'name': 'LendingKarma', 'founded_year': 2009},
#  {'name': 'Corporation Hiburrito', 'founded_year': 2009},
#  {'name': 'Campus Jerk', 'founded_year': 2009},
#  {'name': 'Aikon Labs', 'founded_year': 2009},
#  {'name': 'Sport Cloud', 'founded_year': 2009},
#  {'name': 'Japan Jobs', 'founded_year': 2009},
#  {'name': 'Fast Careers UK', 'founded_year': 2009},
#  {'name': 'BigSpire Technologies', 'founded_year': 2009},
#  {'name': 'TwiShitter', 'founded_year': 2009},
#  {'name': 'tweetmart', 'founded_year': 2009},
#  {'name': 'Delivr', 'founded_year': 2009},
#  {'name': 'AppStoreHQ', 'founded_year': 2009},
#  {'name': 'Elovivo', 'founded_year': 2009},
#  {'name': 'Open Studio', 'founded_year': 2009},
#  {'name': 'Uprise Apps', 'founded_year': 2009},
#  {'name': 'FileShare HQ', 'founded_year': 2009},
#  {'name': 'drchrono', 'founded_year': 2009},
#  {'name': 'Zumbua', 'founded_year': 2009},
#  {'name': 'Pressitt', 'founded_year': 2009},
#  {'name': 'Nextstop', 'founded_year': 2009},
#  {'name': 'Square', 'founded_year': 2009},
#  {'name': 'Offeretti', 'founded_year': 2009},
#  {'name': 'TwitDoc', 'founded_year': 2009},
#  {'name': 'Acme Files', 'founded_year': 2009},
#  {'name': 'Twiix', 'founded_year': 2009},
#  {'name': 'My Text Secret', 'founded_year': 2009},
#  {'name': 'TeeVhe', 'founded_year': 2009},
#  {'name': 'ReadWhale', 'founded_year': 2009},
#  {'name': 'Graticle', 'founded_year': 2009},
#  {'name': 'Wefollow', 'founded_year': 2009},
#  {'name': 'Viewista', 'founded_year': 2009},
#  {'name': 'Techvensys', 'founded_year': 2009},
#  {'name': 'HobbyAdda', 'founded_year': 2009},
#  {'name': 'Hot Tweeters', 'founded_year': 2009},
#  {'name': 'Digiting', 'founded_year': 2009},
#  {'name': 'Magnifier', 'founded_year': 2009},
#  {'name': 'Pikkoo', 'founded_year': 2009},
#  {'name': 'OCTALINE', 'founded_year': 2009},
#  {'name': 'Linktive', 'founded_year': 2009},
#  {'name': 'dondecomes', 'founded_year': 2009},
#  {'name': 'ChefCommons', 'founded_year': 2009},
#  {'name': 'nuAlerts', 'founded_year': 2009},
#  {'name': "Book'd", 'founded_year': 2009},
#  {'name': 'Tweetrprise', 'founded_year': 2009},
#  {'name': 'makandra', 'founded_year': 2009},
#  {'name': 'Eco-Rate', 'founded_year': 2009},
#  {'name': 'Shareaholic', 'founded_year': 2009},
#  {'name': 'Contenture', 'founded_year': 2009},
#  {'name': 'KnowEm', 'founded_year': 2009},
#  {'name': 'Statugle', 'founded_year': 2009},
#  {'name': 'Remodel Connect', 'founded_year': 2009},
#  {'name': 'DP7 Digital', 'founded_year': 2009},
#  {'name': '1000 Markets', 'founded_year': 2009},
#  {'name': 'SimpleGeo', 'founded_year': 2009},
#  {'name': 'zappn', 'founded_year': 2009},
#  {'name': 'Student Liberty Youth Magazine', 'founded_year': 2009},
#  {'name': 'CafeCourses', 'founded_year': 2009},
#  {'name': 'fanqieshu', 'founded_year': 2009},
#  {'name': 'Twitoaster', 'founded_year': 2009},
#  {'name': 'V-Goat', 'founded_year': 2009},
#  {'name': 'AppNinjas', 'founded_year': 2009},
#  {'name': 'Beautiful People Society', 'founded_year': 2009},
#  {'name': 'Wetoku', 'founded_year': 2009},
#  {'name': 'JustProto', 'founded_year': 2009},
#  {'name': 'ConsultantForce', 'founded_year': 2009},
#  {'name': 'HitYotta', 'founded_year': 2009},
#  {'name': 'Fan', 'founded_year': 2009},
#  {'name': 'ToolzDO', 'founded_year': 2009},
#  {'name': 'Open Travel', 'founded_year': 2009},
#  {'name': 'Social Collective', 'founded_year': 2009},
#  {'name': 'LocalTripper', 'founded_year': 2009},
#  {'name': 'gdgt', 'founded_year': 2009},
#  {'name': 'PhotoXpress', 'founded_year': 2009},
#  {'name': 'Mozbox Limited', 'founded_year': 2009},
#  {'name': 'Velvet View', 'founded_year': 2009},
#  {'name': 'Lynki', 'founded_year': 2009},
#  {'name': 'Domain Magnet', 'founded_year': 2009},
#  {'name': 'Vidly', 'founded_year': 2009},
#  {'name': 'jamWee', 'founded_year': 2009},
#  {'name': 'Secure BI', 'founded_year': 2009},
#  {'name': 'ZodBod', 'founded_year': 2009},
#  {'name': 'Dingbee', 'founded_year': 2009},
#  {'name': 'Scratchix', 'founded_year': 2009},
#  {'name': 'Chirpio', 'founded_year': 2009},
#  {'name': 'Activity Bookers', 'founded_year': 2009},
#  {'name': 'Hostarting', 'founded_year': 2009},
#  {'name': 'CustomerGyan', 'founded_year': 2009},
#  {'name': 'SocialPlane', 'founded_year': 2009},
#  {'name': 'QxMD Software', 'founded_year': 2009},
#  {'name': 'expertnews', 'founded_year': 2009},
#  {'name': 'Viralheat', 'founded_year': 2009},
#  {'name': 'Zibbet', 'founded_year': 2009},
#  {'name': 'Flaggpole', 'founded_year': 2009},
#  {'name': 'Hiraj', 'founded_year': 2009},
#  {'name': 'Twitguru', 'founded_year': 2009},
#  {'name': 'Boostability', 'founded_year': 2009},
#  {'name': 'ReferenceBot', 'founded_year': 2009},
#  {'name': 'Awesomeless', 'founded_year': 2009},
#  {'name': 'RJRdata', 'founded_year': 2009},
#  {'name': 'Lifeyoumentary', 'founded_year': 2009},
#  {'name': 'Vaultive', 'founded_year': 2009},
#  {'name': 'VocabSushi', 'founded_year': 2009},
#  {'name': 'gpa software inc', 'founded_year': 2009},
#  {'name': 'Real Hospital Jobs', 'founded_year': 2009},
#  {'name': 'Green Wavelength', 'founded_year': 2009},
#  {'name': 'The Resumator', 'founded_year': 2009},
#  {'name': 'Dubspace', 'founded_year': 2009},
#  {'name': 'App Giveaway', 'founded_year': 2009},
#  {'name': 'JobSphere', 'founded_year': 2009},
#  {'name': 'Twittley', 'founded_year': 2009},
#  {'name': 'Carrier Mobile', 'founded_year': 2009},
#  {'name': 'Sofa Labs', 'founded_year': 2009},
#  {'name': 'AppUseful', 'founded_year': 2009},
#  {'name': 'Growth Panel', 'founded_year': 2009},
#  {'name': 'YR Free', 'founded_year': 2009},
#  {'name': 'College Art Online', 'founded_year': 2009},
#  {'name': 'Kickstarter', 'founded_year': 2009},
#  {'name': 'Undead Code Studios', 'founded_year': 2009},
#  {'name': 'Cokidoo', 'founded_year': 2009},
#  {'name': 'folowen', 'founded_year': 2009},
#  {'name': 'Design Your Dorm', 'founded_year': 2009},
#  {'name': 'Quirky', 'founded_year': 2009},
#  {'name': 'Manager Labs', 'founded_year': 2009},
#  {'name': 'IndiaOnAPage', 'founded_year': 2009},
#  {'name': 'NAIJABORN', 'founded_year': 2009},
#  {'name': 'Nalts Consulting', 'founded_year': 2009},
#  {'name': 'InRev', 'founded_year': 2009},
#  {'name': 'ArtNeighbor', 'founded_year': 2009},
#  {'name': 'Advertising Solutions', 'founded_year': 2009},
#  {'name': 'RSSUnite', 'founded_year': 2009},
#  {'name': 'RentShout', 'founded_year': 2009},
#  {'name': 'Covet', 'founded_year': 2009},
#  {'name': 'ClickFuel', 'founded_year': 2009},
#  {'name': 'Movip', 'founded_year': 2009},
#  {'name': 'TweetWagon', 'founded_year': 2009},
#  {'name': '3D Creation Lab', 'founded_year': 2009},
#  {'name': 'EquiTipz', 'founded_year': 2009},
#  {'name': 'Spezify', 'founded_year': 2009},
#  {'name': 'Logomyway', 'founded_year': 2009},
#  {'name': "Blame Drew's Cancer", 'founded_year': 2009},
#  {'name': 'mTrip', 'founded_year': 2009},
#  {'name': 'Gravity', 'founded_year': 2009},
#  {'name': 'Maopao', 'founded_year': 2009},
#  {'name': 'SearchMerge', 'founded_year': 2009},
#  {'name': 'scoyo', 'founded_year': 2009},
#  {'name': 'Spurd, Inc', 'founded_year': 2009},
#  {'name': 'OnePage', 'founded_year': 2009},
#  {'name': 'Status Search', 'founded_year': 2009},
#  {'name': 'Xamplified', 'founded_year': 2009},
#  {'name': 'Althea Systems', 'founded_year': 2009},
#  {'name': '140Labs', 'founded_year': 2009},
#  {'name': 'FindandSmile', 'founded_year': 2009},
#  {'name': 'Covet Shop', 'founded_year': 2009},
#  {'name': 'ReTargeter', 'founded_year': 2009},
#  {'name': 'Udorse', 'founded_year': 2009},
#  {'name': 'Ganttzilla', 'founded_year': 2009},
#  {'name': 'Meuzer', 'founded_year': 2009},
#  {'name': 'MultiURL', 'founded_year': 2009},
#  {'name': 'Urban Airship', 'founded_year': 2009},
#  {'name': 'fabeetle', 'founded_year': 2009},
#  {'name': 'YesOrNow', 'founded_year': 2009},
#  {'name': 'HURRYCAM', 'founded_year': 2009},
#  {'name': 'Stereomood', 'founded_year': 2009},
#  {'name': 'Quantum Whisper', 'founded_year': 2009},
#  {'name': 'SharesPost', 'founded_year': 2009},
#  {'name': 'Clearly Beer Pong', 'founded_year': 2009},
#  {'name': 'e Luxury Stores', 'founded_year': 2009},
#  {'name': 'citadirecta', 'founded_year': 2009},
#  {'name': 'Bar Exchange', 'founded_year': 2009},
#  {'name': 'Yokaboo', 'founded_year': 2009},
#  {'name': 'Sparcq', 'founded_year': 2009},
#  {'name': 'Nirvana', 'founded_year': 2009},
#  {'name': 'goalster', 'founded_year': 2009},
#  {'name': 'Kloud Mobile', 'founded_year': 2009},
#  {'name': 'Trusted Transcription', 'founded_year': 2009},
#  {'name': 'Finest Expert', 'founded_year': 2009},
#  {'name': 'Innovatv', 'founded_year': 2009},
#  {'name': 'FiredNetwork', 'founded_year': 2009},
#  {'name': 'TwitsMag Canada', 'founded_year': 2009},
#  {'name': 'Buddingup', 'founded_year': 2009},
#  {'name': 'iAppLogic', 'founded_year': 2009},
#  {'name': 'Bionima LLC', 'founded_year': 2009},
#  {'name': 'FilesOverMiles', 'founded_year': 2009},
#  {'name': 'BitMethod', 'founded_year': 2009},
#  {'name': 'Zerodegre', 'founded_year': 2009},
#  {'name': 'ShopTheRate', 'founded_year': 2009},
#  {'name': 'ZIPQODE', 'founded_year': 2009},
#  {'name': 'Eventric', 'founded_year': 2009},
#  {'name': 'Duffel', 'founded_year': 2009},
#  {'name': 'JobMotel', 'founded_year': 2009},
#  {'name': 'BigTree Solutions', 'founded_year': 2009},
#  {'name': 'Strategist News', 'founded_year': 2009},
#  {'name': 'Vevo', 'founded_year': 2009},
#  {'name': 'Talenthouse', 'founded_year': 2009},
#  {'name': 'urNetwork', 'founded_year': 2009},
#  {'name': 'BOKU', 'founded_year': 2009},
#  {'name': 'Tepilo', 'founded_year': 2009},
#  {'name': 'ipadio', 'founded_year': 2009},
#  {'name': 'AgreeYourFee', 'founded_year': 2009},
#  {'name': 'Mohawk Interactive', 'founded_year': 2009},
#  {'name': 'Pixable', 'founded_year': 2009},
#  {'name': 'PrintFriendly', 'founded_year': 2009},
#  {'name': 'Applied Genetics Technologies Corporation', 'founded_year': 2009},
#  {'name': 'Solix Biofuels', 'founded_year': 2009},
#  {'name': 'Ykone', 'founded_year': 2009},
#  {'name': 'I Love Social Media', 'founded_year': 2009},
#  {'name': 'WiseStamp', 'founded_year': 2009},
#  {'name': 'OzTern Digital Services', 'founded_year': 2009},
#  {'name': 'youserbase', 'founded_year': 2009},
#  {'name': 'Clovis Oncology', 'founded_year': 2009},
#  {'name': 'ResuWe', 'founded_year': 2009},
#  {'name': 'Aragon Pharmaceuticals', 'founded_year': 2009},
#  {'name': 'Startlike', 'founded_year': 2009},
#  {'name': 'Ftwitt', 'founded_year': 2009},
#  {'name': 'JoinMinds', 'founded_year': 2009},
#  {'name': 'ITTAGS', 'founded_year': 2009},
#  {'name': 'tiggin', 'founded_year': 2009},
#  {'name': 'Echoes Kazulo', 'founded_year': 2009},
#  {'name': 'Ray Websmith', 'founded_year': 2009},
#  {'name': 'Recreax', 'founded_year': 2009},
#  {'name': 'Enternships', 'founded_year': 2009},
#  {'name': 'TinyPetition', 'founded_year': 2009},
#  {'name': 'Studylance', 'founded_year': 2009},
#  {'name': 'Tour Volume', 'founded_year': 2009},
#  {'name': 'Comufy', 'founded_year': 2009},
#  {'name': 'Aleveo', 'founded_year': 2009},
#  {'name': 'Rashad Media', 'founded_year': 2009},
#  {'name': 'BetMyStock', 'founded_year': 2009},
#  {'name': 'Mojeek', 'founded_year': 2009},
#  {'name': 'Kvittar', 'founded_year': 2009},
#  {'name': 'Layar', 'founded_year': 2009},
#  {'name': 'GatherSource', 'founded_year': 2009},
#  {'name': 'WineDineTv', 'founded_year': 2009},
#  {'name': 'PicFog', 'founded_year': 2009},
#  {'name': 'Taxi Fares app', 'founded_year': 2009},
#  {'name': 'Actinobac Biomed', 'founded_year': 2009},
#  {'name': 'Yafflezone', 'founded_year': 2009},
#  {'name': 'Foodberry', 'founded_year': 2009},
#  {'name': 'FertilityAuthority', 'founded_year': 2009},
#  {'name': 'Tryst', 'founded_year': 2009},
#  {'name': 'Small Bone Innovations', 'founded_year': 2009},
#  {'name': 'LIG Investment Advisers', 'founded_year': 2009},
#  {'name': 'Lipperhey', 'founded_year': 2009},
#  {'name': 'Online Intelligence', 'founded_year': 2009},
#  {'name': 'Locassa', 'founded_year': 2009},
#  {'name': 'Verified Pages', 'founded_year': 2009},
#  {'name': 'M4K1', 'founded_year': 2009},
#  {'name': 'Personal', 'founded_year': 2009},
#  {'name': 'ZOOMcatalog', 'founded_year': 2009},
#  {'name': 'Wikitude', 'founded_year': 2009},
#  {'name': 'vooch', 'founded_year': 2009},
#  {'name': 'Freshly Branded', 'founded_year': 2009},
#  {'name': 'Vyoom', 'founded_year': 2009},
#  {'name': 'Midwest Data Systems', 'founded_year': 2009},
#  {'name': 'Truckeo', 'founded_year': 2009},
#  {'name': 'Vortimer', 'founded_year': 2009},
#  {'name': 'Abillo', 'founded_year': 2009},
#  {'name': 'Myhive', 'founded_year': 2009},
#  {'name': 'TwtBks', 'founded_year': 2009},
#  {'name': '140Ware', 'founded_year': 2009},
#  {'name': 'Asyus', 'founded_year': 2009},
#  {'name': 'Delphi', 'founded_year': 2009},
#  {'name': 'Cloudify', 'founded_year': 2009},
#  {'name': 'LugIron Software', 'founded_year': 2009},
#  {'name': 'CfaTestBank', 'founded_year': 2009},
#  {'name': 'MeetingVoice', 'founded_year': 2009},
#  {'name': 'Easter Egg', 'founded_year': 2009},
#  {'name': 'Dating Software Script', 'founded_year': 2009},
#  {'name': 'Appsfire', 'founded_year': 2009},
#  {'name': 'Kilrush Digital', 'founded_year': 2009},
#  {'name': 'ChallengePost', 'founded_year': 2009},
#  {'name': 'Jowki', 'founded_year': 2009},
#  {'name': 'Tweetmondo', 'founded_year': 2009},
#  {'name': 'Outspoken Media', 'founded_year': 2009},
#  {'name': 'WorkWatcher', 'founded_year': 2009},
#  {'name': 'Teambox', 'founded_year': 2009},
#  {'name': 'SPOTI', 'founded_year': 2009},
#  {'name': 'Revetto', 'founded_year': 2009},
#  {'name': 'Fuze Box', 'founded_year': 2009},
#  {'name': 'Automatic Backlinks', 'founded_year': 2009},
#  {'name': 'Kerfuffle', 'founded_year': 2009},
#  {'name': 'Clickom', 'founded_year': 2009},
#  {'name': 'Pinboard', 'founded_year': 2009},
#  {'name': 'What the Hashtag?', 'founded_year': 2009},
#  {'name': 'Bonvoyagee', 'founded_year': 2009},
#  {'name': 'ftopia', 'founded_year': 2009},
#  {'name': 'Tiverias Apps', 'founded_year': 2009},
#  {'name': 'Collective Core', 'founded_year': 2009},
#  {'name': 'Glacir', 'founded_year': 2009},
#  {'name': 'Abadoo', 'founded_year': 2009},
#  {'name': 'Concealium Software', 'founded_year': 2009},
#  {'name': 'HOTForms123', 'founded_year': 2009},
#  {'name': 'PlentyWays', 'founded_year': 2009},
#  {'name': 'Aava Mobile', 'founded_year': 2009},
#  {'name': 'Luma International', 'founded_year': 2009},
#  {'name': 'Bookwhen', 'founded_year': 2009},
#  {'name': 'pTracker', 'founded_year': 2009},
#  {'name': 'CityMove', 'founded_year': 2009},
#  {'name': 'MergeSkills', 'founded_year': 2009},
#  {'name': 'Flatterline', 'founded_year': 2009},
#  {'name': 'tribalX', 'founded_year': 2009},
#  {'name': 'atlanticOptimize', 'founded_year': 2009},
#  {'name': 'CRMStage', 'founded_year': 2009},
#  {'name': 'Malaysia Travel', 'founded_year': 2009},
#  {'name': 'LinkSpreadeR', 'founded_year': 2009},
#  {'name': 'PubliciTweet', 'founded_year': 2009},
#  {'name': 'Tiny Speck', 'founded_year': 2009},
#  {'name': 'Advanced Power Projects', 'founded_year': 2009},
#  {'name': 'ConvoCreatr', 'founded_year': 2009},
#  {'name': 'Gambolio', 'founded_year': 2009},
#  {'name': 'SEO Sumo', 'founded_year': 2009},
#  {'name': 'InstantQ', 'founded_year': 2009},
#  {'name': 'acrossair', 'founded_year': 2009},
#  {'name': 'MyChances', 'founded_year': 2009},
#  {'name': 'Getyoo', 'founded_year': 2009},
#  {'name': 'OfficialVirtualDJ', 'founded_year': 2009},
#  {'name': 'Oriact', 'founded_year': 2009},
#  {'name': 'Adhunk', 'founded_year': 2009},
#  {'name': 'OpenX', 'founded_year': 2008},
#  {'name': 'GoingOn', 'founded_year': 2008},
#  {'name': 'Cloudant', 'founded_year': 2008},
#  {'name': 'KIT digital', 'founded_year': 2008},
#  {'name': 'YouBeQB', 'founded_year': 2008},
#  {'name': 'Crunchyroll', 'founded_year': 2008},
#  {'name': 'Uptake', 'founded_year': 2008},
#  {'name': 'BeliefNet', 'founded_year': 2008},
#  {'name': 'Fancast', 'founded_year': 2008},
#  {'name': 'Newspepper', 'founded_year': 2008},
#  {'name': 'Webnode', 'founded_year': 2008},
#  {'name': 'MOLI', 'founded_year': 2008},
#  {'name': 'WonderHowTo', 'founded_year': 2008},
#  {'name': 'First30Days', 'founded_year': 2008},
#  {'name': 'Mibura', 'founded_year': 2008},
#  {'name': 'PokerPlayersSocialNetwork', 'founded_year': 2008},
#  {'name': 'thatsmymouse', 'founded_year': 2008},
#  {'name': 'Taunt Media', 'founded_year': 2008},
#  {'name': 'Tvosz', 'founded_year': 2008},
#  {'name': 'Triptuber', 'founded_year': 2008},
#  {'name': 'Unknown Vector', 'founded_year': 2008},
#  {'name': 'Jirbo', 'founded_year': 2008},
#  {'name': 'Poodz', 'founded_year': 2008},
#  {'name': 'HealthcareMagic', 'founded_year': 2008},
#  {'name': 'HEXIO', 'founded_year': 2008},
#  {'name': 'Volo Media', 'founded_year': 2008},
#  {'name': '8aweek', 'founded_year': 2008},
#  {'name': 'BuzzFeed', 'founded_year': 2008},
#  {'name': 'Snapseekers', 'founded_year': 2008},
#  {'name': 'Stumpedia', 'founded_year': 2008},
#  {'name': 'Askablogr', 'founded_year': 2008},
#  {'name': 'fotopedia', 'founded_year': 2008},
#  {'name': 'Trackur', 'founded_year': 2008},
#  {'name': 'IShareWeShare', 'founded_year': 2008},
#  {'name': 'Newspond', 'founded_year': 2008},
#  {'name': 'JackPot Rewards', 'founded_year': 2008},
#  {'name': 'Newsclipper', 'founded_year': 2008},
#  {'name': 'P2P-Next', 'founded_year': 2008},
#  {'name': 'CineGoGo', 'founded_year': 2008},
#  {'name': 'Academic Capital Exchange', 'founded_year': 2008},
#  {'name': 'Kluster', 'founded_year': 2008},
#  {'name': 'RareShare', 'founded_year': 2008},
#  {'name': 'Scred', 'founded_year': 2008},
#  {'name': 'Howcast', 'founded_year': 2008},
#  {'name': 'BillShrink', 'founded_year': 2008},
#  {'name': 'Particle', 'founded_year': 2008},
#  {'name': 'Totspot', 'founded_year': 2008},
#  {'name': 'Biographicon', 'founded_year': 2008},
#  {'name': 'Heavy Electrons', 'founded_year': 2008},
#  {'name': 'ZapNat', 'founded_year': 2008},
#  {'name': 'Workpost', 'founded_year': 2008},
#  {'name': 'ProofHQ', 'founded_year': 2008},
#  {'name': '99designs', 'founded_year': 2008},
#  {'name': 'LiveRail', 'founded_year': 2008},
#  {'name': 'nobosh', 'founded_year': 2008},
#  {'name': 'Gsm Lobby', 'founded_year': 2008},
#  {'name': 'Jpari', 'founded_year': 2008},
#  {'name': 'Bloxes', 'founded_year': 2008},
#  {'name': 'CityIN', 'founded_year': 2008},
#  {'name': 'politicsultra', 'founded_year': 2008},
#  {'name': 'Jobzerk', 'founded_year': 2008},
#  {'name': 'AppPad', 'founded_year': 2008},
#  {'name': 'Mobicue', 'founded_year': 2008},
#  {'name': 'Sprout', 'founded_year': 2008},
#  {'name': 'Gnip', 'founded_year': 2008},
#  {'name': 'Wundrbar', 'founded_year': 2008},
#  {'name': 'Darrb', 'founded_year': 2008},
#  {'name': 'Tapioca Mobile', 'founded_year': 2008},
#  {'name': 'Wordki', 'founded_year': 2008},
#  {'name': 'Notice Technologies', 'founded_year': 2008},
#  {'name': 'CreateDebate', 'founded_year': 2008},
#  {'name': 'CloudMade', 'founded_year': 2008},
#  {'name': 'ReadBurner', 'founded_year': 2008},
#  {'name': 'Clipta', 'founded_year': 2008},
#  {'name': 'Act-On Software', 'founded_year': 2008},
#  {'name': 'VisualSage', 'founded_year': 2008},
#  {'name': 'tunesBag', 'founded_year': 2008},
#  {'name': 'InformedMD', 'founded_year': 2008},
#  {'name': 'thesixtyone', 'founded_year': 2008},
#  {'name': 'Soashable', 'founded_year': 2008},
#  {'name': 'Silentale', 'founded_year': 2008},
#  {'name': 'Quotably', 'founded_year': 2008},
#  {'name': 'Intent', 'founded_year': 2008},
#  {'name': 'BuyerRaja', 'founded_year': 2008},
#  {'name': 'Episodic', 'founded_year': 2008},
#  {'name': 'Rosterbot', 'founded_year': 2008},
#  {'name': 'Weplay', 'founded_year': 2008},
#  {'name': 'Akvo', 'founded_year': 2008},
#  {'name': 'Sport Ngin', 'founded_year': 2008},
#  {'name': 'Say2GO', 'founded_year': 2008},
#  {'name': 'Wakozi', 'founded_year': 2008},
#  {'name': 'Kalibera', 'founded_year': 2008},
#  {'name': 'TagCow', 'founded_year': 2008},
#  {'name': 'Edmodo', 'founded_year': 2008},
#  {'name': 'Noovo', 'founded_year': 2008},
#  {'name': 'Woopra', 'founded_year': 2008},
#  {'name': 'AudioMicro', 'founded_year': 2008},
#  {'name': 'Penzu', 'founded_year': 2008},
#  {'name': 'stickychicken', 'founded_year': 2008},
#  {'name': 'Recommend Box', 'founded_year': 2008},
#  {'name': 'Sososher', 'founded_year': 2008},
#  {'name': 'Learn10', 'founded_year': 2008},
#  {'name': 'eHealthMe', 'founded_year': 2008},
#  {'name': 'Students Know', 'founded_year': 2008},
#  {'name': 'Weardrobe', 'founded_year': 2008},
#  {'name': 'Livestrong', 'founded_year': 2008},
#  {'name': 'PriorSmart', 'founded_year': 2008},
#  {'name': 'Guitarati', 'founded_year': 2008},
#  {'name': 'Teet', 'founded_year': 2008},
#  {'name': 'Asaph', 'founded_year': 2008},
#  {'name': 'Cotendo', 'founded_year': 2008},
#  {'name': 'Pirillo Open Source CMS Project', 'founded_year': 2008},
#  {'name': 'Coull', 'founded_year': 2008},
#  {'name': 'GamerNook', 'founded_year': 2008},
#  {'name': 'YouVersion', 'founded_year': 2008},
#  {'name': 'Twubble', 'founded_year': 2008},
#  {'name': 'Edistorm', 'founded_year': 2008},
#  {'name': 'WineTastetv', 'founded_year': 2008},
#  {'name': 'FinFolio', 'founded_year': 2008},
#  {'name': 'FragMob', 'founded_year': 2008},
#  {'name': 'skoogO', 'founded_year': 2008},
#  {'name': 'Jobingenieur', 'founded_year': 2008},
#  {'name': 'Mojiva', 'founded_year': 2008},
#  {'name': 'Cutcaster', 'founded_year': 2008},
#  {'name': 'GitHub', 'founded_year': 2008},
#  {'name': 'YUPPTV', 'founded_year': 2008},
#  {'name': 'Gridjit', 'founded_year': 2008},
#  {'name': 'BookGlutton', 'founded_year': 2008},
#  {'name': 'Mibbit', 'founded_year': 2008},
#  {'name': 'MyFab', 'founded_year': 2008},
#  {'name': 'Twitlinks', 'founded_year': 2008},
#  {'name': 'TweetMeme', 'founded_year': 2008},
#  {'name': 'Salesconx', 'founded_year': 2008},
#  {'name': 'Mad Mimi', 'founded_year': 2008},
#  {'name': 'TutorByTxt', 'founded_year': 2008},
#  {'name': 'Sutros', 'founded_year': 2008},
#  {'name': 'EQAL', 'founded_year': 2008},
#  {'name': 'Beer Universe', 'founded_year': 2008},
#  {'name': 'Commuto', 'founded_year': 2008},
#  {'name': 'TigerLogic', 'founded_year': 2008},
#  {'name': 'Tweet Clouds', 'founded_year': 2008},
#  {'name': 'All-rankings', 'founded_year': 2008},
#  {'name': 'Mollom', 'founded_year': 2008},
#  {'name': 'UserVoice', 'founded_year': 2008},
#  {'name': 'StrawPoll', 'founded_year': 2008},
#  {'name': 'Crowdstatus', 'founded_year': 2008},
#  {'name': 'Imagine Whatever', 'founded_year': 2008},
#  {'name': 'Sideline Report', 'founded_year': 2008},
#  {'name': 'WotsCool', 'founded_year': 2008},
#  {'name': 'MySocial 24x7', 'founded_year': 2008},
#  {'name': 'CheckDog', 'founded_year': 2008},
#  {'name': 'Wolpy', 'founded_year': 2008},
#  {'name': 'Serious Business', 'founded_year': 2008},
#  {'name': 'Retail Convergence', 'founded_year': 2008},
#  {'name': 'StubOrder', 'founded_year': 2008},
#  {'name': 'Twistory', 'founded_year': 2008},
#  {'name': 'The Publicity Wheel', 'founded_year': 2008},
#  {'name': 'Twitturly', 'founded_year': 2008},
#  {'name': 'twit+', 'founded_year': 2008},
#  {'name': 'grabAfriend', 'founded_year': 2008},
#  {'name': 'SoarPort', 'founded_year': 2008},
#  {'name': 'Pontiflex', 'founded_year': 2008},
#  {'name': 'InGameNow', 'founded_year': 2008},
#  {'name': 'ImportGenius', 'founded_year': 2008},
#  {'name': 'GeoGraffiti', 'founded_year': 2008},
#  {'name': 'Syncplicity', 'founded_year': 2008},
#  {'name': 'New Relic', 'founded_year': 2008},
#  ...]

# %% [markdown]
# ### 15. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `acquisition price` in a descending order. Limit the search to 10 documents.

# %%
list(colec.find({'founded_day':{'$lte':7}},
                {'name':1, '_id':0, 'acquisition.price_amount':1, 'founded_day':1}).sort('acquisition.price_amount', -1).limit(10))
# Out:
# [{'name': 'Netscape',
#   'founded_day': 4,
#   'acquisition': {'price_amount': 4200000000}},
#  {'name': 'PayPal',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 1500000000}},
#  {'name': 'Zappos',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 1200000000}},
#  {'name': 'Alibaba',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 1000000000}},
#  {'name': 'Postini',
#   'founded_day': 2,
#   'acquisition': {'price_amount': 625000000}},
#  {'name': 'Danger',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 500000000}},
#  {'name': 'Clearwell Systems',
#   'founded_day': 6,
#   'acquisition': {'price_amount': 410000000}},
#  {'name': 'PrimeSense',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 345000000}},
#  {'name': 'Amobee',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 321000000}},
#  {'name': 'BlueLithium',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 300000000}}]

# %% [markdown]
# ### 16. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascending order.

# %%
list(colec.find({'$and':[{'category_code':'web'}, 
                       {'number_of_employees':{'$gt':4000}}]},
               
               {'_id':0,'name':1,'category_code':1,'number_of_employees':1}).sort('number_of_employees',1))
# Out:
# [{'name': 'Expedia', 'category_code': 'web', 'number_of_employees': 4400},
#  {'name': 'AOL', 'category_code': 'web', 'number_of_employees': 8000},
#  {'name': 'Webkinz', 'category_code': 'web', 'number_of_employees': 8657},
#  {'name': 'Rakuten', 'category_code': 'web', 'number_of_employees': 10000},
#  {'name': 'Los Angeles Times Media Group',
#   'category_code': 'web',
#   'number_of_employees': 10000},
#  {'name': 'Groupon', 'category_code': 'web', 'number_of_employees': 10000},
#  {'name': 'Yahoo!', 'category_code': 'web', 'number_of_employees': 13600},
#  {'name': 'eBay', 'category_code': 'web', 'number_of_employees': 15000},
#  {'name': 'Experian', 'category_code': 'web', 'number_of_employees': 15500}]

# %% [markdown]
# ### 17. All the companies whose acquisition amount is more than 10.000.000, and currency is 'EUR'.

# %%
list(colec.find({'$and':[{'acquisition.price_amount':{'$gt':1e7}},
                         {'acquisition.price_currency_code':'EUR'}]},
                
                {'_id':0, 'name':1, 'acquisition.price_amount':1, 'acquisition.price_currency_code':1}))
# Out:
# [{'name': 'ZYB',
#   'acquisition': {'price_amount': 31500000, 'price_currency_code': 'EUR'}},
#  {'name': 'Apertio',
#   'acquisition': {'price_amount': 140000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Greenfield Online',
#   'acquisition': {'price_amount': 40000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Webedia',
#   'acquisition': {'price_amount': 70000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Wayfinder',
#   'acquisition': {'price_amount': 24000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Tuenti Technologies',
#   'acquisition': {'price_amount': 70000000, 'price_currency_code': 'EUR'}},
#  {'name': 'BioMed Central',
#   'acquisition': {'price_amount': 43400000, 'price_currency_code': 'EUR'}}]

# %% [markdown]
# ### 18. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
list(colec.find({'acquisition.acquired_month':{'$lte':3}},
                {'_id':0, 'name':1, 'acquisition.acquired_month':1}).limit(10))
# Out:
# [{'name': 'Kyte', 'acquisition': {'acquired_month': 1}},
#  {'name': 'NetRatings', 'acquisition': {'acquired_month': 2}},
#  {'name': 'blogTV', 'acquisition': {'acquired_month': 3}},
#  {'name': 'Livestream', 'acquisition': {'acquired_month': 1}},
#  {'name': 'iContact', 'acquisition': {'acquired_month': 2}},
#  {'name': 'Coghead', 'acquisition': {'acquired_month': 2}},
#  {'name': 'Dailymotion', 'acquisition': {'acquired_month': 2}},
#  {'name': 'Netvibes', 'acquisition': {'acquired_month': 2}},
#  {'name': 'Flickr', 'acquisition': {'acquired_month': 3}},
#  {'name': 'BabyCenter', 'acquisition': {'acquired_month': 3}}]

# %% [markdown]
# # Bonus
# ### 19. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
list(colec.find({'$and':[{'founded_year':{'$gte':2000, '$lte':2010}},
                         {'acquisition.acquired_year':{'$gte':2011}}]},
                
                {'_id':0, 'name':1,'founded_year':1,'acquisition.acquired_year':1}))
# Out:
# [{'name': 'Wetpaint',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Digg',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Geni',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Kyte',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Jingle Networks',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'blogTV',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'delicious',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Revision3',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'iContact',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Mashery',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Dailymotion',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'KickApps',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Instructables',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Netvibes',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Dogster',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'adBrite',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Meebo',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Seesmic',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Zvents',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Oodle',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Flixster',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'IceRocket',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'hi5', 'founded_year': 2003, 'acquisition': {'acquired_year': 2011}},
#  {'name': 'Indeed',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Grockit',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Zenfolio',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Wishpot',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Retrevo',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'SelectMinds',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Flock',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'TimeBridge',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'TokBox',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Six Apart',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'MySpace',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Doostang',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Docstoc',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Vlingo',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'sezmi',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Greystripe',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'LocaModa',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Thumbplay',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'OMGPOP',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Daylife',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Behance',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Attributor',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'WooMe',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Viewdle',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Mixx',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'TripIt',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'OneRiot',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Tumri',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Clickable',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'GamerDNA',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Xobni',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Sermo',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Worklight',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'PlaySpan',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Zimbra',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'earthmine',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Whiskey Media',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'VoodooVox',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'CondoDomain',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Uptake',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'AdReady',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'The Climate Corporation',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Tumblr',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'JackBe',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'EchoSign',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Rollbase',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Marakana',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Peer39',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Vitrue',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Pelago',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'MerchantCircle',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Loopt',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Bloglines',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Mogreet',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'UpNext',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'TrustedID',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Sendori',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Kewego',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'SocialPicks',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Shipwire',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Smilebox',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Kosmix',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Goodreads',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Qik', 'founded_year': 2006, 'acquisition': {'acquired_year': 2011}},
#  {'name': 'KAYAK',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Scrapblog',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Meraki',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Jobfox',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Outspark',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Livemocha',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Mpayy',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'SuccessFactors',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'UnLtdWorld',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Amobee',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Roost',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Lijit Networks',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Taptu',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'BreakingPoint Systems',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Qype',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'PicScout',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'MOG', 'founded_year': 2005, 'acquisition': {'acquired_year': 2012}},
#  {'name': 'SnapNames',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Paprika Lab',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'AdoTube',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'HipLogic',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Camlink',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'SlideRocket',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Particle',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Vovici',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Panache',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'PacketFront',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Litmos',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Next New Networks',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Sprout',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'NeoEdge Networks',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'modu',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Krillion',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Star Analytics',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Replay Solutions',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'SignalDemand',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Planypus',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Snipshot',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Dimdim',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'OrangeSoda',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Magento',
#   'founded_year': 2010,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Clearwell Systems',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Trendrr',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Weplay',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Postlets',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'dotSyntax',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Zong',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Cotendo',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Enomaly',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'SiBEAM',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Vivity Labs',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'MediaWhiz',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'mediaFORGE',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Trunkt',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'AdXpose',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Compfight',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Salesconx',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Collective Intellect',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Apture',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Soocial',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'EQAL',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'LOVEFiLM',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'TeachStreet',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Mollom',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Savvy Circle',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Android',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Syncplicity',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Zinch',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'PrimeSense',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'FuGen Solutions',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'ClairMail',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'FIRST ROI',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'CitizenHawk',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Efficient Frontier',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Tiny Prints',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Sometrics',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'JustMeans',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Transpera',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Tupalo',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Aster Data Systems',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Fliqz',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'CoverItLive',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'OtherInbox',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Acquity Group',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'BelAir Networks',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Handmark',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'StartForce',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Intelliworks',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Yield Software',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Pivot',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Sense Networks',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2014}},
#  {'name': 'Wilogo',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'mokono',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Bestofmedia Group',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Socialcast',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'EpikOne',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Bandsintown',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Boxee',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Astaro',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'InQuira',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'AdParlor',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'OkCupid',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'SageTV',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Instinctiv',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Posterous',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'National Transcript Center',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'TweetDeck',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Praxis Language',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'WatchMouse',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Saffron Digital',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Involver',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'GigMaven',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Truviso',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'ADCentricity',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Leafish',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Napera Networks',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Academic Earth',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Buysight',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Qumu',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Allvoices',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Admeld',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'ActiveCause',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'RentMineOnline',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Hunch',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'dynaTrace software',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Sandlot Games',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Hyper9',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'InstallFree',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Likewise Software',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'BackType',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'ZManda',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Advasense',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'bTendo',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Synchronica',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Axis',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'ReTel Technologies',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'ShopWiki',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'PPTV',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Jumptap',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Producteev',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Yammer',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'GoodGuide',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': "Where I've Been",
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Swype',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Intela',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Big Stage',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Lolapps',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'AUPEO!',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Metismo',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Hyper9',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'InstallFree',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Likewise Software',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'BackType',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'ZManda',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Advasense',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'bTendo',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Synchronica',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Axis',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'ReTel Technologies',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'ShopWiki',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'PPTV',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Jumptap',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Producteev',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Yammer',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'GoodGuide',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': "Where I've Been",
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Swype',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Intela',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Big Stage',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Lolapps',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'AUPEO!',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Metismo',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'LogLogic',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Gowalla',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Atalasoft',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Vertica Systems',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'CoreTrace',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Twittertise',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Wiggio',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Avaak',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'PropertyBridge',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Kiva Systems',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Sentrigo',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'ExactTarget',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'FanSnap',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'AskMe Corp',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'CarZen',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Globrix',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Games2Win',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Obtiva',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Trusteer',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Crescendo Networks',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Model Metrics',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Brickfish',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Citizenside',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Clearwire',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Ascribe',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'SiteBrand',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Rollstream',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Imagine Communications',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'NewBay',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'iChange',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'HyperWeek',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'PlaceVine',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Webedia',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'expressor software',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'mFoundry',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Azuro',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Guaranteach',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'AppLabs',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Geocade',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Pardot',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': '3X Systems',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Circle of Moms',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Rainbow Partners',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Quantivo',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Silver Tail Systems',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Arc90',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Rhythm NewMedia',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'GoGo Lingo',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'SenSage',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Procedural',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'eConversions',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Oberon Media',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Provade',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Virident Systems',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': '3Leaf',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'InfoEther',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Better Place',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Crossbeam Systems',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'RingCube Technologies',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Mu Dynamics',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Multigig',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Sensory Networks',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'ID Analytics',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Socialbomb',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'CureTogether',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Demotix',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'NorthStar Systems International',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Project Wedding',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'ParAccel',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Vocalocity',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'PhoneFactor',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'BroadLight',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Voxify',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'PokeTALK',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Liquid Air Lab',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Open Kernel Labs',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Telegent Systems',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Crossing Automation',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'DesignArt Networks',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'HYFN',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Neuralitic Systems',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Nexsan',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Echopass Corporation',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'M-Factor',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'TRAFFIQ',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Virtual Computer',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Xelerated',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Audiolife',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'VirtuOz',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Litepoint',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Shutl',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Neverblue',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Socialize',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'ulike',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Oversi',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Spoiled Milk',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'ScienceOps',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'TopCoder',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Strangeloop Networks',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Selatra',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Outright',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Sourcefire',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Pliant Technology',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Enclarity',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Mendeley',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Tynt',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Pixmac',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'ClickEquations',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Viridity Software',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Evostor',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'SchemaLogic',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Safend',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Honk',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'BioVex',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Javaground',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Zenprise',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'RightsFlow',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Kiala',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'picoChip',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Tatto Media',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Zoombu',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'SmartReply',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Ardian',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'goviral',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'MCLA The Lax Mag',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Republic Project',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Tamarac',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Preview Networks',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'oneforty',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'iPropertyWebsites',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'IdentityTruth',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'TweetPhoto',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'CheapCheapCheap',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Joobili',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'EnergyHub',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'avVenta',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'IMASTE',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Solera Networks',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'N-able Technologies',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Zencoder',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Adeptol',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Trellia Networks',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'billFLO',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Instapaper',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'LikeCube',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Infochimps',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': '5to1',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'GigLocator',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'HipCricket',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Markafoni',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'OffiSync',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'JustSpotted',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Fulcrum Microsystems',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Wefollow',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Fotomoto',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Vital Networks',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Arieso',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'VKernel Corporation',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Attassa',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'HauteLook',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Playfire',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Miyowa',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'SensorLogic',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': '1000 Markets',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Bigfoot Networks',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'TxVia',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'SimpleGeo',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'gdgt',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Garlik',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'ArtusLabs',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Rhythmia Medical',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'CardStar',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Pixlr',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Topsy Labs',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Autoquake',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Zipcar',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Hara',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Soliant Energy',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Blip',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'TRIRIGA',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Prenova',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Pasteuria Bioscience',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Social Shore',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Icera',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Pixable',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Certify Data Systems',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Semprus BioSciences',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Aragon Pharmaceuticals',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Xsigo',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Demdex',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Context Optional',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Pachube',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'FastSoft',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'oneDrum',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'tarpipe',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'The Book Depository',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Taligen Therapeutics',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Makani Power',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Peekspy',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Enpirion',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Pearl Therapeutics',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Aveksa',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'SpectraLinear',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Layer 7 Technologies',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Clean Mobile',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Colibria',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'StreamBase Systems',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'PopCap Games',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'SoftLayer',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Moonfruit',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'BzzAgent',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Avenda Systems',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Telx',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Liquavista',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'iCentera',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Anchor Bay Technologies',
#   'founded_year': 2001,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'SandForce',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Applied Language Solutions',
#   'founded_year': 2003,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Aspera',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Everyday Solutions',
#   'founded_year': 2000,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'MediaPal',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'Bump Technologies',
#   'founded_year': 2008,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'ALOT',
#   'founded_year': 2007,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'OptiMedica',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Luminus Devices',
#   'founded_year': 2002,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Celestial Semiconductor',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2011}},
#  {'name': 'MyChances',
#   'founded_year': 2009,
#   'acquisition': {'acquired_year': 2011}}]

# %% [markdown]
# ### 20. All the companies that have been 'deadpooled' after the third year.

# %%
deed = list(colec.find({'$and':[{'deadpooled_year':{'$gt':3}}, 
                               {'founded_year':{'$gt':1000}}]},
                               
                               
        {'_id':0, 'name':1, 'deadpooled_year':1, 'founded_year':1}))

# %%
deed[:10]
# Out:
# [{'name': 'Omnidrive', 'founded_year': 2005, 'deadpooled_year': 2008},
#  {'name': 'Babelgum', 'founded_year': 2007, 'deadpooled_year': 2013},
#  {'name': 'Sparter', 'founded_year': 2007, 'deadpooled_year': 2008},
#  {'name': 'Thoof', 'founded_year': 2006, 'deadpooled_year': 2013},
#  {'name': 'Wesabe', 'founded_year': 2005, 'deadpooled_year': 2010},
#  {'name': 'Jangl SMS', 'founded_year': 2005, 'deadpooled_year': 2008},
#  {'name': 'Stickam', 'founded_year': 2006, 'deadpooled_year': 2013},
#  {'name': 'AllPeers', 'founded_year': 2004, 'deadpooled_year': 2008},
#  {'name': 'EQO', 'founded_year': 2006, 'deadpooled_year': 2012},
#  {'name': 'AllofMP3', 'founded_year': 2000, 'deadpooled_year': 2007}]

# %%
import pandas as pd
df = pd.DataFrame(deed)
df.head()
# Out:
#         name  founded_year  deadpooled_year
# 0  Omnidrive          2005             2008
# 1   Babelgum          2007             2013
# 2    Sparter          2007             2008
# 3      Thoof          2006             2013
# 4     Wesabe          2005             2010

# %%
df['dife'] = df.deadpooled_year - df.founded_year

# %%
df.head()
# Out:
#         name  founded_year  deadpooled_year  dife
# 0  Omnidrive          2005             2008     3
# 1   Babelgum          2007             2013     6
# 2    Sparter          2007             2008     1
# 3      Thoof          2006             2013     7
# 4     Wesabe          2005             2010     5

# %%
empresas = df[df.dife > 3]
empresas
# Out:
#                  name  founded_year  deadpooled_year  dife
# 1            Babelgum          2007             2013     6
# 3               Thoof          2006             2013     7
# 4              Wesabe          2005             2010     5
# 6             Stickam          2006             2013     7
# 7            AllPeers          2004             2008     4
# ..                ...           ...              ...   ...
# 697         SpeakSoft          2007             2012     5
# 699            Tagito          2008             2012     4
# 700  Nordic Windpower          2007             2013     6
# 702    Nethra Imaging          2003             2012     9
# 705           Prolify          2002             2007     5
#
# [437 rows x 4 columns]

# %%
empresas['name']
# Out:
# 1              Babelgum
# 3                 Thoof
# 4                Wesabe
# 6               Stickam
# 7              AllPeers
#              ...
# 697           SpeakSoft
# 699              Tagito
# 700    Nordic Windpower
# 702      Nethra Imaging
# 705             Prolify
# Name: name, Length: 437, dtype: object

# %%
pd.options.display.max_rows = None

# %%
empresas['name']
# Out:
# 1                             Babelgum
# 3                                Thoof
# 4                               Wesabe
# 6                              Stickam
# 7                             AllPeers
# 8                                  EQO
# 9                             AllofMP3
# 10                           SellABand
# 11                                Zlio
# 12                               Jaiku
# 16                             Coghead
# 18                              Swivel
# 19                               Slide
# 21                                Sway
# 23                           coComment
# 24                        Hotelicopter
# 25                               Ujogo
# 26                              PeerMe
# 27                             Tangler
# 28                            TalkPlus
# 29                        PermissionTV
# 31                            Nirvanix
# 33                          Millsberry
# 34                              Revver
# 35                               Sampa
# 36                            DanceJam
# 38                          Brightkite
# 40                               Zango
# 42                             BitPass
# 43                          SpiralFrog
# 44                            Multiply
# 45                         RampedMedia
# 47                             Nemedia
# 48                              Trutap
# 50                               ITema
# 51                               Orgoo
# 53                           RatePoint
# 55                           MuseStorm
# 56                                Eons
# 57                                Cuil
# 58                                mEgo
# 59                        StoryBlender
# 60                           BroadClip
# 63                              Goojet
# 64                           Notemarks
# 65                            mPortico
# 67                             Grouply
# 68                              PlanHQ
# 69                            Youlicit
# 70                             Mixaloo
# 71                             Zipidee
# 72                             Confabb
# 73                            Buzzwire
# 74                             YowTRIP
# 77                           Eurekster
# 78                            Songbird
# 79                        GridNetworks
# 80                            Upcoming
# 81                         Excite@Home
# 82                               Faves
# 83                             Minekey
# 87                             Apprema
# 88                             Skribit
# 89                               xkoto
# 91                          Adhysteria
# 92                              SeeToo
# 93                              betNOW
# 95                              Dapper
# 98                             RipCode
# 99                         SimulScribe
# 101                          bluepulse
# 102                               ARPU
# 103                           Journeys
# 104                             yoonew
# 105                            Enforta
# 106                             Mumboe
# 107                              Bizak
# 109                           TV Shack
# 110                        Sharetivity
# 117                     What They Like
# 118                             Qifang
# 121                          Smalltown
# 122                         EveryBlock
# 124                         QponDirect
# 126                             Danger
# 127                          RealNames
# 130                           YouCastr
# 131                    JackPot Rewards
# 133                     World Reviewer
# 136                          Swarmcast
# 138                    Fifteen Reasons
# 142                            I-stats
# 144                              Akoha
# 146                BrightSide Software
# 147                             CityIN
# 149                             Everex
# 150                           SearchMe
# 151                     Global Roaming
# 153                               modu
# 156                            Elastra
# 158                      Authenticlick
# 161                         Socialmoth
# 162                     Tapioca Mobile
# 163                         WebVisible
# 165                             Zebtab
# 168                             Etelos
# 169                           HelloTxt
# 170                  Clearwell Systems
# 171                     YourTeamOnline
# 172                          Pressflip
# 173                             itzbig
# 175                             Minggl
# 176                              Naubo
# 178                           Netcipia
# 179                            Jodange
# 180                           PutPlace
# 182                        Vivity Labs
# 183                         Labmeeting
# 184                       CVN Networks
# 185                          Twitlinks
# 188                        BubbleShare
# 189                             Muxlim
# 191                         PrepChamps
# 192                           Aardvark
# 193                             Viewzi
# 194                          Talicious
# 195                OPEN Sports Network
# 196                           Center'd
# 200                           Skyrider
# 203                             twidox
# 204                      Your Survival
# 205                              BView
# 206                 Dilithium Networks
# 208                            Accoona
# 210                           Fonemesh
# 212                        shopandsave
# 213                            mywaves
# 214                     Amazing Worlds
# 215                              Ztail
# 216                          MediaRush
# 217                   Creative Citizen
# 218                         EnterMedia
# 220                      Sxip Identity
# 224                          Zefanclub
# 226                               1bib
# 227                             Aptera
# 229                           TeleFlip
# 230             Inertia Beverage Group
# 232                           DotSpots
# 233                              Muecs
# 234                        MyPronostic
# 236                           MIKESTAR
# 237                           Twiddict
# 240                           ECO-SAFE
# 243                           MovieSet
# 246                             Loud3r
# 248                          MyTrainer
# 249                         IntroNiche
# 250                            LinQpay
# 252                            SaySwap
# 253                             Guruji
# 255                       RoboDynamics
# 256                            FlyCast
# 258                              rPath
# 261                        Fortisphere
# 262                              Zoopy
# 263                             Cyloop
# 264                             Yuntaa
# 265                    adicate timeads
# 268                       Semanticator
# 269                        Partnerbyte
# 277                          mmCHANNEL
# 278                            KnowNow
# 280            Refulgence Technostream
# 281                         SulfurCell
# 283                             AtBizz
# 284                        Kappa Prime
# 285                              Polka
# 286             Blue Lava Technologies
# 287                            neoSaej
# 288                         ByteShield
# 289                           Medpedia
# 290                              Myrio
# 291                        ArtistForce
# 292                      PhoneFromHere
# 293                     Cascada Mobile
# 294                            Jamglue
# 295                               Lexy
# 296                             Code71
# 297                      Carbonetworks
# 298                        Instagarage
# 302                             Enikos
# 303                RODECO ICT Services
# 305                              Cucku
# 307                           Mobnotes
# 309                  Six Degrees Games
# 310                    Local Marketers
# 311                       LeisureLogix
# 313                        Logia Group
# 314                             Heekya
# 315                           ididwork
# 316                       MyFrontSteps
# 319                        Frogmetrics
# 321                              1Cast
# 323                            Varolii
# 324                     Nevis Networks
# 325             Sequoia Communications
# 326                   Unity 4 Humanity
# 328                             Storrz
# 331                             Phokki
# 332                        Carticipate
# 333      Shattered Reality Interactive
# 334                       FairSoftware
# 336                          HammerKit
# 339                           Klatcher
# 340                         artandseek
# 341                          Picateers
# 342                             Linkua
# 344                SimpleLeap Software
# 348                      Fusion Garage
# 349                             Gruvie
# 350                          Pixelpipe
# 355                        Frogmetrics
# 357                              1Cast
# 359                            Varolii
# 360                     Nevis Networks
# 361             Sequoia Communications
# 362                   Unity 4 Humanity
# 364                             Storrz
# 367                             Phokki
# 368                        Carticipate
# 369      Shattered Reality Interactive
# 370                       FairSoftware
# 372                          HammerKit
# 375                           Klatcher
# 376                         artandseek
# 377                          Picateers
# 378                             Linkua
# 380                SimpleLeap Software
# 384                      Fusion Garage
# 385                             Gruvie
# 386                          Pixelpipe
# 389                            Getfugu
# 390                        The Society
# 391                 ConSentry Networks
# 393                             Telera
# 394                          Metranome
# 395                           Semantra
# 396                               Qpyn
# 397                        DirectMoney
# 398                      Ziva Software
# 399                    Vertica Systems
# 401                 Club Scene Network
# 404                               Povo
# 405                          GeoCities
# 406                           FanPrice
# 407                          SDH Group
# 408                            MyShape
# 409                            FlameUp
# 412                     Koala Databank
# 413                       Gossip Girls
# 414                              Zubka
# 415              Tailgate Technologies
# 416                           SolFocus
# 417         InterStilist Professionnel
# 418                          TripShake
# 419                             Vontoo
# 420                        Mybandstock
# 422                           DubMeNow
# 423                        Microsupply
# 425                  Engineering Ideas
# 428                            FanSnap
# 429                      Karo Internet
# 432                             Pumant
# 433                             Tyfish
# 435                            maufait
# 439                      Dolphin Geeks
# 441                           Newmerix
# 442                               Qoof
# 446                              Zadby
# 447                              iKobo
# 448                           kidthing
# 451                            Q-magic
# 452                       GlobalCrypto
# 453                     Planet Metrics
# 454                   Illumix Software
# 455                   Easy Bill Online
# 456                           pickrset
# 458                           Qapacity
# 459                           Tiberium
# 460                  Behind the Burner
# 462                            Amadesa
# 464                            AndSpot
# 465                          FirstDIBZ
# 466                           AutoVirt
# 467                         Darkstrand
# 468                           Raffstar
# 472                             Meijob
# 473                           BetUknow
# 474                          Bloggerce
# 475                        Hit Systems
# 476                             REMOTV
# 478                              Zykis
# 479                             Exit41
# 480                        Broadchoice
# 484                            Zentact
# 485                           Novafora
# 486                         artaculous
# 490                            eBillme
# 492                             Rudder
# 493                               i2we
# 494                        mBeat Media
# 495                    SeeSaw Networks
# 496                       IMedExchange
# 498                        Robotgalaxy
# 500                      Avega Systems
# 501                 Hammerhead Systems
# 502                Neopolitan Networks
# 504                          VoloMedia
# 505                       Fuego Nation
# 506                   Applied Identity
# 507                           Kickfire
# 508                           AdYouNet
# 509                     Aquest Systems
# 510                  ChipVision Design
# 513                Digital Performance
# 514                         Crowd Rent
# 516                            Rapport
# 519                              Focus
# 520                     Zeugma Systems
# 523                Extreme Enterprises
# 524                              scanR
# 525                            QSecure
# 526                   IonLogix Systems
# 527                        KlickSports
# 528                              4Blox
# 531                           HeySpace
# 532                         Speedshape
# 534      Power Analog Microelectronics
# 535              Shocking Technologies
# 536                            Appscio
# 537                          Nanoradio
# 538                       Aurora Feint
# 539                    Jumper Networks
# 542                           Gemisimo
# 543                            RADLIVE
# 544                            OpVista
# 547                  Hidden City Games
# 550                           Collexpo
# 552                          CipherMax
# 554                            Etology
# 555                        Gecko Audio
# 556             Executive Intermediary
# 557                            Bandbox
# 558                            Spotigo
# 559                         Filmmortal
# 560                             Pollsb
# 561        Digital Marketing Solutions
# 565                    HellHouse Media
# 568                Punch Entertainment
# 569                     htmlPlayground
# 570                            servtag
# 571    Pocket Communications Northeast
# 573                            Hotalot
# 575                           ABC Live
# 577                          M3X Media
# 578                     Gnomz Software
# 582                            Ondeego
# 583                         Fabchannel
# 584                            Foldees
# 586                           Pacinian
# 587                            Dmailer
# 588                           Ubequity
# 589                          Futuretec
# 591                         Heartscape
# 598                              Rovrr
# 601                            TrewCap
# 604                              Cruxy
# 605                           LookStat
# 607                             KnewCo
# 608                             Groxis
# 609                          GoNogging
# 612                            Divided
# 615                          Aerovance
# 619                   Airship Ventures
# 627                            Factery
# 628                         FledgeWing
# 630                             kinkon
# 632                          LETSGROOP
# 634                              Bidoo
# 637                       SPOC Medical
# 638                   Matisse Networks
# 639                Nakaya Microdevices
# 640                           CinemaKi
# 641                   Canopy Financial
# 643                           FanFeedr
# 644                     Elanti Systems
# 646                        Virgin Play
# 649                         Therosteon
# 650                           DermaGen
# 653                      Pigmata Media
# 654                              Ecast
# 655                              Libox
# 656                         ClassifEye
# 657                              Vocab
# 658                          ZettaCore
# 660                            Mobshop
# 661                   Rewarding Return
# 662                              BeeTV
# 663                         GameGround
# 665                           DynaPump
# 666                            Apieron
# 668                           Anaphore
# 669                     Morgan Everett
# 672                          Biofisica
# 674                 InterMed Discovery
# 675                              S*Bio
# 676                 Limerick BioPharma
# 677                       CostumeWorks
# 679                      FuckedCompany
# 680                            Scopial
# 683                Biolex Therapeutics
# 684                         PhotoThera
# 685              Global Data Solutions
# 686                             Azingo
# 689                 JinkoSolar Holding
# 690                  ERTH Technologies
# 691                              LEYIO
# 692                 Kurani Interactive
# 693                     Metallkraft AS
# 694                           MindFuse
# 695                       Bling Nation
# 697                          SpeakSoft
# 699                             Tagito
# 700                   Nordic Windpower
# 702                     Nethra Imaging
# 705                            Prolify
# Name: name, dtype: object
